# %% [markdown]
# 1.   Data cleaning functions
# 2.   Tokenization & Lemmatization
# 3. StopWords
# 4. POS Tagging
# 5. NER
# 6. Sentiment Analysis
# 7. RAKE
# 8. KeyBERT

# %%
# !pip3 install rake-nltk
# Out:
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from rake-nltk) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.66.2)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.8.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.25.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (24.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 54.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 53.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.4 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 46.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.4-py3-none-any.whl size=39200 sha256=d3cda2f4007c36cb8101c6bbe180245d4305268d8ef9f5ce7745d67178a83d59
#   Stored in directory: /root/.cache/pip/wheels/97/ef/4c/6588bd7072b0cc04225b40e639b991e49ebd4e21fb81f0acee
# Successfully built keybert
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers, keybert
# Successfully installed keybert-0.8.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.5.1

# %% [markdown]
# ##Libraries

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import pos_tag
from nltk import ne_chunk

import re

#import stanza
from rake_nltk import Rake
from keybert import KeyBERT

# %%
# Download necessary resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %% [markdown]
# ##Load Data

# %%
# Load the dataset
df = pd.read_csv('speaker_speeches.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                      Speaker  \
# 0           0            SHRI GAURAV GOGOI
# 1           1     SHRI MADDILA GURUMOORTHY
# 2           2          SHRI RAMPRIT MANDAL
# 3           3  SHRI PRATAP CHANDRA SARANGI
# 4           4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category
# 0            Issue
# 1  Call For Action
# 2  Call For Action
# 3       Appreciate
# 4       Appreciate

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Speaker       0
# Speech        0
# Date          0
# Type          0
# Gender        0
# Party         0
# Category      0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category
# 0            Issue
# 1  Call For Action
# 2  Call For Action
# 3       Appreciate
# 4       Appreciate

# %% [markdown]
# ##Preprocessing

# %%
# Storing the original speech
df['original_speech'] = df['Speech']

# %%
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category                                    original_speech
# 0            Issue  This is a country characterised by devotion. T...
# 1  Call For Action  I would like to speak about Lord  Rama and the...
# 2  Call For Action  I would like to express my gratitude to you  f...
# 3       Appreciate  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4       Appreciate  Unprecedented work has been done during the  1...

# %%
def removeNumbers(data):
	return ''.join([i for i in data if not i.isdigit()])

def toLowerCase(data):
	return data.lower()

def removeWhiteSpace(data):
	return data.replace(" ","")

def removeNewLine(data):
	return data.replace("\n","")

def getUpperCharacters(data):
	return ''.join(c for c in data if c.isupper())

def removeSpecialCharacters(data):
	data = re.sub('[^a-zA-Z0-9 \n\.]', '', data)
	return data

def removePunctuation(data):
    data = re.sub(r'[^\w\s]', '', data)
    return data

# %%
df['Preprocessed_Speech'] = df['Speech'].apply(toLowerCase)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removeSpecialCharacters)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removeNewLine)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removeNumbers)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removePunctuation)

# %%
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category                                    original_speech  \
# 0            Issue  This is a country characterised by devotion. T...
# 1  Call For Action  I would like to speak about Lord  Rama and the...
# 2  Call For Action  I would like to express my gratitude to you  f...
# 3       Appreciate  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4       Appreciate  Unprecedented work has been done during the  1...
#
#                                  Preprocessed_Speech
# 0  this is a country characterised by devotion th...
# 1  i would like to speak about lord  rama and the...
# 2  i would like to express my gratitude to you  f...
# 3  lord ram is a symbol of dignity  lord shri ram...
# 4  unprecedented work has been done during the  t...

# %%
df['Preprocessed_Speech'][1]
# Out:
# 'i would like to speak about lord  rama and the importance of the eternal teachings of lord rama as depicted in the  ramayana his reign termed as ram rajya symbolized good governance and  epitomised justice welfare and happiness for all the leadership of lord rama was  dedicated to fairness compassion and the welfare of his people above all else the  lord venkateshwara temple in my parliamentary constituency at tirupati is one of  the most famous temples in our country anjanadri hill one of the seven hills is  supposed to be the birthplace of hanuman another location lepakshi is referenced  in the ramaana which stands as a testament to the widespread reverence of lord  ramas legacy  by developing these sites we will enhance indias cultural heritage  tourism as well as reinforce the bonds of unity and spirituality inspired by lord  rama we request the government for comprehensive development and better  connectivity to all religious sites nationwide to further enrich our cultural heritage  and thereby strengthen the fabric of our society'

# %% [markdown]
# ###Tokenization & Lemmatization

# %%
# Tokenization function using Stanza
df['Tokenized_Speech'] = df['Preprocessed_Speech'].apply(word_tokenize)

# %%
df['Tokenized_Speech'][0]
# Out:
# ['this',
#  'is',
#  'a',
#  'country',
#  'characterised',
#  'by',
#  'devotion',
#  'this',
#  'country',
#  'is',
#  'a',
#  'country',
#  'of',
#  'faith',
#  'in',
#  'this',
#  'country',
#  'we',
#  'bind',
#  'our',
#  'diversity',
#  'with',
#  'goodwill',
#  'and',
#  'cherish',
#  'the',
#  'society',
#  'with',
#  'a',
#  'sense',
#  'of',
#  'service',
#  'lord',
#  'rama',
#  'belongs',
#  'to',
#  'everyone',
#  'and',
#  'he',
#  'is',
#  'with',
#  'us',
#  'all',
#  'the',
#  'time',
#  'when',
#  'we',
#  'meet',
#  'each',
#  'other',
#  'we',
#  'exchange',
#  'greetings',
#  'by',
#  'saying',
#  'ramram',
#  'in',
#  'north',
#  'india',
#  'or',
#  'western',
#  'india',
#  'what',
#  'is',
#  'mahatma',
#  'gandhis',
#  'definition',
#  'of',
#  'ram',
#  'rajya',
#  'where',
#  'everyone',
#  'is',
#  'happy',
#  'and',
#  'no',
#  'one',
#  'is',
#  'sad',
#  'this',
#  'is',
#  'his',
#  'definition',
#  'gandhi',
#  'ji',
#  'has',
#  'also',
#  'said',
#  'that',
#  'his',
#  'hindu',
#  'dharma',
#  'teaches',
#  'him',
#  'to',
#  'respect',
#  'all',
#  'religions',
#  'the',
#  'secret',
#  'of',
#  'ram',
#  'rajya',
#  'is',
#  'inherent',
#  'in',
#  'this',
#  'definition',
#  'we',
#  'should',
#  'ponder',
#  'whether',
#  'all',
#  'the',
#  'backward',
#  'deprived',
#  'and',
#  'minorities',
#  'are',
#  'happy',
#  'this',
#  'was',
#  'the',
#  'definition',
#  'of',
#  'ram',
#  'rajya',
#  'by',
#  'mahatma',
#  'gandhi',
#  'but',
#  'today',
#  'we',
#  'are',
#  'seeing',
#  'that',
#  'crimes',
#  'against',
#  'scheduled',
#  'castes',
#  'and',
#  'scheduled',
#  'tribes',
#  'are',
#  'on',
#  'the',
#  'rise',
#  'if',
#  'we',
#  'compare',
#  'it',
#  'with',
#  'the',
#  'year',
#  'gone',
#  'by',
#  'crime',
#  'has',
#  'gone',
#  'up',
#  'by',
#  'around',
#  'percent',
#  'in',
#  'the',
#  'year',
#  'is',
#  'this',
#  'ram',
#  'rajya',
#  'today',
#  'the',
#  'backward',
#  'classes',
#  'are',
#  'demanding',
#  'a',
#  'caste',
#  'census',
#  'because',
#  'they',
#  'see',
#  'that',
#  'injustice',
#  'is',
#  'being',
#  'meted',
#  'out',
#  'to',
#  'them',
#  'and',
#  'caste',
#  'discrimination',
#  'is',
#  'taking',
#  'place',
#  'sita',
#  'mata',
#  'has',
#  'also',
#  'been',
#  'referred',
#  'to',
#  'in',
#  'the',
#  'ramayana',
#  'sita',
#  'mata',
#  'never',
#  'let',
#  'her',
#  'patience',
#  'and',
#  'strength',
#  'diminish',
#  'but',
#  'did',
#  'the',
#  'dalit',
#  'daughter',
#  'of',
#  'unnao',
#  'our',
#  'women',
#  'wrestlers',
#  'have',
#  'the',
#  'same',
#  'feeling',
#  'when',
#  'they',
#  'were',
#  'fighting',
#  'for',
#  'their',
#  'rights',
#  'it',
#  'is',
#  'mentioned',
#  'in',
#  'the',
#  'report',
#  'of',
#  'our',
#  'own',
#  'parliamentary',
#  'committee',
#  'that',
#  'women',
#  'belonging',
#  'to',
#  'the',
#  'scheduled',
#  'castes',
#  'are',
#  'being',
#  'harassed',
#  'on',
#  'the',
#  'basis',
#  'of',
#  'caste',
#  'and',
#  'gender',
#  'and',
#  'they',
#  'are',
#  'also',
#  'sexually',
#  'exploited',
#  'after',
#  'this',
#  'discussion',
#  'in',
#  'the',
#  'lok',
#  'sabha',
#  'when',
#  'all',
#  'the',
#  'mps',
#  'go',
#  'to',
#  'their',
#  'respective',
#  'constituencies',
#  'they',
#  'will',
#  'see',
#  'helplessness',
#  'among',
#  'the',
#  'youth',
#  'today',
#  'due',
#  'to',
#  'this',
#  'unemployment',
#  'the',
#  'helpless',
#  'indian',
#  'youth',
#  'has',
#  'chosen',
#  'the',
#  'path',
#  'of',
#  'drugs',
#  'and',
#  'crime',
#  'today',
#  'they',
#  'helplessly',
#  'arrange',
#  'some',
#  'funds',
#  'and',
#  'migrate',
#  'to',
#  'a',
#  'foreign',
#  'country',
#  'this',
#  'is',
#  'the',
#  'reality',
#  'we',
#  'can',
#  'not',
#  'deny',
#  'this',
#  'truth',
#  'that',
#  'is',
#  'why',
#  'our',
#  'party',
#  'has',
#  'been',
#  'doing',
#  'social',
#  'service',
#  'for',
#  'so',
#  'many',
#  'years',
#  'we',
#  'are',
#  'aware',
#  'of',
#  'the',
#  'truth',
#  'we',
#  'have',
#  'done',
#  'a',
#  'lot',
#  'but',
#  'still',
#  'a',
#  'lot',
#  'remains',
#  'to',
#  'be',
#  'done',
#  'we',
#  'too',
#  'have',
#  'no',
#  'objection',
#  'in',
#  'admitting',
#  'that',
#  'we',
#  'have',
#  'made',
#  'mistakes',
#  'whereas',
#  'the',
#  'congress',
#  'follows',
#  'gandhis',
#  'ram',
#  'rajya',
#  'we',
#  'walk',
#  'on',
#  'the',
#  'path',
#  'of',
#  'justice',
#  'we',
#  'believe',
#  'in',
#  'secularism',
#  'people',
#  'living',
#  'in',
#  'india',
#  'believe',
#  'in',
#  'different',
#  'religions',
#  'and',
#  'we',
#  'believe',
#  'in',
#  'equality',
#  'of',
#  'all',
#  'religions',
#  'not',
#  'just',
#  'scripture',
#  'but',
#  'there',
#  'is',
#  'so',
#  'much',
#  'strength',
#  'in',
#  'the',
#  'soil',
#  'of',
#  'this',
#  'country',
#  'that',
#  'binds',
#  'the',
#  'different',
#  'languages',
#  'and',
#  'faiths',
#  'of',
#  'crore',
#  'people',
#  'with',
#  'integrity',
#  'love',
#  'and',
#  'goodwill',
#  'therefore',
#  'i',
#  'would',
#  'also',
#  'like',
#  'to',
#  'caution',
#  'the',
#  'ruling',
#  'party',
#  'that',
#  'it',
#  'should',
#  'desist',
#  'from',
#  'following',
#  'the',
#  'path',
#  'of',
#  'nathuram',
#  'they',
#  'should',
#  'not',
#  'allow',
#  'the',
#  'tradition',
#  'of',
#  'glorifying',
#  'nathuram',
#  'either',
#  'you',
#  'should',
#  'not',
#  'have',
#  'any',
#  'hesitation',
#  'in',
#  'this',
#  'i',
#  'would',
#  'like',
#  'to',
#  'say',
#  'that',
#  'one',
#  'must',
#  'refrain',
#  'from',
#  'exhibiting',
#  'ego',
#  'in',
#  'ones',
#  'conduct',
#  'ravana',
#  'was',
#  'killed',
#  'due',
#  'to',
#  'his',
#  'ego',
#  'it',
#  'is',
#  'the',
#  'egoistic',
#  'approach',
#  'of',
#  'the',
#  'government',
#  'that',
#  'keeps',
#  'it',
#  'from',
#  'casting',
#  'a',
#  'look',
#  'on',
#  'rising',
#  'inflation',
#  'and',
#  'instability',
#  'in',
#  'the',
#  'country',
#  'whether',
#  'it',
#  'is',
#  'in',
#  'manipur',
#  'ladakh',
#  'or',
#  'along',
#  'the',
#  'border',
#  'with',
#  'china',
#  'your',
#  'ego',
#  'prevents',
#  'you',
#  'from',
#  'perceiving',
#  'the',
#  'growing',
#  'apprehension',
#  'that',
#  'exists',
#  'in',
#  'society',
#  'today',
#  'particularly',
#  'among',
#  'minorities',
#  'this',
#  'country',
#  'did',
#  'not',
#  'come',
#  'into',
#  'existence',
#  'when',
#  'this',
#  'government',
#  'came',
#  'to',
#  'power',
#  'in',
#  'the',
#  'year',
#  'this',
#  'country',
#  'did',
#  'not',
#  'emerge',
#  'on',
#  'earth',
#  'on',
#  'january',
#  'ram',
#  'lalla',
#  'was',
#  'always',
#  'with',
#  'us',
#  'he',
#  'was',
#  'with',
#  'us',
#  'even',
#  'years',
#  'ago',
#  'and',
#  'is',
#  'with',
#  'us',
#  'even',
#  'today',
#  'and',
#  'when',
#  'your',
#  'government',
#  'is',
#  'not',
#  'in',
#  'power',
#  'he',
#  'will',
#  'be',
#  'with',
#  'us',
#  'tomorrow',
#  'also',
#  'ram',
#  'is',
#  'in',
#  'our',
#  'hearts',
#  'there',
#  'should',
#  'be',
#  'love',
#  'and',
#  'goodwill',
#  'in',
#  'saying',
#  'jai',
#  'shri',
#  'ram',
#  'but',
#  'bitterness',
#  'and',
#  'anger',
#  'are',
#  'always',
#  'heard',
#  'in',
#  'your',
#  'jai',
#  'shri',
#  'ram',
#  'why',
#  'is',
#  'it',
#  'so',
#  'the',
#  'indian',
#  'national',
#  'congress',
#  'party',
#  'has',
#  'always',
#  'worked',
#  'to',
#  'confer',
#  'rights',
#  'on',
#  'the',
#  'citizens',
#  'of',
#  'india',
#  'in',
#  'a',
#  'spirit',
#  'of',
#  'service',
#  'inspired',
#  'by',
#  'the',
#  'values',
#  'of',
#  'gandhiji',
#  'and',
#  'the',
#  'guidance',
#  'of',
#  'dr',
#  'ambedkar',
#  'we',
#  'also',
#  'expect',
#  'you',
#  'to',
#  'work',
#  'in',
#  'a',
#  'spirit',
#  'of',
#  'service',
#  'in',
#  'whatever',
#  'time',
#  'is',
#  'left',
#  'in',
#  'your',
#  'tenure',
#  'let',
#  'me',
#  'remind',
#  'you',
#  'once',
#  'again',
#  'that',
#  'in',
#  'our',
#  'country',
#  'there',
#  'are',
#  'many',
#  'religions',
#  'many',
#  'scriptures',
#  'many',
#  'prophets',
#  'but',
#  'if',
#  'there',
#  'is',
#  'any',
#  'scripture',
#  'of',
#  'governance',
#  'it',
#  'is',
#  'only',
#  'the',
#  'constitution',
#  'the',
#  'minister',
#  'of',
#  'state',
#  'in',
#  'the',
#  'ministry',
#  'of',
#  'consumer',
#  'affairs',
#  'food',
#  'and',
#  'public',
#  'distribution',
#  'and',
#  'minister',
#  'of',
#  'state',
#  'in',
#  'the',
#  'ministry',
#  'of',
#  'rural',
#  'development',
#  'sadhvi',
#  'niranjan',
#  'jyoti',
#  'i',
#  'being',
#  'associated',
#  'with',
#  'the',
#  'ram',
#  'janmabhoomi',
#  'movement',
#  'support',
#  'this',
#  'motion',
#  'in',
#  'this',
#  'new',
#  'house',
#  'and',
#  'compliment',
#  'the',
#  'illustrious',
#  'prime',
#  'minister',
#  'of',
#  'the',
#  'country',
#  'on',
#  'behalf',
#  'of',
#  'the',
#  'saints',
#  'and',
#  'the',
#  'people',
#  'of',
#  'the',
#  'country',
#  'this',
#  'was',
#  'a',
#  'struggle',
#  'of',
#  'years',
#  'although',
#  'the',
#  'name',
#  'of',
#  'any',
#  'person',
#  'from',
#  'outside',
#  'can',
#  'not',
#  'be',
#  'mentioned',
#  'here',
#  'today',
#  'when',
#  'i',
#  'stand',
#  'to',
#  'speak',
#  'on',
#  'this',
#  'motion',
#  'i',
#  'would',
#  'like',
#  'to',
#  'recall',
#  'the',
#  'respected',
#  'late',
#  'ashok',
#  'singhal',
#  'ji',
#  'the',
#  'saints',
#  'who',
#  'never',
#  'knew',
#  'how',
#  'to',
#  'live',
#  'under',
#  'roofs',
#  'who',
#  'used',
#  'to',
#  'live',
#  'in',
#  'forests',
#  'under',
#  'the',
#  'trees',
#  'they',
#  'all',
#  'gathered',
#  'in',
#  'the',
#  'kumbh',
#  'of',
#  'prayagraj',
#  'for',
#  'the',
#  'ram',
#  'janmabhoomi',
#  'on',
#  'the',
#  'request',
#  'of',
#  'ashok',
#  'singhal',
#  'ji',
#  'now',
#  'there',
#  'was',
#  'a',
#  'lot',
#  'of',
#  'discussion',
#  'from',
#  'the',
#  'opposition',
#  'side',
#  'they',
#  'talked',
#  'about',
#  'bapuji',
#  'after',
#  'independence',
#  'mahatma',
#  'gandhi',
#  'had',
#  'also',
#  'said',
#  'that',
#  'since',
#  'independence',
#  'had',
#  'been',
#  'achieved',
#  'congress',
#  'should',
#  'be',
#  'abolished',
#  'this',
#  'was',
#  'not',
#  'accepted',
#  'but',
#  'if',
#  'anyone',
#  'has',
#  'truly',
#  'implemented',
#  'the',
#  'idea',
#  'of',
#  'ram',
#  'rajya',
#  'it',
#  'has',
#  'been',
#  'implemented',
#  'by',
#  'the',
#  'illustrious',
#  'prime',
#  'minister',
#  'of',
#  'the',
#  'country',
#  'the',
#  'people',
#  'of',
#  'the',
#  'country',
#  'are',
#  'watching',
#  'what',
#  'the',
#  'opposition',
#  'did',
#  'to',
#  'ram',
#  'earlier',
#  'in',
#  'the',
#  'year',
#  'their',
#  'counsel',
#  'had',
#  'appeared',
#  'in',
#  'court',
#  'and',
#  'submitted',
#  'that',
#  'a',
#  'judgment',
#  'should',
#  'not',
#  'be',
#  'passed',
#  'in',
#  'favour',
#  'of',
#  'the',
#  'construction',
#  'of',
#  'the',
#  'ram',
#  'temple',
#  'i',
#  'respect',
#  'the',
#  'judges',
#  'and',
#  'congratulate',
#  'the',
#  'honprime',
#  'minister',
#  'of',
#  'the',
#  'country',
#  'we',
#  'have',
#  'to',
#  'change',
#  'history',
#  'now',
#  'by',
#  'reading',
#  'the',
#  'ramcharit',
#  'manas',
#  'and',
#  'follow',
#  'the',
#  'path',
#  'of',
#  'lord',
#  'ram',
#  'hon',
#  'prime',
#  'minister',
#  'has',
#  ...]

# %%
# Initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

#lemmatize the speech using NLTK
def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens

df['Lemmatized_Speech'] = df['Preprocessed_Speech'].apply(lemmatize_text)

# %%
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category                                    original_speech  \
# 0            Issue  This is a country characterised by devotion. T...
# 1  Call For Action  I would like to speak about Lord  Rama and the...
# 2  Call For Action  I would like to express my gratitude to you  f...
# 3       Appreciate  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4       Appreciate  Unprecedented work has been done during the  1...
#
#                                  Preprocessed_Speech  \
# 0  this is a country characterised by devotion th...
# 1  i would like to speak about lord  rama and the...
# 2  i would like to express my gratitude to you  f...
# 3  lord ram is a symbol of dignity  lord shri ram...
# 4  unprecedented work has been done during the  t...
#
#                                     Tokenized_Speech  \
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, has, been, done, during,...
#
#                                    Lemmatized_Speech
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, ha, been, done, during, ...

# %% [markdown]
# ###Removing stopwords

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))

# %%
# Pre-processed field contains the tokens upon which tokenisation, lemmatisation and removal of punctuation and stop-words is applied
df['Preprocessed_Speech'] = df['Lemmatized_Speech']

# %%
for i in range(len(df)):
    df['Preprocessed_Speech'][i] = [ele for ele in df['Preprocessed_Speech'][i] if ele not in (stop_words)]

# %%
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category                                    original_speech  \
# 0            Issue  This is a country characterised by devotion. T...
# 1  Call For Action  I would like to speak about Lord  Rama and the...
# 2  Call For Action  I would like to express my gratitude to you  f...
# 3       Appreciate  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4       Appreciate  Unprecedented work has been done during the  1...
#
#                                  Preprocessed_Speech  \
# 0  [country, characterised, devotion, country, co...
# 1  [would, like, speak, lord, rama, importance, e...
# 2  [would, like, express, gratitude, giving, oppo...
# 3  [lord, ram, symbol, dignity, lord, shri, ram, ...
# 4  [unprecedented, work, ha, done, th, lok, sabha...
#
#                                     Tokenized_Speech  \
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, has, been, done, during,...
#
#                                    Lemmatized_Speech
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, ha, been, done, during, ...

# %% [markdown]
# ###POS Tagging

# %%
def pos_tagging(tokens):
    tagged_tokens = pos_tag(tokens)
    return tagged_tokens

df['POS_Tagged_Speech'] = df['Preprocessed_Speech'].apply(pos_tagging)

# %%
print("POS Tagged Sentence:")
for word, pos_tag in df['POS_Tagged_Speech'][0]:
    print(f"{word}({pos_tag})", end=" ")
# Out:
# POS Tagged Sentence:
# country(NN) characterised(VBD) devotion(JJ) country(NN) country(NN) faith(VBD) country(NN) bind(NN) diversity(NN) goodwill(NN) cherish(JJ) society(NN) sense(NN) service(NN) lord(NN) rama(NN) belongs(VBZ) everyone(NN) u(JJ) time(NN) meet(JJ) exchange(NN) greeting(VBG) saying(VBG) ramram(JJ) north(JJ) india(JJ) western(JJ) india(NN) mahatma(NN) gandhi(JJ) definition(NN) ram(NN) rajya(NN) everyone(NN) happy(JJ) one(CD) sad(JJ) definition(NN) gandhi(NN) ji(NN) ha(NN) also(RB) said(VBD) hindu(JJ) dharma(NN) teach(NN) respect(NN) religion(NN) secret(JJ) ram(NN) rajya(NN) inherent(JJ) definition(NN) ponder(NN) whether(IN) backward(NN) deprived(VBN) minority(NN) happy(JJ) wa(NN) definition(NN) ram(NN) rajya(NN) mahatma(NN) gandhi(NN) today(NN) seeing(VBG) crime(NN) scheduled(VBN) caste(NN) scheduled(VBN) tribe(JJ) rise(NN) compare(NN) year(NN) gone(VBN) crime(NN) ha(NN) gone(VBN) around(IN) percent(JJ) year(NN) ram(NN) rajya(NN) today(NN) backward(IN) class(NN) demanding(VBG) caste(NN) census(NN) see(VBP) injustice(RB) meted(VBN) caste(NN) discrimination(NN) taking(VBG) place(NN) sita(NN) mata(NN) ha(NN) also(RB) referred(VBD) ramayana(JJ) sita(NN) mata(NN) never(RB) let(VBD) patience(NN) strength(NN) diminish(JJ) dalit(NN) daughter(NN) unnao(JJ) woman(NN) wrestler(NN) feeling(VBG) fighting(VBG) right(RB) mentioned(VBN) report(NN) parliamentary(JJ) committee(NN) woman(NN) belonging(VBG) scheduled(VBN) caste(NN) harassed(VBN) basis(NN) caste(NN) gender(NN) also(RB) sexually(RB) exploited(VBN) discussion(NN) lok(NN) sabha(NN) mp(NN) go(VBP) respective(JJ) constituency(NN) see(VBP) helplessness(NN) among(IN) youth(NN) today(NN) due(JJ) unemployment(NN) helpless(NN) indian(JJ) youth(NN) ha(NN) chosen(VBN) path(JJ) drug(NN) crime(NN) today(NN) helplessly(RB) arrange(JJ) fund(NN) migrate(NN) foreign(JJ) country(NN) reality(NN) deny(VBP) truth(NN) party(NN) ha(JJ) social(JJ) service(NN) many(JJ) year(NN) aware(JJ) truth(NN) done(VBN) lot(NN) still(RB) lot(NN) remains(VBZ) done(VBN) objection(NN) admitting(VBG) made(VBN) mistake(NN) whereas(JJ) congress(NN) follows(VBZ) gandhi(VBP) ram(JJ) rajya(NN) walk(VBP) path(IN) justice(NN) believe(VBP) secularism(NN) people(NNS) living(VBG) india(JJ) believe(VBP) different(JJ) religion(NN) believe(VBP) equality(NN) religion(NN) scripture(NN) much(JJ) strength(NN) soil(NN) country(NN) bind(VB) different(JJ) language(NN) faith(NN) crore(NN) people(NNS) integrity(VBP) love(VB) goodwill(NN) therefore(RB) would(MD) also(RB) like(VB) caution(NN) ruling(VBG) party(NN) desist(NN) following(VBG) path(NN) nathuram(RB) allow(JJ) tradition(NN) glorifying(VBG) nathuram(CC) either(DT) hesitation(NN) would(MD) like(VB) say(VB) one(CD) must(MD) refrain(VB) exhibiting(VBG) ego(JJ) one(CD) conduct(NN) ravana(NN) wa(NN) killed(VBD) due(JJ) ego(RB) egoistic(JJ) approach(NN) government(NN) keep(VB) casting(NN) look(NN) rising(VBG) inflation(NN) instability(NN) country(NN) whether(IN) manipur(JJ) ladakh(NN) along(IN) border(NN) china(NN) ego(NN) prevents(NNS) perceiving(VBG) growing(VBG) apprehension(NN) exists(VBZ) society(NN) today(NN) particularly(RB) among(IN) minority(NN) country(NN) come(VBD) existence(JJ) government(NN) came(VBD) power(NN) year(NN) country(NN) emerge(VBP) earth(JJ) january(JJ) ram(NN) lalla(NN) wa(NN) always(RB) u(JJ) wa(NN) u(NN) even(RB) year(NN) ago(IN) u(JJ) even(RB) today(NN) government(NN) power(NN) u(NN) tomorrow(NN) also(RB) ram(JJ) heart(NN) love(NN) goodwill(NN) saying(VBG) jai(NN) shri(NN) ram(NN) bitterness(NN) anger(NN) always(RB) heard(VBD) jai(NN) shri(NN) ram(NN) indian(JJ) national(JJ) congress(NN) party(NN) ha(NN) always(RB) worked(VBD) confer(NN) right(RB) citizen(JJ) india(NNP) spirit(NN) service(NN) inspired(VBD) value(NN) gandhiji(NN) guidance(NN) dr(NN) ambedkar(NN) also(RB) expect(VBP) work(NN) spirit(NN) service(NN) whatever(WDT) time(NN) left(VBD) tenure(JJ) let(NN) remind(VB) country(NN) many(JJ) religion(VBP) many(JJ) scripture(NN) many(JJ) prophet(JJ) scripture(NN) govern ...

# %% [markdown]
# ###NER - Named Entity Recognition

# %%
def ner_tagging(tokens):
    from nltk import pos_tag
    tagged_tokens = pos_tag(tokens)
    named_entities = ne_chunk(tagged_tokens)
    return named_entities

# %%
df['NER_Tagged_Speech'] = df['Preprocessed_Speech'].apply(ner_tagging)

# %%
sentence_index = 2
print("Original Sentence:")
print(df['Preprocessed_Speech'][sentence_index])

print("\nNER Tagged Sentence:")
for chunk in df['NER_Tagged_Speech'][sentence_index]:
    if hasattr(chunk, 'label'):
        print(f"{chunk.label()}: {' '.join(c[0] for c in chunk)}")
# Out:
# Original Sentence:
# ['would', 'like', 'express', 'gratitude', 'giving', 'opportunity', 'participate', 'discussion', 'construction', 'historic', 'shri', 'ram', 'temple', 'consecration', 'shri', 'ramlala', 'name', 'ram', 'unforgettable', 'u', 'every', 'occasion', 'life', 'unveiling', 'idol', 'ramlala', 'construction', 'temple', 'hon', 'prime', 'minister', 'ha', 'historic', 'work', 'request', 'hon', 'prime', 'minister', 'ram', 'mandir', 'wa', 'built', 'ayodhya', 'similarly', 'grand', 'temple', 'also', 'built', 'sitamarhi', 'bihar', 'birthplace', 'maa', 'janaki']
#
# NER Tagged Sentence:

# %%
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category                                    original_speech  \
# 0            Issue  This is a country characterised by devotion. T...
# 1  Call For Action  I would like to speak about Lord  Rama and the...
# 2  Call For Action  I would like to express my gratitude to you  f...
# 3       Appreciate  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4       Appreciate  Unprecedented work has been done during the  1...
#
#                                  Preprocessed_Speech  \
# 0  [country, characterised, devotion, country, co...
# 1  [would, like, speak, lord, rama, importance, e...
# 2  [would, like, express, gratitude, giving, oppo...
# 3  [lord, ram, symbol, dignity, lord, shri, ram, ...
# 4  [unprecedented, work, ha, done, th, lok, sabha...
#
#                                     Tokenized_Speech  \
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, has, been, done, during,...
#
#                                    Lemmatized_Speech  \
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, ha, been, done, during, ...
#
#                                    POS_Tagged_Speech  \
# 0  [(country, NN), (characterised, VBD), (devotio...
# 1  [(would, MD), (like, VB), (speak, NN), (lord, ...
# 2  [(would, MD), (like, VB), (express, JJ), (grat...
# 3  [(lord, NN), (ram, NN), (symbol, NN), (dignity...
# 4  [(unprecedented, JJ), (work, NN), (ha, NN), (d...
#
#                                    NER_Tagged_Speech
# 0  [(country, NN), (characterised, VBD), (devotio...
# 1  [(would, MD), (like, VB), (speak, NN), (lord, ...
# 2  [(would, MD), (like, VB), (express, JJ), (grat...
# 3  [(lord, NN), (ram, NN), (symbol, NN), (dignity...
# 4  [(unprecedented, JJ), (work, NN), (ha, NN), (d...

# %% [markdown]
# ##Sentiment Analysis

# %% [markdown]
# The existing models each support negative, neutral, and positive, represented by 0, 1, 2 respectively.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
df['Sentiment_Speech'] = df['Preprocessed_Speech'].apply(lambda tokens: ' '.join(tokens))

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

def analyze_sentiment_with_score(text):
    sentiment_scores = sid.polarity_scores(text)
    if sentiment_scores['compound'] >= 0.05:
        sentiment_label = 'Positive'
    elif sentiment_scores['compound'] <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    return sentiment_label, sentiment_scores['compound']

# Apply sentiment analysis to each speech and store sentiment scores
df['Sentiment_Label'], df['Sentiment_Score'] = zip(*df['Sentiment_Speech'].apply(analyze_sentiment_with_score))

# %%
df.head()
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category                                    original_speech  \
# 0            Issue  This is a country characterised by devotion. T...
# 1  Call For Action  I would like to speak about Lord  Rama and the...
# 2  Call For Action  I would like to express my gratitude to you  f...
# 3       Appreciate  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4       Appreciate  Unprecedented work has been done during the  1...
#
#                                  Preprocessed_Speech  \
# 0  [country, characterised, devotion, country, co...
# 1  [would, like, speak, lord, rama, importance, e...
# 2  [would, like, express, gratitude, giving, oppo...
# 3  [lord, ram, symbol, dignity, lord, shri, ram, ...
# 4  [unprecedented, work, ha, done, th, lok, sabha...
#
#                                     Tokenized_Speech  \
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, has, been, done, during,...
#
#                                    Lemmatized_Speech  \
# 0  [this, is, a, country, characterised, by, devo...
# 1  [i, would, like, to, speak, about, lord, rama,...
# 2  [i, would, like, to, express, my, gratitude, t...
# 3  [lord, ram, is, a, symbol, of, dignity, lord, ...
# 4  [unprecedented, work, ha, been, done, during, ...
#
#                                     Sentiment_Speech Sentiment  \
# 0  country characterised devotion country country...  Positive
# 1  would like speak lord rama importance eternal ...  Positive
# 2  would like express gratitude giving opportunit...  Positive
# 3  lord ram symbol dignity lord shri ram ideal su...  Positive
# 4  unprecedented work ha done th lok sabha leader...  Positive
#
#   Sentiment_Label  Sentiment_Score
# 0        Positive           0.9917
# 1        Positive           0.9840
# 2        Positive           0.9371
# 3        Positive           0.9813
# 4        Positive           0.7906

# %%
negative_statement = df[df['Sentiment'] == 'Negative']['original_speech'].iloc[0]
positive_statement = df[df['Sentiment'] == 'Positive']['original_speech'].iloc[0]
neutral_statement = df[df['Sentiment'] == 'Neutral']['original_speech'].iloc[0]

print("Negative Statement:")
print(negative_statement)
print("\nPositive Statement:")
print(positive_statement)
print("\nNeutral Statement:")
neutral_statement
# Out:
# Negative Statement:
# This white paper is not a white paper but an  election stunt. This is an attempt to hide all the failures of the government. It is  regrettable that the order for the release of a drug-related criminal in Manipur comes  from the Chief Minister's office. Another report came regarding the Ayushman  Bharat scheme as to what kind of corruption is happening in Ayushman Bharat  today. The audit noted that around 7.5 lakh beneficiaries were registered against the  same mobile number and no verification was done. Claims are being filed in the  name of 90 thousand people who have died. No action is being taken on that. Today  ED has become another arm of BJP. ED's job is to catch the corrupt. But today ED  is their special weapon to suppress democracy and the voice of opposition and how  to include corrupt people in the BJP. Had they allowed ED to work, it would have  caught all the people who have absconded abroad today. There are about 31 people  abroad who owe a debt of Rs 40 thousand crore, but today ED is not  apprehending them. If the Prime Minister is so powerful in the world then why does  he not bring back these people hiding abroad?
#
# Positive Statement:
# This is a country characterised by devotion. This  country is a country of faith. In this country, we bind our diversity with goodwill  and cherish the society with a sense of service. Lord Rama belongs to everyone and  he is with us all the time. When we meet each other, we exchange greetings by saying  'Ram-Ram' in North India or Western India. What is Mahatma Gandhi's definition  of Ram Rajya? Where everyone is happy and no one is sad, this is his definition.  Gandhi ji has also said that his Hindu dharma teaches him to respect all religions,  the secret of Ram Rajya is inherent in this definition. We should ponder whether all  the backward, deprived and minorities are happy, this was the definition of Ram  Rajya by Mahatma Gandhi. But today we are seeing that crimes against Scheduled  Castes and Scheduled Tribes are on the rise. If we compare it with the year gone by,  crime has gone up by around 50 percent in the year 2023. Is this Ram Rajya? Today  the backward classes are demanding a caste census because they see that injustice is  being meted out to them, and caste discrimination is taking place. Sita Mata has also  been referred to in the Ramayana. Sita Mata never let her patience and strength  diminish, but did the Dalit daughter of Unnao, our women wrestlers, have the same  feeling when they were fighting for their rights? It is mentioned in the report of our  own Parliamentary Committee that women belonging to the Scheduled Castes are  being harassed on the basis of caste and gender and they are also sexually exploited.  After this discussion in the Lok Sabha, when all the MPs go to their respective  constituencies, they will see helplessness among the youth. Today, due to this  unemployment, the helpless Indian youth has chosen the path of drugs and crime.  Today, they helplessly arrange some funds and migrate to a foreign country. This is  the reality. We cannot deny this truth. That is why our party has been doing social  service for so many years. We are aware of the truth. We have done a lot, but still a  lot remains to be done. We too have no objection in admitting that we have made  mistakes. Whereas the Congress follows Gandhi's Ram Rajya, we walk on the path  of justice. We believe in secularism. People living in India believe in different  religions and we believe in equality of all religions. Not just scripture, but there is  so much strength in the soil of this country that binds the different languages and  faiths of 140 crore people with integrity, love and goodwill. Therefore, I would also  like to caution the ruling party that it should desist from following the path of  Nathuram. They should not allow the tradition of glorifying Nathuram either. You  should not have any hesitation in this. I would like to say that one must refrain from  exhibiting ego in one’s conduct. Ravana was killed due to his ego. It is the egoistic  approach of the government that keeps it from casting a look on rising inflation and  instability  in the country, whether it is in Manipur, Ladakh or along the border with  China. Your ego prevents you from perceiving the growing apprehension that exists  in society today, particularly among minorities. This country did not come into  existence when this Government came to Power in the year 2014, this country did  not emerge on earth on January 22, 2024. Ram Lalla was always with us. He was  with us even 500 years ago and is with us even today and when your Government is  not in Power he will be with us tomorrow also. Ram is in our hearts. There should  be love and goodwill in saying Jai Shri Ram. But bitterness and anger are always  heard in your Jai Shri Ram, why is it so? The Indian National Congress Party has  always worked to confer rights on the citizens of India in a spirit of service, inspired  by the values of Gandhiji and the guidance of Dr. Ambedkar. We also expect you to  work in a spirit of service in whatever time is left in your tenure. Let me remind you  once agai ...
#
# Neutral Statement:
# "I salute Hon. Prime Minister for conferring  'Bharat Ratna' on farmer leader Chaudhary Charan Singh ji and Shri M.S.  Swaminathan, who made the country self-reliant in the agriculture sector."

# %%
import matplotlib.pyplot as plt
sentiment_counts = df['Sentiment'].value_counts()

plt.bar(sentiment_counts.index, sentiment_counts.values, color=['green', 'red', 'gray'])
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.title('Sentiment Distribution')
plt.show()

# %%
party_sentiment_counts = df.groupby(['Party', 'Sentiment']).size().unstack(fill_value=0)

party_sentiment_counts.plot(kind='bar', stacked=True)
plt.xlabel('Party')
plt.ylabel('Frequency')
plt.title('Sentiment Distribution by Party')
plt.legend(title='Sentiment')
plt.show()

# %%
party_counts = df['Party'].value_counts()
top_10_parties = party_counts.head(10).index
party_sentiment_counts = df[df['Party'].isin(top_10_parties)].groupby(['Party', 'Sentiment']).size().unstack(fill_value=0)

party_sentiment_counts.plot(kind='bar', stacked=True)
plt.xlabel('Party')
plt.ylabel('Frequency')
plt.title('Sentiment Distribution by Top 10 Parties')
plt.legend(title='Sentiment')
plt.show()

# %%
df_observed_parties = df[df['Party'].isin(top_10_parties)]
party_sentiment_counts = df_observed_parties.groupby(['Party', 'Sentiment']).size().unstack(fill_value=0)

party_total_speeches = party_sentiment_counts.sum(axis=1)

party_sentiment_percentage = party_sentiment_counts.div(party_total_speeches, axis=0) * 100
party_sentiment_percentage = party_sentiment_percentage[['Negative', 'Positive', 'Neutral']]

print("Percentage of Negative and Positive Sentiments in Parliamentary Speeches for Observed Parties:")
print(party_sentiment_percentage)
# Out:
# Percentage of Negative and Positive Sentiments in Parliamentary Speeches for Observed Parties:
# Sentiment      Negative   Positive   Neutral
# Party
# BJD           11.666667  85.000000  3.333333
# BJP           13.078471  81.488934  5.432596
# BSP           22.000000  78.000000  0.000000
# Congress      21.111111  76.666667  2.222222
# JDU            7.272727  89.090909  3.636364
# NCP           12.500000  85.000000  2.500000
# Shiv Sena     23.076923  76.923077  0.000000
# TDP            9.090909  90.909091  0.000000
# TMC           35.000000  62.500000  2.500000
# YSR Congress   8.333333  88.333333  3.333333

# %%
party_sentiment_counts = df.groupby(['Category', 'Sentiment']).size().unstack(fill_value=0)

party_sentiment_counts.plot(kind='bar', stacked=True)
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.title('Sentiment Distribution by Party')
plt.legend(title='Sentiment')
plt.show()

# %%
# Plot histograms for each party
fig, axs = plt.subplots(5, 2, figsize=(12, 18))
axs = axs.flatten()
for i, party in enumerate(top_10_parties):
    party_data = df[df['Party'] == party]
    axs[i].hist(party_data['Sentiment_Score'], bins=5, alpha=0.5)
    axs[i].set_title(party)
    axs[i].set_xlabel('Sentiment Score')
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
party_sentiment_distribution = df.groupby('Party')['Sentiment'].value_counts(normalize=True).unstack(fill_value=0)

party_sentiment_distribution.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Party')
plt.ylabel('Proportion of Speeches')
plt.title('Sentiment Distribution in Each Party')
plt.legend(title='Sentiment')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###Key Word Extraction RAKE

# %%
# Initialize RAKE
rake = Rake()

# Function to extract keywords using RAKE
def extract_keywords_rake(text):
    # keywords
    rake.extract_keywords_from_text(text)
    ranked_phrases = rake.get_ranked_phrases_with_scores()

    # top keywords
    keywordList = []
    for keyword in ranked_phrases:
        keyword_updated = keyword[1].split()
        keyword_updated_string = " ".join(keyword_updated[:2])
        keywordList.append(keyword_updated_string)
        if len(keywordList) > 9:
            break

    return keywordList
df['Keywords_RAKE'] = df['Preprocessed_Speech'].apply(lambda x: extract_keywords_rake(' '.join(x)))


# Print the extracted keywords for each speech
for index, row in df.iterrows():
    print(f"Speech {index}:")
    print("Keywords (RAKE):", row['Keywords_RAKE'])
    print()
# Out:
# Speech 0:
# Keywords (RAKE): ['country characterised']
#
# Speech 1:
# Keywords (RAKE): ['would like']
#
# Speech 2:
# Keywords (RAKE): ['would like']
#
# Speech 3:
# Keywords (RAKE): ['lord ram']
#
# Speech 4:
# Keywords (RAKE): ['unprecedented work']
#
# Speech 5:
# Keywords (RAKE): ['fortunate born']
#
# Speech 6:
# Keywords (RAKE): ['happy lord']
#
# Speech 7:
# Keywords (RAKE): ['elected th']
#
# Speech 8:
# Keywords (RAKE): ['elected lok']
#
# Speech 9:
# Keywords (RAKE): ['would like']
#
# Speech 10:
# Keywords (RAKE): ['stand motion']
#
# Speech 11:
# Keywords (RAKE): ['judgement ram']
#
# Speech 12:
# Keywords (RAKE): ['parliament got']
#
# Speech 13:
# Keywords (RAKE): ['thank voter']
#
# Speech 14:
# Keywords (RAKE): ['way everyone']
#
# Speech 15:
# Keywords (RAKE): ['hon speaker']
#
# Speech 16:
# Keywords (RAKE): ['speaking ram']
#
# Speech 17:
# Keywords (RAKE): ['take opportunity']
#
# Speech 18:
# Keywords (RAKE): ['lok sabha']
#
# Speech 19:
# Keywords (RAKE): ['selected member']
#
# Speech 20:
# Keywords (RAKE): ['entered th']
#
# Speech 21:
# Keywords (RAKE): ['salute hon']
#
# Speech 22:
# Keywords (RAKE): ['many thanks']
#
# Speech 23:
# Keywords (RAKE): ['way hon']
#
# Speech 24:
# Keywords (RAKE): ['especially thank']
#
# Speech 25:
# Keywords (RAKE): ['coming close']
#
# Speech 26:
# Keywords (RAKE): ['would like']
#
# Speech 27:
# Keywords (RAKE): ['party opinion']
#
# Speech 28:
# Keywords (RAKE): ['white paper']
#
# Speech 29:
# Keywords (RAKE): ['white paper']
#
# Speech 30:
# Keywords (RAKE): ['white paper']
#
# Speech 31:
# Keywords (RAKE): ['necessary present']
#
# Speech 32:
# Keywords (RAKE): ['average gdp']
#
# Speech 33:
# Keywords (RAKE): ['white paper']
#
# Speech 34:
# Keywords (RAKE): ['odishas longstanding']
#
# Speech 35:
# Keywords (RAKE): ['white paper']
#
# Speech 36:
# Keywords (RAKE): ['white paper']
#
# Speech 37:
# Keywords (RAKE): ['india emerged']
#
# Speech 38:
# Keywords (RAKE): ['year tenure']
#
# Speech 39:
# Keywords (RAKE): ['misfortune country']
#
# Speech 40:
# Keywords (RAKE): ['intent purpose']
#
# Speech 41:
# Keywords (RAKE): ['whenever certain']
#
# Speech 42:
# Keywords (RAKE): ['welcome bill']
#
# Speech 43:
# Keywords (RAKE): ['appreciate bill']
#
# Speech 44:
# Keywords (RAKE): ['house country']
#
# Speech 45:
# Keywords (RAKE): ['bill ha']
#
# Speech 46:
# Keywords (RAKE): ['today water']
#
# Speech 47:
# Keywords (RAKE): ['government bihar']
#
# Speech 48:
# Keywords (RAKE): ['constitutional amendment']
#
# Speech 49:
# Keywords (RAKE): ['seen swachhta']
#
# Speech 50:
# Keywords (RAKE): ['support bill']
#
# Speech 51:
# Keywords (RAKE): ['country ha']
#
# Speech 52:
# Keywords (RAKE): ['water pollution']
#
# Speech 53:
# Keywords (RAKE): ['welcome water']
#
# Speech 54:
# Keywords (RAKE): ['known main']
#
# Speech 55:
# Keywords (RAKE): ['amendment law']
#
# Speech 56:
# Keywords (RAKE): ['important bill']
#
# Speech 57:
# Keywords (RAKE): ['suggest bill']
#
# Speech 58:
# Keywords (RAKE): ['would like']
#
# Speech 59:
# Keywords (RAKE): ['water prevention']
#
# Speech 60:
# Keywords (RAKE): ['rise support']
#
# Speech 61:
# Keywords (RAKE): ['laid statement']
#
# Speech 62:
# Keywords (RAKE): ['laid statement']
#
# Speech 63:
# Keywords (RAKE): ['laid statement']
#
# Speech 64:
# Keywords (RAKE): ['laid statement']
#
# Speech 65:
# Keywords (RAKE): ['budget embodies']
#
# Speech 66:
# Keywords (RAKE): ['laid statement']
#
# Speech 67:
# Keywords (RAKE): ['since government']
#
# Speech 68:
# Keywords (RAKE): ['laid statement']
#
# Speech 69:
# Keywords (RAKE): ['rise speak']
#
# Speech 70:
# Keywords (RAKE): ['laid statement']
#
# Speech 71:
# Keywords (RAKE): ['thank honble']
#
# Speech 72:
# Keywords (RAKE): ['laid statement']
#
# Speech 73:
# Keywords (RAKE): ['laid statement']
#
# Speech 74:
# Keywords (RAKE): ['laid statement']
#
# Speech 75:
# Keywords (RAKE): ['interim budget']
#
# Speech 76:
# Keywords (RAKE): ['prime minister']
#
# Speech 77:
# Keywords (RAKE): ['laid statement']
#
# Speech 78:
# Keywords (RAKE): ['laid statement']
#
# Speech 79:
# Keywords (RAKE): ['honble finance']
#
# Speech 80:
# Keywords (RAKE): ['extensive provision']
#
# Speech 81:
# Keywords (RAKE): ['finance minister']
#
# Speech 82:
# Keywords (RAKE): ['first would']
#
# Speech 83:
# Keywords (RAKE): ['rajya sabha']
#
# Speech 84:
# Keywords (RAKE): ['compliment honble']
#
# Speech 85:
# Keywords (RAKE): ['interim budget']
#
# Speech 86:
# Keywords (RAKE): ['since also']
#
# Speech 87:
# Keywords (RAKE): ['using new']
#
# Speech 88:
# Keywords (RAKE): ['honble prime']
#
# Speech 89:
# Keywords (RAKE): ['step provide']
#
# Speech 90:
# Keywords (RAKE): ['government ha']
#
# Speech 91:
# Keywords (RAKE): ['budget clearly']
#
# Speech 92:
# Keywords (RAKE): ['per caput']
#
# Speech 93:
# Keywords (RAKE): ['good budget']
#
# Speech 94:
# Keywords (RAKE): ['since bifurcation']
#
# Speech 95:
# Keywords (RAKE): ['lot hope']
#
# Speech 96:
# Keywords (RAKE): ['claim lifted']
#
# Speech 97:
# Keywords (RAKE): ['present budget']
#
# Speech 98:
# Keywords (RAKE): ['ha big']
#
# Speech 99:
# Keywords (RAKE): ['would like']
#
# Speech 100:
# Keywords (RAKE): ['government ha']
#
# Speech 101:
# Keywords (RAKE): ['allocating capital']
#
# Speech 102:
# Keywords (RAKE): ['country wa']
#
# Speech 103:
# Keywords (RAKE): ['congratulate government']
#
# Speech 104:
# Keywords (RAKE): ['due allround']
#
# Speech 105:
# Keywords (RAKE): ['due economic']
#
# Speech 106:
# Keywords (RAKE): ['data world']
#
# Speech 107:
# Keywords (RAKE): ['government adamant']
#
# Speech 108:
# Keywords (RAKE): ['nation need']
#
# Speech 109:
# Keywords (RAKE): ['allocation water']
#
# Speech 110:
# Keywords (RAKE): ['support budget']
#
# Speech 111:
# Keywords (RAKE): ['support welcome']
#
# Speech 112:
# Keywords (RAKE): ['budget lay']
#
# Speech 113:
# Keywords (RAKE): ['prime minister']
#
# Speech 114:
# Keywords (RAKE): ['paltry allocation']
#
# Speech 115:
# Keywords (RAKE): ['allround alltouching']
#
# Speech 116:
# Keywords (RAKE): ['interim budget']
#
# Speech 117:
# Keywords (RAKE): ['interim budget']
#
# Speech 118:
# Keywords (RAKE): ['first budget']
#
# Speech 119:
# Keywords (RAKE): ['current government']
#
# Speech 120:
# Keywords (RAKE): ['fully electoral']
#
# Speech 121:
# Keywords (RAKE): ['government leadership']
#
# Speech 122:
# Keywords (RAKE): ['ten year']
#
# Speech 123:
# Keywords (RAKE): ['prime minister']
#
# Speech 124:
# Keywords (RAKE): ['finance minister']
#
# Speech 125:
# Keywords (RAKE): ['welcome interim']
#
# Speech 126:
# Keywords (RAKE): ['basic mantra']
#
# Speech 127:
# Keywords (RAKE): ['rise appreciate']
#
# Speech 128:
# Keywords (RAKE): ['welcome allinclusive']
#
# Speech 129:
# Keywords (RAKE): ['think budget']
#
# Speech 130:
# Keywords (RAKE): ['important problem']
#
# Speech 131:
# Keywords (RAKE): ['member house']
#
# Speech 132:
# Keywords (RAKE): ['welcome support']
#
# Speech 133:
# Keywords (RAKE): ['interim budget']
#
# Speech 134:
# Keywords (RAKE): ['thank honble']
#
# Speech 135:
# Keywords (RAKE): ['government interim']
#
# Speech 136:
# Keywords (RAKE): ['highlight interim']
#
# Speech 137:
# Keywords (RAKE): ['budget ha']
#
# Speech 138:
# Keywords (RAKE): ['want income']
#
# Speech 139:
# Keywords (RAKE): ['discussion respect']
#
# Speech 140:
# Keywords (RAKE): ['muchneeded law']
#
# Speech 141:
# Keywords (RAKE): ['jammu kashmir']
#
# Speech 142:
# Keywords (RAKE): ['stand speak']
#
# Speech 143:
# Keywords (RAKE): ['behalf shiv']
#
# Speech 144:
# Keywords (RAKE): ['support bill']
#
# Speech 145:
# Keywords (RAKE): ['article wa']
#
# Speech 146:
# Keywords (RAKE): ['india probably']
#
# Speech 147:
# Keywords (RAKE): ['work done']
#
# Speech 148:
# Keywords (RAKE): ['bill make']
#
# Speech 149:
# Keywords (RAKE): ['constitution jammu']
#
# Speech 150:
# Keywords (RAKE): ['rise support']
#
# Speech 151:
# Keywords (RAKE): ['behalf party']
#
# Speech 152:
# Keywords (RAKE): ['provision bill']
#
# Speech 153:
# Keywords (RAKE): ['issue question']
#
# Speech 154:
# Keywords (RAKE): ['public examination']
#
# Speech 155:
# Keywords (RAKE): ['public examination']
#
# Speech 156:
# Keywords (RAKE): ['today got']
#
# Speech 157:
# Keywords (RAKE): ['today bill']
#
# Speech 158:
# Keywords (RAKE): ['first foremost']
#
# Speech 159:
# Keywords (RAKE): ['support public']
#
# Speech 160:
# Keywords (RAKE): ['support bill']
#
# Speech 161:
# Keywords (RAKE): ['government finally']
#
# Speech 162:
# Keywords (RAKE): ['request omit']
#
# Speech 163:
# Keywords (RAKE): ['support bill']
#
# Speech 164:
# Keywords (RAKE): ['union territory']
#
# Speech 165:
# Keywords (RAKE): ['government desirous']
#
# Speech 166:
# Keywords (RAKE): ['introduction bill']
#
# Speech 167:
# Keywords (RAKE): ['rise support']
#
# Speech 168:
# Keywords (RAKE): ['union territory']
#
# Speech 169:
# Keywords (RAKE): ['support two']
#
# Speech 170:
# Keywords (RAKE): ['country ha']
#
# Speech 171:
# Keywords (RAKE): ['would like']
#
# Speech 172:
# Keywords (RAKE): ['laid statement']
#
# Speech 173:
# Keywords (RAKE): ['laid statement']
#
# Speech 174:
# Keywords (RAKE): ['laid statement']
#
# Speech 175:
# Keywords (RAKE): ['laid statement']
#
# Speech 176:
# Keywords (RAKE): ['laid statement']
#
# Speech 177:
# Keywords (RAKE): ['laid statement']
#
# Speech 178:
# Keywords (RAKE): ['laid statement']
#
# Speech 179:
# Keywords (RAKE): ['laid statement']
#
# Speech 180:
# Keywords (RAKE): ['country biggest']
#
# Speech 181:
# Keywords (RAKE): ['first time']
#
# Speech 182:
# Keywords (RAKE): ['rise speak']
#
# Speech 183:
# Keywords (RAKE): ['laid statement']
#
# Speech 184:
# Keywords (RAKE): ['laid statement']
#
# Speech 185:
# Keywords (RAKE): ['laid statement']
#
# Speech 186:
# Keywords (RAKE): ['excellency honble']
#
# Speech 187:
# Keywords (RAKE): ['laid statement']
#
# Speech 188:
# Keywords (RAKE): ['laid statement']
#
# Speech 189:
# Keywords (RAKE): ['laid statement']
#
# Speech 190:
# Keywords (RAKE): ['january excellency']
#
# Speech 191:
# Keywords (RAKE): ['great house']
#
# Speech 192:
# Keywords (RAKE): ['first behalf']
#
# Speech 193:
# Keywords (RAKE): ['last decade']
#
# Speech 194:
# Keywords (RAKE): ['augured well']
#
# Speech 195:
# Keywords (RAKE): ['increasing number']
#
# Speech 196:
# Keywords (RAKE): ['nowadays advertisement']
#
# Speech 197:
# Keywords (RAKE): ['life mata']
#
# Speech 198:
# Keywords (RAKE): ['district araria']
#
# Speech 199:
# Keywords (RAKE): ['need provide']
#
# Speech 200:
# Keywords (RAKE): ['present raxaul']
#
# Speech 201:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 202:
# Keywords (RAKE): ['thanks passion']
#
# Speech 203:
# Keywords (RAKE): ['heavy rainfall']
#
# Speech 204:
# Keywords (RAKE): ['poor rail']
#
# Speech 205:
# Keywords (RAKE): ['plan anvil']
#
# Speech 206:
# Keywords (RAKE): ['doping sporting']
#
# Speech 207:
# Keywords (RAKE): ['mnregs fund']
#
# Speech 208:
# Keywords (RAKE): ['annual intake']
#
# Speech 209:
# Keywords (RAKE): ['government andhra']
#
# Speech 210:
# Keywords (RAKE): ['commendable step']
#
# Speech 211:
# Keywords (RAKE): ['ha taken']
#
# Speech 212:
# Keywords (RAKE): ['wa good']
#
# Speech 213:
# Keywords (RAKE): ['said doping']
#
# Speech 214:
# Keywords (RAKE): ['reason bill']
#
# Speech 215:
# Keywords (RAKE): ['behalf party']
#
# Speech 216:
# Keywords (RAKE): ['sportspersons rural']
#
# Speech 217:
# Keywords (RAKE): ['bill indeed']
#
# Speech 218:
# Keywords (RAKE): ['support national']
#
# Speech 219:
# Keywords (RAKE): ['even included']
#
# Speech 220:
# Keywords (RAKE): ['construction work']
#
# Speech 221:
# Keywords (RAKE): ['agneepath scheme']
#
# Speech 222:
# Keywords (RAKE): ['sheohar district']
#
# Speech 223:
# Keywords (RAKE): ['recent year']
#
# Speech 224:
# Keywords (RAKE): ['fourlaning project']
#
# Speech 225:
# Keywords (RAKE): ['crore house']
#
# Speech 226:
# Keywords (RAKE): ['section prevention']
#
# Speech 227:
# Keywords (RAKE): ['jaipur international']
#
# Speech 228:
# Keywords (RAKE): ['east coast']
#
# Speech 229:
# Keywords (RAKE): ['someshwar parbat']
#
# Speech 230:
# Keywords (RAKE): ['dhenkanal one']
#
# Speech 231:
# Keywords (RAKE): ['house discussing']
#
# Speech 232:
# Keywords (RAKE): ['attack shot']
#
# Speech 233:
# Keywords (RAKE): ['proposed amendment']
#
# Speech 234:
# Keywords (RAKE): ['law relating']
#
# Speech 235:
# Keywords (RAKE): ['government must']
#
# Speech 236:
# Keywords (RAKE): ['indian judiciary']
#
# Speech 237:
# Keywords (RAKE): ['small bill']
#
# Speech 238:
# Keywords (RAKE): ['act wa']
#
# Speech 239:
# Keywords (RAKE): ['issue old']
#
# Speech 240:
# Keywords (RAKE): ['today government']
#
# Speech 241:
# Keywords (RAKE): ['family court']
#
# Speech 242:
# Keywords (RAKE): ['separate building']
#
# Speech 243:
# Keywords (RAKE): ['rise speak']
#
# Speech 244:
# Keywords (RAKE): ['family court']
#
# Speech 245:
# Keywords (RAKE): ['support family']
#
# Speech 246:
# Keywords (RAKE): ['main godown']
#
# Speech 247:
# Keywords (RAKE): ['central government']
#
# Speech 248:
# Keywords (RAKE): ['corona period']
#
# Speech 249:
# Keywords (RAKE): ['many people']
#
# Speech 250:
# Keywords (RAKE): ['deplorable situation']
#
# Speech 251:
# Keywords (RAKE): ['present state']
#
# Speech 252:
# Keywords (RAKE): ['one navodaya']
#
# Speech 253:
# Keywords (RAKE): ['union government']
#
# Speech 254:
# Keywords (RAKE): ['gram panchayat']
#
# Speech 255:
# Keywords (RAKE): ['ha severe']
#
# Speech 256:
# Keywords (RAKE): ['east coast']
#
# Speech 257:
# Keywords (RAKE): ['would like']
#
# Speech 258:
# Keywords (RAKE): ['youth lok']
#
# Speech 259:
# Keywords (RAKE): ['would like']
#
# Speech 260:
# Keywords (RAKE): ['glad government']
#
# Speech 261:
# Keywords (RAKE): ['bihtaaurangabad new']
#
# Speech 262:
# Keywords (RAKE): ['biswanath chariali']
#
# Speech 263:
# Keywords (RAKE): ['subject today']
#
# Speech 264:
# Keywords (RAKE): ['government implementing']
#
# Speech 265:
# Keywords (RAKE): ['government ha']
#
# Speech 266:
# Keywords (RAKE): ['agricultural productivity']
#
# Speech 267:
# Keywords (RAKE): ['gruesome murder']
#
# Speech 268:
# Keywords (RAKE): ['nandedbidar railway']
#
# Speech 269:
# Keywords (RAKE): ['country india']
#
# Speech 270:
# Keywords (RAKE): ['would like']
#
# Speech 271:
# Keywords (RAKE): ['ambala famous']
#
# Speech 272:
# Keywords (RAKE): ['present basis']
#
# Speech 273:
# Keywords (RAKE): ['patna district']
#
# Speech 274:
# Keywords (RAKE): ['matter inclusion']
#
# Speech 275:
# Keywords (RAKE): ['present csr']
#
# Speech 276:
# Keywords (RAKE): ['speed national']
#
# Speech 277:
# Keywords (RAKE): ['union government']
#
# Speech 278:
# Keywords (RAKE): ['vasai virar']
#
# Speech 279:
# Keywords (RAKE): ['navodaya vidyalayas']
#
# Speech 280:
# Keywords (RAKE): ['passenger trainslocal']
#
# Speech 281:
# Keywords (RAKE): ['severe electricity']
#
# Speech 282:
# Keywords (RAKE): ['entire gujarat']
#
# Speech 283:
# Keywords (RAKE): ['recorded number']
#
# Speech 284:
# Keywords (RAKE): ['due departmental']
#
# Speech 285:
# Keywords (RAKE): ['work nh']
#
# Speech 286:
# Keywords (RAKE): ['present regular']
#
# Speech 287:
# Keywords (RAKE): ['need convert']
#
# Speech 288:
# Keywords (RAKE): ['article indian']
#
# Speech 289:
# Keywords (RAKE): ['proposal set']
#
# Speech 290:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 291:
# Keywords (RAKE): ['many time']
#
# Speech 292:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 293:
# Keywords (RAKE): ['today crore']
#
# Speech 294:
# Keywords (RAKE): ['provision ha']
#
# Speech 295:
# Keywords (RAKE): ['deoghar ha']
#
# Speech 296:
# Keywords (RAKE): ['water indira']
#
# Speech 297:
# Keywords (RAKE): ['jute industry']
#
# Speech 298:
# Keywords (RAKE): ['paddy farmer']
#
# Speech 299:
# Keywords (RAKE): ['lalitpursingrauli rail']
#
# Speech 300:
# Keywords (RAKE): ['year poshan']
#
# Speech 301:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 302:
# Keywords (RAKE): ['fencing ha']
#
# Speech 303:
# Keywords (RAKE): ['wa enunciated']
#
# Speech 304:
# Keywords (RAKE): ['almost central']
#
# Speech 305:
# Keywords (RAKE): ['west bengal']
#
# Speech 306:
# Keywords (RAKE): ['work widening']
#
# Speech 307:
# Keywords (RAKE): ['bill seek']
#
# Speech 308:
# Keywords (RAKE): ['whole world']
#
# Speech 309:
# Keywords (RAKE): ['belgaum airport']
#
# Speech 310:
# Keywords (RAKE): ['leg support']
#
# Speech 311:
# Keywords (RAKE): ['rise support']
#
# Speech 312:
# Keywords (RAKE): ['stand support']
#
# Speech 313:
# Keywords (RAKE): ['quick point']
#
# Speech 314:
# Keywords (RAKE): ['hon minister']
#
# Speech 315:
# Keywords (RAKE): ['rise support']
#
# Speech 316:
# Keywords (RAKE): ['bill seek']
#
# Speech 317:
# Keywords (RAKE): ['horrendous tragedy']
#
# Speech 318:
# Keywords (RAKE): ['current conflict']
#
# Speech 319:
# Keywords (RAKE): ['trinamool congress']
#
# Speech 320:
# Keywords (RAKE): ['question nonalignment']
#
# Speech 321:
# Keywords (RAKE): ['look humanitarian']
#
# Speech 322:
# Keywords (RAKE): ['first would']
#
# Speech 323:
# Keywords (RAKE): ['permissible invade']
#
# Speech 324:
# Keywords (RAKE): ['judging people']
#
# Speech 325:
# Keywords (RAKE): ['congratulate hon']
#
# Speech 326:
# Keywords (RAKE): ['congratulate government']
#
# Speech 327:
# Keywords (RAKE): ['war anywhere']
#
# Speech 328:
# Keywords (RAKE): ['state government']
#
# Speech 329:
# Keywords (RAKE): ['conflict going']
#
# Speech 330:
# Keywords (RAKE): ['thank chairman']
#
# Speech 331:
# Keywords (RAKE): ['situation ukraine']
#
# Speech 332:
# Keywords (RAKE): ['first would']
#
# Speech 333:
# Keywords (RAKE): ['sir sound']
#
# Speech 334:
# Keywords (RAKE): ['would like']
#
# Speech 335:
# Keywords (RAKE): ['constitution scheduled']
#
# Speech 336:
# Keywords (RAKE): ['honoured participate']
#
# Speech 337:
# Keywords (RAKE): ['support constitution']
#
# Speech 338:
# Keywords (RAKE): ['passing constitution']
#
# Speech 339:
# Keywords (RAKE): ['behalf bahujan']
#
# Speech 340:
# Keywords (RAKE): ['include scheduled']
#
# Speech 341:
# Keywords (RAKE): ['rise speak']
#
# Speech 342:
# Keywords (RAKE): ['would like']
#
# Speech 343:
# Keywords (RAKE): ['important big']
#
# Speech 344:
# Keywords (RAKE): ['extension train']
#
# Speech 345:
# Keywords (RAKE): ['request concerned']
#
# Speech 346:
# Keywords (RAKE): ['request government']
#
# Speech 347:
# Keywords (RAKE): ['rapid urbanization']
#
# Speech 348:
# Keywords (RAKE): ['bhilwara famous']
#
# Speech 349:
# Keywords (RAKE): ['request hon']
#
# Speech 350:
# Keywords (RAKE): ['would like']
#
# Speech 351:
# Keywords (RAKE): ['young athlete']
#
# Speech 352:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 353:
# Keywords (RAKE): ['national health']
#
# Speech 354:
# Keywords (RAKE): ['strong demand']
#
# Speech 355:
# Keywords (RAKE): ['budaga jangam']
#
# Speech 356:
# Keywords (RAKE): ['sincerely request']
#
# Speech 357:
# Keywords (RAKE): ['shifting headquarters']
#
# Speech 358:
# Keywords (RAKE): ['request union']
#
# Speech 359:
# Keywords (RAKE): ['passage bill']
#
# Speech 360:
# Keywords (RAKE): ['feel bill']
#
# Speech 361:
# Keywords (RAKE): ['would like']
#
# Speech 362:
# Keywords (RAKE): ['bill intends']
#
# Speech 363:
# Keywords (RAKE): ['really concern']
#
# Speech 364:
# Keywords (RAKE): ['bill classic']
#
# Speech 365:
# Keywords (RAKE): ['justice stand']
#
# Speech 366:
# Keywords (RAKE): ['objection bill']
#
# Speech 367:
# Keywords (RAKE): ['law commission']
#
# Speech 368:
# Keywords (RAKE): ['read particular']
#
# Speech 369:
# Keywords (RAKE): ['say compete']
#
# Speech 370:
# Keywords (RAKE): ['vehemently oppose']
#
# Speech 371:
# Keywords (RAKE): ['subject inclusion']
#
# Speech 372:
# Keywords (RAKE): ['modern india']
#
# Speech 373:
# Keywords (RAKE): ['scheduled caste']
#
# Speech 374:
# Keywords (RAKE): ['wa aimed']
#
# Speech 375:
# Keywords (RAKE): ['main objective']
#
# Speech 376:
# Keywords (RAKE): ['disagreement object']
#
# Speech 377:
# Keywords (RAKE): ['gond community']
#
# Speech 378:
# Keywords (RAKE): ['gond tribals']
#
# Speech 379:
# Keywords (RAKE): ['per provision']
#
# Speech 380:
# Keywords (RAKE): ['government justice']
#
# Speech 381:
# Keywords (RAKE): ['rise support']
#
# Speech 382:
# Keywords (RAKE): ['leg speak']
#
# Speech 383:
# Keywords (RAKE): ['gond dhuria']
#
# Speech 384:
# Keywords (RAKE): ['would like']
#
# Speech 385:
# Keywords (RAKE): ['government ha']
#
# Speech 386:
# Keywords (RAKE): ['ysrcp party']
#
# Speech 387:
# Keywords (RAKE): ['would like']
#
# Speech 388:
# Keywords (RAKE): ['honble prime']
#
# Speech 389:
# Keywords (RAKE): ['oppose bill']
#
# Speech 390:
# Keywords (RAKE): ['issue discussed']
#
# Speech 391:
# Keywords (RAKE): ['climate change']
#
# Speech 392:
# Keywords (RAKE): ['plant neem']
#
# Speech 393:
# Keywords (RAKE): ['quite serious']
#
# Speech 394:
# Keywords (RAKE): ['today whole']
#
# Speech 395:
# Keywords (RAKE): ['climate change']
#
# Speech 396:
# Keywords (RAKE): ['today step']
#
# Speech 397:
# Keywords (RAKE): ['subject related']
#
# Speech 398:
# Keywords (RAKE): ['would like']
#
# Speech 399:
# Keywords (RAKE): ['r crore']
#
# Speech 400:
# Keywords (RAKE): ['union budget']
#
# Speech 401:
# Keywords (RAKE): ['sport one']
#
# Speech 402:
# Keywords (RAKE): ['would like']
#
# Speech 403:
# Keywords (RAKE): ['heartily grateful']
#
# Speech 404:
# Keywords (RAKE): ['first point']
#
# Speech 405:
# Keywords (RAKE): ['game india']
#
# Speech 406:
# Keywords (RAKE): ['government agency']
#
# Speech 407:
# Keywords (RAKE): ['history sport']
#
# Speech 408:
# Keywords (RAKE): ['sport code']
#
# Speech 409:
# Keywords (RAKE): ['work government']
#
# Speech 410:
# Keywords (RAKE): ['provision municipal']
#
# Speech 411:
# Keywords (RAKE): ['urgency bring']
#
# Speech 412:
# Keywords (RAKE): ['three corporation']
#
# Speech 413:
# Keywords (RAKE): ['division power']
#
# Speech 414:
# Keywords (RAKE): ['municipal corporation']
#
# Speech 415:
# Keywords (RAKE): ['many complaint']
#
# Speech 416:
# Keywords (RAKE): ['bill strengthens']
#
# Speech 417:
# Keywords (RAKE): ['objection decision']
#
# Speech 418:
# Keywords (RAKE): ['think bill']
#
# Speech 419:
# Keywords (RAKE): ['balakrishnan committee']
#
# Speech 420:
# Keywords (RAKE): ['university hospital']
#
# Speech 421:
# Keywords (RAKE): ['rise support']
#
# Speech 422:
# Keywords (RAKE): ['view necessary']
#
# Speech 423:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 424:
# Keywords (RAKE): ['order increase']
#
# Speech 425:
# Keywords (RAKE): ['purpose vaccination']
#
# Speech 426:
# Keywords (RAKE): ['due case']
#
# Speech 427:
# Keywords (RAKE): ['level crossing']
#
# Speech 428:
# Keywords (RAKE): ['extracting edible']
#
# Speech 429:
# Keywords (RAKE): ['covid pandemic']
#
# Speech 430:
# Keywords (RAKE): ['due technical']
#
# Speech 431:
# Keywords (RAKE): ['according article']
#
# Speech 432:
# Keywords (RAKE): ['almost type']
#
# Speech 433:
# Keywords (RAKE): ['per recent']
#
# Speech 434:
# Keywords (RAKE): ['thousand tribals']
#
# Speech 435:
# Keywords (RAKE): ['commission agricultural']
#
# Speech 436:
# Keywords (RAKE): ['due flood']
#
# Speech 437:
# Keywords (RAKE): ['odisha government']
#
# Speech 438:
# Keywords (RAKE): ['million tourist']
#
# Speech 439:
# Keywords (RAKE): ['incidence cancer']
#
# Speech 440:
# Keywords (RAKE): ['institute chartered']
#
# Speech 441:
# Keywords (RAKE): ['would like']
#
# Speech 442:
# Keywords (RAKE): ['several country']
#
# Speech 443:
# Keywords (RAKE): ['per statement']
#
# Speech 444:
# Keywords (RAKE): ['statutory monopoly']
#
# Speech 445:
# Keywords (RAKE): ['appreciate effort']
#
# Speech 446:
# Keywords (RAKE): ['amendment bill']
#
# Speech 447:
# Keywords (RAKE): ['bill aim']
#
# Speech 448:
# Keywords (RAKE): ['bill brought']
#
# Speech 449:
# Keywords (RAKE): ['chartered accountant']
#
# Speech 450:
# Keywords (RAKE): ['rise oppose']
#
# Speech 451:
# Keywords (RAKE): ['three half']
#
# Speech 452:
# Keywords (RAKE): ['would like']
#
# Speech 453:
# Keywords (RAKE): ['formidable problem']
#
# Speech 454:
# Keywords (RAKE): ['many issue']
#
# Speech 455:
# Keywords (RAKE): ['first president']
#
# Speech 456:
# Keywords (RAKE): ['president address']
#
# Speech 457:
# Keywords (RAKE): ['president ha']
#
# Speech 458:
# Keywords (RAKE): ['understand constitution']
#
# Speech 459:
# Keywords (RAKE): ['concrete plan']
#
# Speech 460:
# Keywords (RAKE): ['mention president']
#
# Speech 461:
# Keywords (RAKE): ['government india']
#
# Speech 462:
# Keywords (RAKE): ['would like']
#
# Speech 463:
# Keywords (RAKE): ['support motion']
#
# Speech 464:
# Keywords (RAKE): ['hon president']
#
# Speech 465:
# Keywords (RAKE): ['pandemic around']
#
# Speech 466:
# Keywords (RAKE): ['fought corona']
#
# Speech 467:
# Keywords (RAKE): ['nothing mentioned']
#
# Speech 468:
# Keywords (RAKE): ['support address']
#
# Speech 469:
# Keywords (RAKE): ['first support']
#
# Speech 470:
# Keywords (RAKE): ['countryman motivated']
#
# Speech 471:
# Keywords (RAKE): ['would like']
#
# Speech 472:
# Keywords (RAKE): ['every wing']
#
# Speech 473:
# Keywords (RAKE): ['thank giving']
#
# Speech 474:
# Keywords (RAKE): ['hon speaker']
#
# Speech 475:
# Keywords (RAKE): ['presidential address']
#
# Speech 476:
# Keywords (RAKE): ['presidential address']
#
# Speech 477:
# Keywords (RAKE): ['outline renovation']
#
# Speech 478:
# Keywords (RAKE): ['join honourable']
#
# Speech 479:
# Keywords (RAKE): ['feel presidential']
#
# Speech 480:
# Keywords (RAKE): ['hon president']
#
# Speech 481:
# Keywords (RAKE): ['listening address']
#
# Speech 482:
# Keywords (RAKE): ['take concrete']
#
# Speech 483:
# Keywords (RAKE): ['president address']
#
# Speech 484:
# Keywords (RAKE): ['would like']
#
# Speech 485:
# Keywords (RAKE): ['country facing']
#
# Speech 486:
# Keywords (RAKE): ['express gratitude']
#
# Speech 487:
# Keywords (RAKE): ['oppose introduction']
#
# Speech 488:
# Keywords (RAKE): ['retrogressive amendment']
#
# Speech 489:
# Keywords (RAKE): ['come preparing']
#
# Speech 490:
# Keywords (RAKE): ['government aggressively']
#
# Speech 491:
# Keywords (RAKE): ['important important']
#
# Speech 492:
# Keywords (RAKE): ['good government']
#
# Speech 493:
# Keywords (RAKE): ['bill beyond']
#
# Speech 494:
# Keywords (RAKE): ['stand oppose']
#
# Speech 495:
# Keywords (RAKE): ['believe bill']
#
# Speech 496:
# Keywords (RAKE): ['forgetting aadhaar']
#
# Speech 497:
# Keywords (RAKE): ['government ha']
#
# Speech 498:
# Keywords (RAKE): ['bill whereby']
#
# Speech 499:
# Keywords (RAKE): ['behalf party']
#
# Speech 500:
# Keywords (RAKE): ['bill wa']
#
# Speech 501:
# Keywords (RAKE): ['bill need']
#
# Speech 502:
# Keywords (RAKE): ['behalf biju']
#
# Speech 503:
# Keywords (RAKE): ['support supplementary']
#
# Speech 504:
# Keywords (RAKE): ['economic development']
#
# Speech 505:
# Keywords (RAKE): ['west bengal']
#
# Speech 506:
# Keywords (RAKE): ['guidance hon']
#
# Speech 507:
# Keywords (RAKE): ['support second']
#
# Speech 508:
# Keywords (RAKE): ['extend support']
#
# Speech 509:
# Keywords (RAKE): ['today country']
#
# Speech 510:
# Keywords (RAKE): ['rise speak']
#
# Speech 511:
# Keywords (RAKE): ['tamil nadu']
#
# Speech 512:
# Keywords (RAKE): ['present government']
#
# Speech 513:
# Keywords (RAKE): ['government providing']
#
# Speech 514:
# Keywords (RAKE): ['supplementary demand']
#
# Speech 515:
# Keywords (RAKE): ['agree parliament']
#
# Speech 516:
# Keywords (RAKE): ['rise support']
#
# Speech 517:
# Keywords (RAKE): ['definitely want']
#
# Speech 518:
# Keywords (RAKE): ['hon finance']
#
# Speech 519:
# Keywords (RAKE): ['trend committing']
#
# Speech 520:
# Keywords (RAKE): ['covid pandemic']
#
# Speech 521:
# Keywords (RAKE): ['provision r']
#
# Speech 522:
# Keywords (RAKE): ['would like']
#
# Speech 523:
# Keywords (RAKE): ['crore people']
#
# Speech 524:
# Keywords (RAKE): ['government ha']
#
# Speech 525:
# Keywords (RAKE): ['represent nandurbar']
#
# Speech 526:
# Keywords (RAKE): ['maharashtra ha']
#
# Speech 527:
# Keywords (RAKE): ['key feature']
#
# Speech 528:
# Keywords (RAKE): ['government ha']
#
# Speech 529:
# Keywords (RAKE): ['anything tremendous']
#
# Speech 530:
# Keywords (RAKE): ['rise speak']
#
# Speech 531:
# Keywords (RAKE): ['bill seek']
#
# Speech 532:
# Keywords (RAKE): ['bill represents']
#
# Speech 533:
# Keywords (RAKE): ['bill wa']
#
# Speech 534:
# Keywords (RAKE): ['catena judgment']
#
# Speech 535:
# Keywords (RAKE): ['according study']
#
# Speech 536:
# Keywords (RAKE): ['wa rightly']
#
# Speech 537:
# Keywords (RAKE): ['drug abuse']
#
# Speech 538:
# Keywords (RAKE): ['issue related']
#
# Speech 539:
# Keywords (RAKE): ['rise support']
#
# Speech 540:
# Keywords (RAKE): ['important question']
#
# Speech 541:
# Keywords (RAKE): ['act regulates']
#
# Speech 542:
# Keywords (RAKE): ['main objective']
#
# Speech 543:
# Keywords (RAKE): ['unfortunate today']
#
# Speech 544:
# Keywords (RAKE): ['government ha']
#
# Speech 545:
# Keywords (RAKE): ['support budget']
#
# Speech 546:
# Keywords (RAKE): ['budget anti']
#
# Speech 547:
# Keywords (RAKE): ['government ha']
#
# Speech 548:
# Keywords (RAKE): ['balanced budget']
#
# Speech 549:
# Keywords (RAKE): ['budget presented']
#
# Speech 550:
# Keywords (RAKE): ['welcome budget']
#
# Speech 551:
# Keywords (RAKE): ['india struggle']
#
# Speech 552:
# Keywords (RAKE): ['majority population']
#
# Speech 553:
# Keywords (RAKE): ['wholeheartedly congratulate']
#
# Speech 554:
# Keywords (RAKE): ['government india']
#
# Speech 555:
# Keywords (RAKE): ['would like']
#
# Speech 556:
# Keywords (RAKE): ['budget unique']
#
# Speech 557:
# Keywords (RAKE): ['would like']
#
# Speech 558:
# Keywords (RAKE): ['atmanirbhar bharat']
#
# Speech 559:
# Keywords (RAKE): ['feeling allocation']
#
# Speech 560:
# Keywords (RAKE): ['time pandemic']
#
# Speech 561:
# Keywords (RAKE): ['budget lay']
#
# Speech 562:
# Keywords (RAKE): ['essential relief']
#
# Speech 563:
# Keywords (RAKE): ['foundation new']
#
# Speech 564:
# Keywords (RAKE): ['government ha']
#
# Speech 565:
# Keywords (RAKE): ['today people']
#
# Speech 566:
# Keywords (RAKE): ['prime minister']
#
# Speech 567:
# Keywords (RAKE): ['country heading']
#
# Speech 568:
# Keywords (RAKE): ['india economy']
#
# Speech 569:
# Keywords (RAKE): ['appropriate decision']
#
# Speech 570:
# Keywords (RAKE): ['budget unprecedented']
#
# Speech 571:
# Keywords (RAKE): ['presidential address']
#
# Speech 572:
# Keywords (RAKE): ['today india']
#
# Speech 573:
# Keywords (RAKE): ['last year']
#
# Speech 574:
# Keywords (RAKE): ['government led']
#
# Speech 575:
# Keywords (RAKE): ['hon president']
#
# Speech 576:
# Keywords (RAKE): ['medical fraternity']
#
# Speech 577:
# Keywords (RAKE): ['government ha']
#
# Speech 578:
# Keywords (RAKE): ['president address']
#
# Speech 579:
# Keywords (RAKE): ['today india']
#
# Speech 580:
# Keywords (RAKE): ['government taxing']
#
# Speech 581:
# Keywords (RAKE): ['appreciate attitude']
#
# Speech 582:
# Keywords (RAKE): ['popular budget']
#
# Speech 583:
# Keywords (RAKE): ['present budget']
#
# Speech 584:
# Keywords (RAKE): ['considering situation']
#
# Speech 585:
# Keywords (RAKE): ['happy union']
#
# Speech 586:
# Keywords (RAKE): ['budget ha']
#
# Speech 587:
# Keywords (RAKE): ['budget budget']
#
# Speech 588:
# Keywords (RAKE): ['sir stand']
#
# Speech 589:
# Keywords (RAKE): ['budget make']
#
# Speech 590:
# Keywords (RAKE): ['welcome innovative']
#
# Speech 591:
# Keywords (RAKE): ['every important']
#
# Speech 592:
# Keywords (RAKE): ['atmanirbhar bharat']
#
# Speech 593:
# Keywords (RAKE): ['budget fully']
#
# Speech 594:
# Keywords (RAKE): ['budget ha']
#
# Speech 595:
# Keywords (RAKE): ['farmer food']
#
# Speech 596:
# Keywords (RAKE): ['budget ha']
#
# Speech 597:
# Keywords (RAKE): ['government would']
#
# Speech 598:
# Keywords (RAKE): ['year hon']
#
# Speech 599:
# Keywords (RAKE): ['president address']
#
# Speech 600:
# Keywords (RAKE): ['today corona']
#
# Speech 601:
# Keywords (RAKE): ['would like']
#
# Speech 602:
# Keywords (RAKE): ['government ha']
#
# Speech 603:
# Keywords (RAKE): ['sir rise']
#
# Speech 604:
# Keywords (RAKE): ['time worldwide']
#
# Speech 605:
# Keywords (RAKE): ['address hon']
#
# Speech 606:
# Keywords (RAKE): ['issue raised']
#
# Speech 607:
# Keywords (RAKE): ['would like']
#
# Speech 608:
# Keywords (RAKE): ['india practice']
#
# Speech 609:
# Keywords (RAKE): ['country developing']
#
# Speech 610:
# Keywords (RAKE): ['hon president']
#
# Speech 611:
# Keywords (RAKE): ['supporting motion']
#
# Speech 612:
# Keywords (RAKE): ['sincerely support']
#
# Speech 613:
# Keywords (RAKE): ['presidential address']
#
# Speech 614:
# Keywords (RAKE): ['today country']
#
# Speech 615:
# Keywords (RAKE): ['living together']
#
# Speech 616:
# Keywords (RAKE): ['rise thank']
#
# Speech 617:
# Keywords (RAKE): ['hon president']
#
# Speech 618:
# Keywords (RAKE): ['government ha']
#
# Speech 619:
# Keywords (RAKE): ['support peaceful']
#
# Speech 620:
# Keywords (RAKE): ['highly developed']
#
# Speech 621:
# Keywords (RAKE): ['pained note']
#
# Speech 622:
# Keywords (RAKE): ['government provided']
#
# Speech 623:
# Keywords (RAKE): ['wholeheartedly support']
#
# Speech 624:
# Keywords (RAKE): ['following mantra']
#
# Speech 625:
# Keywords (RAKE): ['year ha']
#
# Speech 626:
# Keywords (RAKE): ['almost last']
#
# Speech 627:
# Keywords (RAKE): ['congress party']
#
# Speech 628:
# Keywords (RAKE): ['address excellency']
#
# Speech 629:
# Keywords (RAKE): ['thank hon']
#
# Speech 630:
# Keywords (RAKE): ['mention frontline']
#
# Speech 631:
# Keywords (RAKE): ['manufacturing earlier']
#
# Speech 632:
# Keywords (RAKE): ['scripture attach']
#
# Speech 633:
# Keywords (RAKE): ['pay tribute']
#
# Speech 634:
# Keywords (RAKE): ['claim government']
#
# Speech 635:
# Keywords (RAKE): ['china expanding']
#
# Speech 636:
# Keywords (RAKE): ['appreciate initiative']
#
# Speech 637:
# Keywords (RAKE): ['government trying']
#
# Speech 638:
# Keywords (RAKE): ['would like']
#
# Speech 639:
# Keywords (RAKE): ['farmer agitation']
#
# Speech 640:
# Keywords (RAKE): ['mp parliament']
#
# Speech 641:
# Keywords (RAKE): ['would like']
#
# Speech 642:
# Keywords (RAKE): ['government inherited']
#
# Speech 643:
# Keywords (RAKE): ['hon president']
#
# Speech 644:
# Keywords (RAKE): ['samajvadi party']
#
# Speech 645:
# Keywords (RAKE): ['hon president']
#
# Speech 646:
# Keywords (RAKE): ['started world']
#
# Speech 647:
# Keywords (RAKE): ['happy central']
#
# Speech 648:
# Keywords (RAKE): ['history punjab']
#
# Speech 649:
# Keywords (RAKE): ['government led']
#
# Speech 650:
# Keywords (RAKE): ['instead keeping']
#
# Speech 651:
# Keywords (RAKE): ['important issue']
#
# Speech 652:
# Keywords (RAKE): ['brahmaputra lifeline']
#
# Speech 653:
# Keywords (RAKE): ['ha passed']
#
# Speech 654:
# Keywords (RAKE): ['child farmer']
#
# Speech 655:
# Keywords (RAKE): ['rise oppose']
#
# Speech 656:
# Keywords (RAKE): ['rise speak']
#
# Speech 657:
# Keywords (RAKE): ['first would']
#
# Speech 658:
# Keywords (RAKE): ['covid vaccination']
#
# Speech 659:
# Keywords (RAKE): ['president address']
#
# Speech 660:
# Keywords (RAKE): ['president address']
#
# Speech 661:
# Keywords (RAKE): ['poverty alleviation']
#
# Speech 662:
# Keywords (RAKE): ['pandemic country']
#
# Speech 663:
# Keywords (RAKE): ['address president']
#
# Speech 664:
# Keywords (RAKE): ['last nine']
#
# Speech 665:
# Keywords (RAKE): ['first point']
#
# Speech 666:
# Keywords (RAKE): ['agitation agricultural']
#
# Speech 667:
# Keywords (RAKE): ['session began']
#
# Speech 668:
# Keywords (RAKE): ['president address']
#
# Speech 669:
# Keywords (RAKE): ['time india']
#
# Speech 670:
# Keywords (RAKE): ['successful effort']
#
# Speech 671:
# Keywords (RAKE): ['performance review']
#
# Speech 672:
# Keywords (RAKE): ['india ha']
#
# Speech 673:
# Keywords (RAKE): ['support motion']
#
# Speech 674:
# Keywords (RAKE): ['hon speaker']
#
# Speech 675:
# Keywords (RAKE): ['corona crore']
#
# Speech 676:
# Keywords (RAKE): ['regarding farmer']
#
# Speech 677:
# Keywords (RAKE): ['last quarter']
#
# Speech 678:
# Keywords (RAKE): ['government brought']
#
# Speech 679:
# Keywords (RAKE): ['hon president']
#
# Speech 680:
# Keywords (RAKE): ['discussing major']
#
# Speech 681:
# Keywords (RAKE): ['outset would']
#
# Speech 682:
# Keywords (RAKE): ['ha observed']
#
# Speech 683:
# Keywords (RAKE): ['people duped']
#
# Speech 684:
# Keywords (RAKE): ['ha long']
#
# Speech 685:
# Keywords (RAKE): ['ha found']
#
# Speech 686:
# Keywords (RAKE): ['taking advantage']
#
# Speech 687:
# Keywords (RAKE): ['india probably']
#
# Speech 688:
# Keywords (RAKE): ['today want']
#
# Speech 689:
# Keywords (RAKE): ['registered chit']
#
# Speech 690:
# Keywords (RAKE): ['chit fund']
#
# Speech 691:
# Keywords (RAKE): ['would like']
#
# Speech 692:
# Keywords (RAKE): ['abolition article']
#
# Speech 693:
# Keywords (RAKE): ['clearly mentioned']
#
# Speech 694:
# Keywords (RAKE): ['unequivocally stand']
#
# Speech 695:
# Keywords (RAKE): ['party support']
#
# Speech 696:
# Keywords (RAKE): ['historic bill']
#
# Speech 697:
# Keywords (RAKE): ['believe removal']
#
# Speech 698:
# Keywords (RAKE): ['government must']
#
# Speech 699:
# Keywords (RAKE): ['rise oppose']
#
# Speech 700:
# Keywords (RAKE): ['historic day']
#
# Speech 701:
# Keywords (RAKE): ['government ha']
#
# Speech 702:
# Keywords (RAKE): ['parliamentary affair']
#
# Speech 703:
# Keywords (RAKE): ['rise support']
#
# Speech 704:
# Keywords (RAKE): ['stand support']
#
# Speech 705:
# Keywords (RAKE): ['rise support']
#
# Speech 706:
# Keywords (RAKE): ['people went']
#
# Speech 707:
# Keywords (RAKE): ['bjp ha']
#
# Speech 708:
# Keywords (RAKE): ['feel get']
#
# Speech 709:
# Keywords (RAKE): ['ha clearly']
#
# Speech 710:
# Keywords (RAKE): ['today celebrate']
#
# Speech 711:
# Keywords (RAKE): ['rise support']
#
# Speech 712:
# Keywords (RAKE): ['supreme court']
#
# Speech 713:
# Keywords (RAKE): ['type bill']
#
# Speech 714:
# Keywords (RAKE): ['bill pave']
#
# Speech 715:
# Keywords (RAKE): ['rise support']
#
# Speech 716:
# Keywords (RAKE): ['would like']
#
# Speech 717:
# Keywords (RAKE): ['supporting bill']
#
# Speech 718:
# Keywords (RAKE): ['even today']
#
# Speech 719:
# Keywords (RAKE): ['rise support']
#
# Speech 720:
# Keywords (RAKE): ['two type']
#
# Speech 721:
# Keywords (RAKE): ['matter immense']
#
# Speech 722:
# Keywords (RAKE): ['commendable hon']
#
# Speech 723:
# Keywords (RAKE): ['transgender community']
#
# Speech 724:
# Keywords (RAKE): ['discriminated people']
#
# Speech 725:
# Keywords (RAKE): ['bill introduced']
#
# Speech 726:
# Keywords (RAKE): ['important bill']
#
# Speech 727:
# Keywords (RAKE): ['applaud government']
#
# Speech 728:
# Keywords (RAKE): ['want minister']
#
# Speech 729:
# Keywords (RAKE): ['would like']
#
# Speech 730:
# Keywords (RAKE): ['surrogacy sacrifice']
#
# Speech 731:
# Keywords (RAKE): ['intended purpose']
#
# Speech 732:
# Keywords (RAKE): ['today india']
#
# Speech 733:
# Keywords (RAKE): ['surrogacy viable']
#
# Speech 734:
# Keywords (RAKE): ['would like']
#
# Speech 735:
# Keywords (RAKE): ['present bill']
#
# Speech 736:
# Keywords (RAKE): ['bill aim']
#
# Speech 737:
# Keywords (RAKE): ['support bill']
#
# Speech 738:
# Keywords (RAKE): ['undoubtedly increasing']
#
# Speech 739:
# Keywords (RAKE): ['house aware']
#
# Speech 740:
# Keywords (RAKE): ['bill important']
#
# Speech 741:
# Keywords (RAKE): ['far increasing']
#
# Speech 742:
# Keywords (RAKE): ['support supreme']
#
# Speech 743:
# Keywords (RAKE): ['remember history']
#
# Speech 744:
# Keywords (RAKE): ['though present']
#
# Speech 745:
# Keywords (RAKE): ['jallianwala bagh']
#
# Speech 746:
# Keywords (RAKE): ['remember discussion']
#
# Speech 747:
# Keywords (RAKE): ['rise support']
#
# Speech 748:
# Keywords (RAKE): ['important bill']
#
# Speech 749:
# Keywords (RAKE): ['would say']
#
# Speech 750:
# Keywords (RAKE): ['government saying']
#
# Speech 751:
# Keywords (RAKE): ['firstly let']
#
# Speech 752:
# Keywords (RAKE): ['jallianwala bagh']
#
# Speech 753:
# Keywords (RAKE): ['rise support']
#
# Speech 754:
# Keywords (RAKE): ['bill aim']
#
# Speech 755:
# Keywords (RAKE): ['congress wa']
#
# Speech 756:
# Keywords (RAKE): ['hundred year']
#
# Speech 757:
# Keywords (RAKE): ['parliament ha']
#
# Speech 758:
# Keywords (RAKE): ['water resource']
#
# Speech 759:
# Keywords (RAKE): ['bill aim']
#
# Speech 760:
# Keywords (RAKE): ['several accident']
#
# Speech 761:
# Keywords (RAKE): ['large dam']
#
# Speech 762:
# Keywords (RAKE): ['gone bill']
#
# Speech 763:
# Keywords (RAKE): ['would like']
#
# Speech 764:
# Keywords (RAKE): ['dam safety']
#
# Speech 765:
# Keywords (RAKE): ['actually think']
#
# Speech 766:
# Keywords (RAKE): ['today discussing']
#
# Speech 767:
# Keywords (RAKE): ['would like']
#
# Speech 768:
# Keywords (RAKE): ['would like']
#
# Speech 769:
# Keywords (RAKE): ['important bill']
#
# Speech 770:
# Keywords (RAKE): ['first time']
#
# Speech 771:
# Keywords (RAKE): ['dam safety']
#
# Speech 772:
# Keywords (RAKE): ['would like']
#
# Speech 773:
# Keywords (RAKE): ['want double']
#
# Speech 774:
# Keywords (RAKE): ['hon prime']
#
# Speech 775:
# Keywords (RAKE): ['parliamentary constituency']
#
# Speech 776:
# Keywords (RAKE): ['would like']
#
# Speech 777:
# Keywords (RAKE): ['providing water']
#
# Speech 778:
# Keywords (RAKE): ['small amendment']
#
# Speech 779:
# Keywords (RAKE): ['per bill']
#
# Speech 780:
# Keywords (RAKE): ['state odisha']
#
# Speech 781:
# Keywords (RAKE): ['air travel']
#
# Speech 782:
# Keywords (RAKE): ['insolvency bankruptcy']
#
# Speech 783:
# Keywords (RAKE): ['none u']
#
# Speech 784:
# Keywords (RAKE): ['respect arbitration']
#
# Speech 785:
# Keywords (RAKE): ['bill priority']
#
# Speech 786:
# Keywords (RAKE): ['bill really']
#
# Speech 787:
# Keywords (RAKE): ['fastest growing']
#
# Speech 788:
# Keywords (RAKE): ['support bill']
#
# Speech 789:
# Keywords (RAKE): ['arbitration act']
#
# Speech 790:
# Keywords (RAKE): ['government ha']
#
# Speech 791:
# Keywords (RAKE): ['name legislation']
#
# Speech 792:
# Keywords (RAKE): ['primarily act']
#
# Speech 793:
# Keywords (RAKE): ['child viewed']
#
# Speech 794:
# Keywords (RAKE): ['risen support']
#
# Speech 795:
# Keywords (RAKE): ['amendment bill']
#
# Speech 796:
# Keywords (RAKE): ['sexual violence']
#
# Speech 797:
# Keywords (RAKE): ['rise support']
#
# Speech 798:
# Keywords (RAKE): ['would like']
#
# Speech 799:
# Keywords (RAKE): ['first would']
#
# Speech 800:
# Keywords (RAKE): ['important aspect']
#
# Speech 801:
# Keywords (RAKE): ['stringency punishment']
#
# Speech 802:
# Keywords (RAKE): ['pocso need']
#
# Speech 803:
# Keywords (RAKE): ['demand bill']
#
# Speech 804:
# Keywords (RAKE): ['support bill']
#
# Speech 805:
# Keywords (RAKE): ['support pocso']
#
# Speech 806:
# Keywords (RAKE): ['would like']
#
# Speech 807:
# Keywords (RAKE): ['view number']
#
# Speech 808:
# Keywords (RAKE): ['government ha']
#
# Speech 809:
# Keywords (RAKE): ['chairman arbitration']
#
# Speech 810:
# Keywords (RAKE): ['arbitration conciliation']
#
# Speech 811:
# Keywords (RAKE): ['different type']
#
# Speech 812:
# Keywords (RAKE): ['rise support']
#
# Speech 813:
# Keywords (RAKE): ['dispute relating']
#
# Speech 814:
# Keywords (RAKE): ['would like']
#
# Speech 815:
# Keywords (RAKE): ['prima facie']
#
# Speech 816:
# Keywords (RAKE): ['various state']
#
# Speech 817:
# Keywords (RAKE): ['first time']
#
# Speech 818:
# Keywords (RAKE): ['generally dispute']
#
# Speech 819:
# Keywords (RAKE): ['people selling']
#
# Speech 820:
# Keywords (RAKE): ['rise support']
#
# Speech 821:
# Keywords (RAKE): ['bill wa']
#
# Speech 822:
# Keywords (RAKE): ['rapid development']
#
# Speech 823:
# Keywords (RAKE): ['mp agree']
#
# Speech 824:
# Keywords (RAKE): ['bill important']
#
# Speech 825:
# Keywords (RAKE): ['rise support']
#
# Speech 826:
# Keywords (RAKE): ['vidharbha one']
#
# Speech 827:
# Keywords (RAKE): ['support important']
#
# Speech 828:
# Keywords (RAKE): ['bill common']
#
# Speech 829:
# Keywords (RAKE): ['almost house']
#
# Speech 830:
# Keywords (RAKE): ['fact case']
#
# Speech 831:
# Keywords (RAKE): ['bill definitely']
#
# Speech 832:
# Keywords (RAKE): ['public property']
#
# Speech 833:
# Keywords (RAKE): ['unauthorized occupant']
#
# Speech 834:
# Keywords (RAKE): ['support bill']
#
# Speech 835:
# Keywords (RAKE): ['concerned delhi']
#
# Speech 836:
# Keywords (RAKE): ['law wa']
#
# Speech 837:
# Keywords (RAKE): ['government bringing']
#
# Speech 838:
# Keywords (RAKE): ['bill made']
#
# Speech 839:
# Keywords (RAKE): ['request government']
#
# Speech 840:
# Keywords (RAKE): ['bill important']
#
# Speech 841:
# Keywords (RAKE): ['rise support']
#
# Speech 842:
# Keywords (RAKE): ['rise support']
#
# Speech 843:
# Keywords (RAKE): ['consumer protection']
#
# Speech 844:
# Keywords (RAKE): ['bill proposes']
#
# Speech 845:
# Keywords (RAKE): ['rise support']
#
# Speech 846:
# Keywords (RAKE): ['code going']
#
# Speech 847:
# Keywords (RAKE): ['government really']
#
# Speech 848:
# Keywords (RAKE): ['genuinely bill']
#
# Speech 849:
# Keywords (RAKE): ['would definitely']
#
# Speech 850:
# Keywords (RAKE): ['oppose bill']
#
# Speech 851:
# Keywords (RAKE): ['bill provides']
#
# Speech 852:
# Keywords (RAKE): ['given pendency']
#
# Speech 853:
# Keywords (RAKE): ['old consumer']
#
# Speech 854:
# Keywords (RAKE): ['second national']
#
# Speech 855:
# Keywords (RAKE): ['behalf party']
#
# Speech 856:
# Keywords (RAKE): ['amalgamation four']
#
# Speech 857:
# Keywords (RAKE): ['would like']
#
# Speech 858:
# Keywords (RAKE): ['bill ha']
#
# Speech 859:
# Keywords (RAKE): ['single alarming']
#
# Speech 860:
# Keywords (RAKE): ['mechanism fixing']
#
# Speech 861:
# Keywords (RAKE): ['congratulate hon']
#
# Speech 862:
# Keywords (RAKE): ['government ha']
#
# Speech 863:
# Keywords (RAKE): ['matter ha']
#
# Speech 864:
# Keywords (RAKE): ['four objection']
#
# Speech 865:
# Keywords (RAKE): ['stand oppose']
#
# Speech 866:
# Keywords (RAKE): ['also harbour']
#
# Speech 867:
# Keywords (RAKE): ['first would']
#
# Speech 868:
# Keywords (RAKE): ['year wa']
#
# Speech 869:
# Keywords (RAKE): ['oppose national']
#
# Speech 870:
# Keywords (RAKE): ['need increase']
#
# Speech 871:
# Keywords (RAKE): ['important bill']
#
# Speech 872:
# Keywords (RAKE): ['first objection']
#
# Speech 873:
# Keywords (RAKE): ['first time']
#
# Speech 874:
# Keywords (RAKE): ['would like']
#
# Speech 875:
# Keywords (RAKE): ['bill doe']
#
# Speech 876:
# Keywords (RAKE): ['medical council']
#
# Speech 877:
# Keywords (RAKE): ['bill important']
#
# Speech 878:
# Keywords (RAKE): ['mci member']
#
# Speech 879:
# Keywords (RAKE): ['last year']
#
# Speech 880:
# Keywords (RAKE): ['bill seek']
#
# Speech 881:
# Keywords (RAKE): ['student get']
#
# Speech 882:
# Keywords (RAKE): ['bill snatching']
#
# Speech 883:
# Keywords (RAKE): ['appreciate bill']
#
# Speech 884:
# Keywords (RAKE): ['go bill']
#
# Speech 885:
# Keywords (RAKE): ['take strong']
#
# Speech 886:
# Keywords (RAKE): ['amendment proposed']
#
# Speech 887:
# Keywords (RAKE): ['company act']
#
# Speech 888:
# Keywords (RAKE): ['government claim']
#
# Speech 889:
# Keywords (RAKE): ['would like']
#
# Speech 890:
# Keywords (RAKE): ['would like']
#
# Speech 891:
# Keywords (RAKE): ['request hon']
#
# Speech 892:
# Keywords (RAKE): ['bill provides']
#
# Speech 893:
# Keywords (RAKE): ['compulsory voting']
#
# Speech 894:
# Keywords (RAKE): ['voting foundation']
#
# Speech 895:
# Keywords (RAKE): ['term voting']
#
# Speech 896:
# Keywords (RAKE): ['conduct member']
#
# Speech 897:
# Keywords (RAKE): ['election country']
#
# Speech 898:
# Keywords (RAKE): ['water state']
#
# Speech 899:
# Keywords (RAKE): ['strongly oppose']
#
# Speech 900:
# Keywords (RAKE): ['thinking religious']
#
# Speech 901:
# Keywords (RAKE): ['rise oppose']
#
# Speech 902:
# Keywords (RAKE): ['rise express']
#
# Speech 903:
# Keywords (RAKE): ['first want']
#
# Speech 904:
# Keywords (RAKE): ['history created']
#
# Speech 905:
# Keywords (RAKE): ['government ha']
#
# Speech 906:
# Keywords (RAKE): ['muslim woman']
#
# Speech 907:
# Keywords (RAKE): ['supreme court']
#
# Speech 908:
# Keywords (RAKE): ['instant triple']
#
# Speech 909:
# Keywords (RAKE): ['oppose bill']
#
# Speech 910:
# Keywords (RAKE): ['marriage sacred']
#
# Speech 911:
# Keywords (RAKE): ['shayara bano']
#
# Speech 912:
# Keywords (RAKE): ['think u']
#
# Speech 913:
# Keywords (RAKE): ['constitution india']
#
# Speech 914:
# Keywords (RAKE): ['bill offends']
#
# Speech 915:
# Keywords (RAKE): ['islam doe']
#
# Speech 916:
# Keywords (RAKE): ['historic moment']
#
# Speech 917:
# Keywords (RAKE): ['need take']
#
# Speech 918:
# Keywords (RAKE): ['party wholeheartedly']
#
# Speech 919:
# Keywords (RAKE): ['chit fund']
#
# Speech 920:
# Keywords (RAKE): ['stand today']
#
# Speech 921:
# Keywords (RAKE): ['stand oppose']
#
# Speech 922:
# Keywords (RAKE): ['must take']
#
# Speech 923:
# Keywords (RAKE): ['though making']
#
# Speech 924:
# Keywords (RAKE): ['stand oppose']
#
# Speech 925:
# Keywords (RAKE): ['strongly oppose']
#
# Speech 926:
# Keywords (RAKE): ['rise support']
#
# Speech 927:
# Keywords (RAKE): ['support bill']
#
# Speech 928:
# Keywords (RAKE): ['several hon']
#
# Speech 929:
# Keywords (RAKE): ['outset would']
#
# Speech 930:
# Keywords (RAKE): ['law said']
#
# Speech 931:
# Keywords (RAKE): ['chit fund']
#
# Speech 932:
# Keywords (RAKE): ['would like']
#
# Speech 933:
# Keywords (RAKE): ['nonbanking finance']
#
# Speech 934:
# Keywords (RAKE): ['way chit']
#
# Speech 935:
# Keywords (RAKE): ['many regulation']
#
# Speech 936:
# Keywords (RAKE): ['depositing banned']
#
# Speech 937:
# Keywords (RAKE): ['directly indirectly']
#
# Speech 938:
# Keywords (RAKE): ['today government']
#
# Speech 939:
# Keywords (RAKE): ['rise speak']
#
# Speech 940:
# Keywords (RAKE): ['number issue']
#
# Speech 941:
# Keywords (RAKE): ['support amendment']
#
# Speech 942:
# Keywords (RAKE): ['government ha']
#
# Speech 943:
# Keywords (RAKE): ['although hon']
#
# Speech 944:
# Keywords (RAKE): ['bill provides']
#
# Speech 945:
# Keywords (RAKE): ['view increasing']
#
# Speech 946:
# Keywords (RAKE): ['trs party']
#
# Speech 947:
# Keywords (RAKE): ['hopeful optimistic']
#
# Speech 948:
# Keywords (RAKE): ['rise support']
#
# Speech 949:
# Keywords (RAKE): ['transport sector']
#
# Speech 950:
# Keywords (RAKE): ['unfortunate lakh']
#
# Speech 951:
# Keywords (RAKE): ['rise speak']
#
# Speech 952:
# Keywords (RAKE): ['first time']
#
# Speech 953:
# Keywords (RAKE): ['amendment bill']
#
# Speech 954:
# Keywords (RAKE): ['hon minister']
#
# Speech 955:
# Keywords (RAKE): ['hon minister']
#
# Speech 956:
# Keywords (RAKE): ['stand oppose']
#
# Speech 957:
# Keywords (RAKE): ['rajasthan desert']
#
# Speech 958:
# Keywords (RAKE): ['depleting water']
#
# Speech 959:
# Keywords (RAKE): ['due scarcity']
#
# Speech 960:
# Keywords (RAKE): ['behalf congress']
#
# Speech 961:
# Keywords (RAKE): ['welcome chair']
#
# Speech 962:
# Keywords (RAKE): ['glad one']
#
# Speech 963:
# Keywords (RAKE): ['ha politics']
#
# Speech 964:
# Keywords (RAKE): ['glad ha']
#
# Speech 965:
# Keywords (RAKE): ['behalf party']
#
# Speech 966:
# Keywords (RAKE): ['today give']
#
# Speech 967:
# Keywords (RAKE): ['hon speaker']
#
# Speech 968:
# Keywords (RAKE): ['take opportunity']
#
# Speech 969:
# Keywords (RAKE): ['behalf party']
#
# Speech 970:
# Keywords (RAKE): ['behalf party']
#
# Speech 971:
# Keywords (RAKE): ['first place']
#
# Speech 972:
# Keywords (RAKE): ['congratulate assuming']
#
# Speech 973:
# Keywords (RAKE): ['behalf people']
#
# Speech 974:
# Keywords (RAKE): ['behalf rlp']
#
# Speech 975:
# Keywords (RAKE): ['associate motion']
#
# Speech 976:
# Keywords (RAKE): ['take opportunity']
#
# Speech 977:
# Keywords (RAKE): ['behalf people']
#
# Speech 978:
# Keywords (RAKE): ['hon member']
#
# Speech 979:
# Keywords (RAKE): ['crore small']
#
# Speech 980:
# Keywords (RAKE): ['whenever sit']
#
# Speech 981:
# Keywords (RAKE): ['people suddenly']
#
# Speech 982:
# Keywords (RAKE): ['odisha still']
#
# Speech 983:
# Keywords (RAKE): ['behalf party']
#
# Speech 984:
# Keywords (RAKE): ['favour bill']
#
# Speech 985:
# Keywords (RAKE): ['came august']
#
# Speech 986:
# Keywords (RAKE): ['hon speaker']
#
# Speech 987:
# Keywords (RAKE): ['favour bill']
#
# Speech 988:
# Keywords (RAKE): ['bill aimed']
#
# Speech 989:
# Keywords (RAKE): ['th birth']
#
# Speech 990:
# Keywords (RAKE): ['bill ha']
#
# Speech 991:
# Keywords (RAKE): ['grateful honble']
#
# Speech 992:
# Keywords (RAKE): ['rise express']
#
# Speech 993:
# Keywords (RAKE): ['difficult task']
#
# Speech 994:
# Keywords (RAKE): ['parliament great']
#
# Speech 995:
# Keywords (RAKE): ['last five']
#
# Speech 996:
# Keywords (RAKE): ['reservation economic']
#
# Speech 997:
# Keywords (RAKE): ['take pride']
#
# Speech 998:
# Keywords (RAKE): ['allocating budget']
#
# Speech 999:
# Keywords (RAKE): ['congratulate hon']
#
# Speech 1000:
# Keywords (RAKE): ['population country']
#
# Speech 1001:
# Keywords (RAKE): ['present government']
#
# Speech 1002:
# Keywords (RAKE): ['unemployment biggest']
#
# Speech 1003:
# Keywords (RAKE): ['budget government']
#
# Speech 1004:
# Keywords (RAKE): ['budget government']
#
# Speech 1005:
# Keywords (RAKE): ['last budget']
#
# Speech 1006:
# Keywords (RAKE): ['budget going']
#
# Speech 1007:
# Keywords (RAKE): ['government moving']
#
# Speech 1008:
# Keywords (RAKE): ['thankful given']
#
# Speech 1009:
# Keywords (RAKE): ['budget shall']
#
# Speech 1010:
# Keywords (RAKE): ['government ha']
#
# Speech 1011:
# Keywords (RAKE): ['commendable budget']
#
# Speech 1012:
# Keywords (RAKE): ['budget contribute']
#
# Speech 1013:
# Keywords (RAKE): ['welcome interim']
#
# Speech 1014:
# Keywords (RAKE): ['mention future']
#
# Speech 1015:
# Keywords (RAKE): ['would like']
#
# Speech 1016:
# Keywords (RAKE): ['government leadership']
#
# Speech 1017:
# Keywords (RAKE): ['progressive budget']
#
# Speech 1018:
# Keywords (RAKE): ['government formed']
#
# Speech 1019:
# Keywords (RAKE): ['welcome pradhan']
#
# Speech 1020:
# Keywords (RAKE): ['budget new']
#
# Speech 1021:
# Keywords (RAKE): ['interim budget']
#
# Speech 1022:
# Keywords (RAKE): ['occasion th']
#
# Speech 1023:
# Keywords (RAKE): ['high hope']
#
# Speech 1024:
# Keywords (RAKE): ['government ha']
#
# Speech 1025:
# Keywords (RAKE): ['holistic transparent']
#
# Speech 1026:
# Keywords (RAKE): ['support budget']
#
# Speech 1027:
# Keywords (RAKE): ['budget reflects']
#
# Speech 1028:
# Keywords (RAKE): ['budget ha']
#
# Speech 1029:
# Keywords (RAKE): ['centre ha']
#
# Speech 1030:
# Keywords (RAKE): ['interim budget']
#
# Speech 1031:
# Keywords (RAKE): ['budget foundation']
#
# Speech 1032:
# Keywords (RAKE): ['budget offer']
#
# Speech 1033:
# Keywords (RAKE): ['support general']
#
# Speech 1034:
# Keywords (RAKE): ['supporting interim']
#
# Speech 1035:
# Keywords (RAKE): ['budget ha']
#
# Speech 1036:
# Keywords (RAKE): ['hope objective']
#
# Speech 1037:
# Keywords (RAKE): ['far interim']
#
# Speech 1038:
# Keywords (RAKE): ['interim budget']
#
# Speech 1039:
# Keywords (RAKE): ['sincerely thank']
#
# Speech 1040:
# Keywords (RAKE): ['interim budget']
#
# Speech 1041:
# Keywords (RAKE): ['prime minister']
#
# Speech 1042:
# Keywords (RAKE): ['finance minister']
#
# Speech 1043:
# Keywords (RAKE): ['support welcome']
#
# Speech 1044:
# Keywords (RAKE): ['interim budget']
#
# Speech 1045:
# Keywords (RAKE): ['support interim']
#
# Speech 1046:
# Keywords (RAKE): ['would like']
#
# Speech 1047:
# Keywords (RAKE): ['entire country']
#
# Speech 1048:
# Keywords (RAKE): ['several necessary']
#
# Speech 1049:
# Keywords (RAKE): ['budget provision']
#
# Speech 1050:
# Keywords (RAKE): ['government ha']
#
# Speech 1051:
# Keywords (RAKE): ['central government']
#
# Speech 1052:
# Keywords (RAKE): ['nda government']
#
# Speech 1053:
# Keywords (RAKE): ['would like']
#
# Speech 1054:
# Keywords (RAKE): ['hon finance']
#
# Speech 1055:
# Keywords (RAKE): ['matter pride']
#
# Speech 1056:
# Keywords (RAKE): ['interim budget']
#
# Speech 1057:
# Keywords (RAKE): ['newly invention']
#
# Speech 1058:
# Keywords (RAKE): ['view general']
#
# Speech 1059:
# Keywords (RAKE): ['indeed wholesome']
#
# Speech 1060:
# Keywords (RAKE): ['grateful finance']
#
# Speech 1061:
# Keywords (RAKE): ['budget presented']
#
# Speech 1062:
# Keywords (RAKE): ['budget historical']
#
# Speech 1063:
# Keywords (RAKE): ['first foremost']
#
# Speech 1064:
# Keywords (RAKE): ['budget year']
#
# Speech 1065:
# Keywords (RAKE): ['tourism promotion']
#
# Speech 1066:
# Keywords (RAKE): ['five year']
#
# Speech 1067:
# Keywords (RAKE): ['thank government']
#
# Speech 1068:
# Keywords (RAKE): ['thank government']
#
# Speech 1069:
# Keywords (RAKE): ['thank hon']
#
# Speech 1070:
# Keywords (RAKE): ['rise support']
#
# Speech 1071:
# Keywords (RAKE): ['hon president']
#
# Speech 1072:
# Keywords (RAKE): ['government taking']
#
# Speech 1073:
# Keywords (RAKE): ['government led']
#
# Speech 1074:
# Keywords (RAKE): ['stated address']
#
# Speech 1075:
# Keywords (RAKE): ['year president']
#
# Speech 1076:
# Keywords (RAKE): ['hon president']
#
# Speech 1077:
# Keywords (RAKE): ['people north']
#
# Speech 1078:
# Keywords (RAKE): ['even many']
#
# Speech 1079:
# Keywords (RAKE): ['address hon']
#
# Speech 1080:
# Keywords (RAKE): ['government commitment']
#
# Speech 1081:
# Keywords (RAKE): ['support motion']
#
# Speech 1082:
# Keywords (RAKE): ['honble president']
#
# Speech 1083:
# Keywords (RAKE): ['toilet constructed']
#
# Speech 1084:
# Keywords (RAKE): ['today entire']
#
# Speech 1085:
# Keywords (RAKE): ['provision article']
#
# Speech 1086:
# Keywords (RAKE): ['would like']
#
# Speech 1087:
# Keywords (RAKE): ['unemployment ha']
#
# Speech 1088:
# Keywords (RAKE): ['name budget']
#
# Speech 1089:
# Keywords (RAKE): ['let u']
#
# Speech 1090:
# Keywords (RAKE): ['key india']
#
# Speech 1091:
# Keywords (RAKE): ['outline given']
#
# Speech 1092:
# Keywords (RAKE): ['present government']
#
# Speech 1093:
# Keywords (RAKE): ['government spare']
#
# Speech 1094:
# Keywords (RAKE): ['today indian']
#
# Speech 1095:
# Keywords (RAKE): ['last session']
#
# Speech 1096:
# Keywords (RAKE): ['matter great']
#
# Speech 1097:
# Keywords (RAKE): ['address hon']
#
# Speech 1098:
# Keywords (RAKE): ['numerous helpless']
#
# Speech 1099:
# Keywords (RAKE): ['million people']
#
# Speech 1100:
# Keywords (RAKE): ['government moving']
#
# Speech 1101:
# Keywords (RAKE): ['honble president']
#
# Speech 1102:
# Keywords (RAKE): ['government ha']
#
# Speech 1103:
# Keywords (RAKE): ['president address']
#
# Speech 1104:
# Keywords (RAKE): ['address wa']
#
# Speech 1105:
# Keywords (RAKE): ['government take']
#
# Speech 1106:
# Keywords (RAKE): ['honble president']
#
# Speech 1107:
# Keywords (RAKE): ['president address']
#
# Speech 1108:
# Keywords (RAKE): ['president address']
#
# Speech 1109:
# Keywords (RAKE): ['would like']
#
# Speech 1110:
# Keywords (RAKE): ['bsnl largest']
#
# Speech 1111:
# Keywords (RAKE): ['government took']
#
# Speech 1112:
# Keywords (RAKE): ['would like']
#
# Speech 1113:
# Keywords (RAKE): ['government ha']
#
# Speech 1114:
# Keywords (RAKE): ['extremely grateful']
#
# Speech 1115:
# Keywords (RAKE): ['farmer literally']
#
# Speech 1116:
# Keywords (RAKE): ['nation celebrating']
#
# Speech 1117:
# Keywords (RAKE): ['giving household']
#
# Speech 1118:
# Keywords (RAKE): ['country progress']
#
# Speech 1119:
# Keywords (RAKE): ['government committed']
#
# Speech 1120:
# Keywords (RAKE): ['honble president']
#
# Speech 1121:
# Keywords (RAKE): ['hon president']
#
# Speech 1122:
# Keywords (RAKE): ['country ha']
#
# Speech 1123:
# Keywords (RAKE): ['focus present']
#
# Speech 1124:
# Keywords (RAKE): ['president address']
#
# Speech 1125:
# Keywords (RAKE): ['president address']
#
# Speech 1126:
# Keywords (RAKE): ['st january']
#
# Speech 1127:
# Keywords (RAKE): ['behalf party']
#
# Speech 1128:
# Keywords (RAKE): ['government ha']
#
# Speech 1129:
# Keywords (RAKE): ['government ha']
#
# Speech 1130:
# Keywords (RAKE): ['first would']
#
# Speech 1131:
# Keywords (RAKE): ['government ha']
#
# Speech 1132:
# Keywords (RAKE): ['country celebrating']
#
# Speech 1133:
# Keywords (RAKE): ['union budget']
#
# Speech 1134:
# Keywords (RAKE): ['government ha']
#
# Speech 1135:
# Keywords (RAKE): ['government leadership']
#
# Speech 1136:
# Keywords (RAKE): ['government make']
#
# Speech 1137:
# Keywords (RAKE): ['government ha']
#
# Speech 1138:
# Keywords (RAKE): ['particularly grateful']
#
# Speech 1139:
# Keywords (RAKE): ['president address']
#
# Speech 1140:
# Keywords (RAKE): ['president address']
#
# Speech 1141:
# Keywords (RAKE): ['dna technology']
#
# Speech 1142:
# Keywords (RAKE): ['think bill']
#
# Speech 1143:
# Keywords (RAKE): ['would like']
#
# Speech 1144:
# Keywords (RAKE): ['common man']
#
# Speech 1145:
# Keywords (RAKE): ['sikkim democratic']
#
# Speech 1146:
# Keywords (RAKE): ['hon member']
#
# Speech 1147:
# Keywords (RAKE): ['constitution amendment']
#
# Speech 1148:
# Keywords (RAKE): ['bill make']
#
# Speech 1149:
# Keywords (RAKE): ['citizenship never']
#
# Speech 1150:
# Keywords (RAKE): ['gathered ensure']
#
# Speech 1151:
# Keywords (RAKE): ['people assam']
#
# Speech 1152:
# Keywords (RAKE): ['bill give']
#
# Speech 1153:
# Keywords (RAKE): ['oppose manner']
#
# Speech 1154:
# Keywords (RAKE): ['oppose bill']
#
# Speech 1155:
# Keywords (RAKE): ['provide uniform']
#
# Speech 1156:
# Keywords (RAKE): ['unfortunately india']
#
# Speech 1157:
# Keywords (RAKE): ['rise support']
#
# Speech 1158:
# Keywords (RAKE): ['constitution th']
#
# Speech 1159:
# Keywords (RAKE): ['today th']
#
# Speech 1160:
# Keywords (RAKE): ['important constitution']
#
# Speech 1161:
# Keywords (RAKE): ['behalf party']
#
# Speech 1162:
# Keywords (RAKE): ['behalf party']
#
# Speech 1163:
# Keywords (RAKE): ['rise speak']
#
# Speech 1164:
# Keywords (RAKE): ['today big']
#
# Speech 1165:
# Keywords (RAKE): ['bill election']
#
# Speech 1166:
# Keywords (RAKE): ['happy reservation']
#
# Speech 1167:
# Keywords (RAKE): ['undoubtedly support']
#
# Speech 1168:
# Keywords (RAKE): ['history created']
#
# Speech 1169:
# Keywords (RAKE): ['government ha']
#
# Speech 1170:
# Keywords (RAKE): ['good decision']
#
# Speech 1171:
# Keywords (RAKE): ['dream well']
#
# Speech 1172:
# Keywords (RAKE): ['appreciate government']
#
# Speech 1173:
# Keywords (RAKE): ['per prevalent']
#
# Speech 1174:
# Keywords (RAKE): ['oppose bill']
#
# Speech 1175:
# Keywords (RAKE): ['today discussing']
#
# Speech 1176:
# Keywords (RAKE): ['shri arun']
#
# Speech 1177:
# Keywords (RAKE): ['price rafale']
#
# Speech 1178:
# Keywords (RAKE): ['opposition sought']
#
# Speech 1179:
# Keywords (RAKE): ['believe country']
#
# Speech 1180:
# Keywords (RAKE): ['government ha']
#
# Speech 1181:
# Keywords (RAKE): ['appears congress']
#
# Speech 1182:
# Keywords (RAKE): ['present aadhaar']
#
# Speech 1183:
# Keywords (RAKE): ['present bill']
#
# Speech 1184:
# Keywords (RAKE): ['supreme court']
#
# Speech 1185:
# Keywords (RAKE): ['issue discussed']
#
# Speech 1186:
# Keywords (RAKE): ['government ha']
#
# Speech 1187:
# Keywords (RAKE): ['price aircraft']

# %% [markdown]
# ##Key Word Extraction using KeyBERT

# %% [markdown]
# KeyBERT is a straightforward and user-friendly keyword extraction technique that leverages BERT embeddings to identify the most similar keywords and keyphrases within a given document. It relies on BERT embeddings and employs basic cosine similarity to pinpoint sub-documents within the text that closely resemble the document as a whole.
#
# To create a document-level representation, BERT is utilized for extracting document embeddings. Subsequently, word embeddings for N-gram words/phrases are extracted. Finally, cosine similarity is applied to identify words/phrases that closely resemble the document, allowing for the identification of terms that best encapsulate the entire document.
#
# KeyBert utilizes huggingface transformer-based pre-trained models to generate embeddings, with the default choice being the all-MiniLM-L6-v2 model.

# %%
# Initialize KeyBERT model
kw_model = KeyBERT()

# Function to extract keywords using KeyBERT
def extract_keywords_keybert(text):
    keywords = kw_model.extract_keywords(text)
    return keywords

df['Keywords_KeyBERT'] = df['Preprocessed_Speech'].apply(lambda x: extract_keywords_keybert(' '.join(x)))

for index, row in df.iterrows():
    print(f"Speech {index}:")
    print("Keywords with Scores (KeyBERT):", row['Keywords_KeyBERT'])
    print()
# Out:
# Speech 0:
# Keywords with Scores (KeyBERT): [('gandhiji', 0.5121), ('gandhi', 0.4641), ('rajya', 0.4597), ('hindu', 0.4304), ('indian', 0.3856)]
#
# Speech 1:
# Keywords with Scores (KeyBERT): [('ramayana', 0.4972), ('rama', 0.4891), ('ramaana', 0.456), ('rajya', 0.4141), ('temple', 0.3765)]
#
# Speech 2:
# Keywords with Scores (KeyBERT): [('mandir', 0.482), ('temple', 0.446), ('gratitude', 0.4316), ('bihar', 0.3705), ('shri', 0.3603)]
#
# Speech 3:
# Keywords with Scores (KeyBERT): [('mandir', 0.379), ('ramchandra', 0.3691), ('shri', 0.3541), ('temple', 0.3166), ('caste', 0.3087)]
#
# Speech 4:
# Keywords with Scores (KeyBERT): [('sabha', 0.483), ('leadership', 0.3735), ('unprecedented', 0.35), ('speaker', 0.3438), ('lok', 0.3233)]
#
# Speech 5:
# Keywords with Scores (KeyBERT): [('ayodhya', 0.4056), ('prayer', 0.3612), ('india', 0.3458), ('pranpratishtha', 0.3391), ('fortunate', 0.332)]
#
# Speech 6:
# Keywords with Scores (KeyBERT): [('ramchandra', 0.404), ('chandra', 0.3918), ('hindu', 0.3799), ('rama', 0.3568), ('india', 0.3355)]
#
# Speech 7:
# Keywords with Scores (KeyBERT): [('sabha', 0.5049), ('parliament', 0.4836), ('constituency', 0.4371), ('lok', 0.3712), ('sitaji', 0.3691)]
#
# Speech 8:
# Keywords with Scores (KeyBERT): [('sabha', 0.52), ('lok', 0.3722), ('reservation', 0.371), ('elected', 0.3665), ('shri', 0.3633)]
#
# Speech 9:
# Keywords with Scores (KeyBERT): [('ramrajya', 0.4833), ('ayodhya', 0.4247), ('rajya', 0.4071), ('andhra', 0.3994), ('ramayana', 0.3975)]
#
# Speech 10:
# Keywords with Scores (KeyBERT): [('sabha', 0.476), ('democracy', 0.4058), ('hindutva', 0.4034), ('speak', 0.3733), ('india', 0.3707)]
#
# Speech 11:
# Keywords with Scores (KeyBERT): [('mandir', 0.5163), ('tribals', 0.4009), ('rajya', 0.3788), ('tribal', 0.3739), ('peace', 0.3342)]
#
# Speech 12:
# Keywords with Scores (KeyBERT): [('parliament', 0.4729), ('janmabhoomi', 0.4526), ('temple', 0.4472), ('ayodhya', 0.4396), ('ramchandra', 0.4071)]
#
# Speech 13:
# Keywords with Scores (KeyBERT): [('constituency', 0.498), ('minister', 0.4013), ('parliamentary', 0.3909), ('uttar', 0.3853), ('pradesh', 0.3374)]
#
# Speech 14:
# Keywords with Scores (KeyBERT): [('parliament', 0.5069), ('sabha', 0.4474), ('deliberation', 0.4232), ('janata', 0.3489), ('debate', 0.3338)]
#
# Speech 15:
# Keywords with Scores (KeyBERT): [('sabha', 0.4657), ('constituency', 0.4205), ('parliamentary', 0.3588), ('member', 0.2907), ('elected', 0.2816)]
#
# Speech 16:
# Keywords with Scores (KeyBERT): [('mandir', 0.5433), ('ramcharit', 0.4535), ('ramayana', 0.4502), ('crore', 0.4154), ('raj', 0.4049)]
#
# Speech 17:
# Keywords with Scores (KeyBERT): [('opportunity', 0.428), ('gratitude', 0.3838), ('constituency', 0.3787), ('opposition', 0.3364), ('speaker', 0.3154)]
#
# Speech 18:
# Keywords with Scores (KeyBERT): [('sabha', 0.5078), ('panchayat', 0.4834), ('lok', 0.4534), ('reservation', 0.3065), ('democracy', 0.2482)]
#
# Speech 19:
# Keywords with Scores (KeyBERT): [('sabha', 0.4999), ('constituency', 0.4204), ('parliament', 0.3953), ('reservation', 0.3891), ('lok', 0.3714)]
#
# Speech 20:
# Keywords with Scores (KeyBERT): [('sabha', 0.5052), ('sabhas', 0.4695), ('parliament', 0.4266), ('lok', 0.3673), ('crore', 0.3192)]
#
# Speech 21:
# Keywords with Scores (KeyBERT): [('agriculture', 0.5917), ('farmer', 0.4685), ('bharat', 0.4486), ('swaminathan', 0.4156), ('sector', 0.3791)]
#
# Speech 22:
# Keywords with Scores (KeyBERT): [('sabha', 0.4903), ('parliament', 0.4039), ('lok', 0.3696), ('treasury', 0.3436), ('providing', 0.3392)]
#
# Speech 23:
# Keywords with Scores (KeyBERT): [('proceeding', 0.4474), ('covid', 0.4403), ('behaviour', 0.3738), ('conducted', 0.3569), ('sir', 0.297)]
#
# Speech 24:
# Keywords with Scores (KeyBERT): [('parliament', 0.4635), ('sabha', 0.4567), ('speaker', 0.3291), ('splendid', 0.3146), ('lok', 0.2929)]
#
# Speech 25:
# Keywords with Scores (KeyBERT): [('sabha', 0.5014), ('parliamentary', 0.4691), ('parliament', 0.469), ('legislation', 0.2797), ('chairperson', 0.2595)]
#
# Speech 26:
# Keywords with Scores (KeyBERT): [('minister', 0.3351), ('crore', 0.3088), ('gdp', 0.2982), ('government', 0.2967), ('singh', 0.2881)]
#
# Speech 27:
# Keywords with Scores (KeyBERT): [('bjp', 0.5056), ('sabha', 0.3614), ('bharat', 0.3491), ('political', 0.3258), ('india', 0.3231)]
#
# Speech 28:
# Keywords with Scores (KeyBERT): [('corruption', 0.4102), ('bjp', 0.4093), ('crore', 0.3834), ('corrupt', 0.3621), ('bharat', 0.3466)]
#
# Speech 29:
# Keywords with Scores (KeyBERT): [('minister', 0.3827), ('bharat', 0.3426), ('swaminathan', 0.3165), ('singh', 0.3077), ('government', 0.294)]
#
# Speech 30:
# Keywords with Scores (KeyBERT): [('governance', 0.3813), ('economy', 0.3761), ('government', 0.3746), ('gdp', 0.3635), ('economic', 0.3479)]
#
# Speech 31:
# Keywords with Scores (KeyBERT): [('gdp', 0.4211), ('economy', 0.4021), ('economist', 0.389), ('fiscal', 0.3576), ('banking', 0.3292)]
#
# Speech 32:
# Keywords with Scores (KeyBERT): [('gdp', 0.3625), ('government', 0.2707), ('minister', 0.2388), ('regime', 0.2372), ('fiscal', 0.2082)]
#
# Speech 33:
# Keywords with Scores (KeyBERT): [('corruption', 0.4981), ('andhra', 0.4326), ('corrupt', 0.431), ('pradesh', 0.4203), ('bharat', 0.4074)]
#
# Speech 34:
# Keywords with Scores (KeyBERT): [('odisha', 0.5491), ('odishas', 0.5162), ('bharat', 0.4049), ('governmentupa', 0.3983), ('demand', 0.3373)]
#
# Speech 35:
# Keywords with Scores (KeyBERT): [('gdp', 0.3923), ('fiscal', 0.3782), ('government', 0.3781), ('economy', 0.3355), ('deficit', 0.3107)]
#
# Speech 36:
# Keywords with Scores (KeyBERT): [('demonetization', 0.398), ('government', 0.3957), ('jharkhand', 0.3328), ('corruptionfree', 0.3244), ('cloud', 0.3243)]
#
# Speech 37:
# Keywords with Scores (KeyBERT): [('government', 0.4105), ('india', 0.4043), ('bihari', 0.3845), ('crore', 0.3723), ('infrastructure', 0.3557)]
#
# Speech 38:
# Keywords with Scores (KeyBERT): [('mandir', 0.4369), ('bharat', 0.3825), ('crore', 0.3582), ('airport', 0.3503), ('government', 0.3374)]
#
# Speech 39:
# Keywords with Scores (KeyBERT): [('corruption', 0.4874), ('government', 0.4196), ('crore', 0.3844), ('benefited', 0.335), ('congress', 0.326)]
#
# Speech 40:
# Keywords with Scores (KeyBERT): [('panchayati', 0.4719), ('nehru', 0.4213), ('gandhi', 0.4072), ('raj', 0.3538), ('government', 0.3248)]
#
# Speech 41:
# Keywords with Scores (KeyBERT): [('reservation', 0.4937), ('caste', 0.4363), ('tribe', 0.4334), ('tamil', 0.3986), ('community', 0.3973)]
#
# Speech 42:
# Keywords with Scores (KeyBERT): [('government', 0.3925), ('andhra', 0.3583), ('odisha', 0.3546), ('reservation', 0.3513), ('pradesh', 0.3439)]
#
# Speech 43:
# Keywords with Scores (KeyBERT): [('government', 0.4239), ('federalism', 0.3924), ('pollution', 0.3852), ('parliamentary', 0.3433), ('constituency', 0.3027)]
#
# Speech 44:
# Keywords with Scores (KeyBERT): [('arunachal', 0.4893), ('bjp', 0.481), ('tribals', 0.4764), ('tribe', 0.4505), ('tribal', 0.4418)]
#
# Speech 45:
# Keywords with Scores (KeyBERT): [('assam', 0.4366), ('tribal', 0.4185), ('andhra', 0.4035), ('tribe', 0.397), ('odisha', 0.3969)]
#
# Speech 46:
# Keywords with Scores (KeyBERT): [('pollution', 0.5706), ('groundwater', 0.4297), ('polluted', 0.4125), ('river', 0.3357), ('contaminated', 0.3338)]
#
# Speech 47:
# Keywords with Scores (KeyBERT): [('bihar', 0.5202), ('reservation', 0.4969), ('caste', 0.4807), ('loharas', 0.3486), ('tribe', 0.3289)]
#
# Speech 48:
# Keywords with Scores (KeyBERT): [('dhangarh', 0.4167), ('maharashtra', 0.4098), ('dhangar', 0.3927), ('caste', 0.3753), ('dhangars', 0.3749)]
#
# Speech 49:
# Keywords with Scores (KeyBERT): [('pollution', 0.394), ('exemption', 0.3045), ('environmental', 0.2932), ('government', 0.2831), ('advisory', 0.2546)]
#
# Speech 50:
# Keywords with Scores (KeyBERT): [('pollution', 0.419), ('stakeholder', 0.3941), ('contamination', 0.3825), ('environmental', 0.373), ('waterborne', 0.356)]
#
# Speech 51:
# Keywords with Scores (KeyBERT): [('ganga', 0.4168), ('wastewater', 0.4131), ('sewage', 0.3941), ('river', 0.3752), ('groundwater', 0.3574)]
#
# Speech 52:
# Keywords with Scores (KeyBERT): [('pollution', 0.3976), ('polluting', 0.3789), ('prevention', 0.3623), ('spcb', 0.3573), ('ce', 0.3372)]
#
# Speech 53:
# Keywords with Scores (KeyBERT): [('pollution', 0.3945), ('kerala', 0.3781), ('enforcement', 0.3434), ('government', 0.3355), ('amendment', 0.3156)]
#
# Speech 54:
# Keywords with Scores (KeyBERT): [('pollution', 0.4823), ('prevention', 0.3938), ('river', 0.3464), ('flood', 0.3212), ('water', 0.3125)]
#
# Speech 55:
# Keywords with Scores (KeyBERT): [('pollution', 0.46), ('assam', 0.3817), ('government', 0.37), ('amendment', 0.3321), ('polluted', 0.3226)]
#
# Speech 56:
# Keywords with Scores (KeyBERT): [('pollution', 0.4107), ('environment', 0.3482), ('river', 0.3291), ('conservation', 0.2913), ('polluted', 0.2865)]
#
# Speech 57:
# Keywords with Scores (KeyBERT): [('pollution', 0.4822), ('parliamentary', 0.4104), ('polluted', 0.3972), ('committee', 0.327), ('passed', 0.3219)]
#
# Speech 58:
# Keywords with Scores (KeyBERT): [('pollution', 0.4274), ('contaminated', 0.4125), ('ganga', 0.3837), ('groundwater', 0.3805), ('polluted', 0.3655)]
#
# Speech 59:
# Keywords with Scores (KeyBERT): [('pollution', 0.4077), ('groundwater', 0.3868), ('government', 0.3541), ('enforcement', 0.3507), ('prevention', 0.3504)]
#
# Speech 60:
# Keywords with Scores (KeyBERT): [('sewage', 0.365), ('groundwater', 0.3285), ('sewerage', 0.3206), ('pollution', 0.3125), ('rise', 0.3022)]
#
# Speech 61:
# Keywords with Scores (KeyBERT): [('maharashtra', 0.48), ('constituency', 0.4199), ('mumbainorth', 0.4117), ('parliamentary', 0.3144), ('processing', 0.3021)]
#
# Speech 62:
# Keywords with Scores (KeyBERT): [('bihar', 0.4322), ('implementation', 0.2967), ('project', 0.2663), ('city', 0.2525), ('statement', 0.2521)]
#
# Speech 63:
# Keywords with Scores (KeyBERT): [('madhya', 0.4745), ('airport', 0.4301), ('pradesh', 0.4172), ('build', 0.2902), ('guna', 0.2399)]
#
# Speech 64:
# Keywords with Scores (KeyBERT): [('overbridge', 0.5592), ('hapur', 0.4851), ('railway', 0.4166), ('construction', 0.3703), ('uttar', 0.3275)]
#
# Speech 65:
# Keywords with Scores (KeyBERT): [('infrastructure', 0.3761), ('sector', 0.3737), ('government', 0.3464), ('fiscal', 0.3372), ('prosperity', 0.32)]
#
# Speech 66:
# Keywords with Scores (KeyBERT): [('maharajganj', 0.5138), ('bihar', 0.4208), ('hospital', 0.3808), ('constituency', 0.3286), ('operate', 0.2902)]
#
# Speech 67:
# Keywords with Scores (KeyBERT): [('tax', 0.3811), ('taxpayer', 0.3702), ('government', 0.367), ('gst', 0.3537), ('filing', 0.3396)]
#
# Speech 68:
# Keywords with Scores (KeyBERT): [('grievance', 0.4873), ('labour', 0.3758), ('teacher', 0.3625), ('jobless', 0.2357), ('school', 0.2254)]
#
# Speech 69:
# Keywords with Scores (KeyBERT): [('kerala', 0.3123), ('raise', 0.3122), ('minister', 0.3044), ('karnataka', 0.2947), ('bjp', 0.2836)]
#
# Speech 70:
# Keywords with Scores (KeyBERT): [('soyabean', 0.4324), ('cotton', 0.3882), ('ban', 0.3051), ('export', 0.304), ('lift', 0.2977)]
#
# Speech 71:
# Keywords with Scores (KeyBERT): [('bihar', 0.5001), ('patna', 0.4765), ('reservation', 0.389), ('bharat', 0.3813), ('minister', 0.3077)]
#
# Speech 72:
# Keywords with Scores (KeyBERT): [('odisha', 0.5195), ('model', 0.3437), ('school', 0.3332), ('opening', 0.3248), ('berhampur', 0.3017)]
#
# Speech 73:
# Keywords with Scores (KeyBERT): [('raipur', 0.4719), ('constituency', 0.3838), ('cement', 0.3635), ('dharsiwa', 0.3451), ('residential', 0.2735)]
#
# Speech 74:
# Keywords with Scores (KeyBERT): [('ramayana', 0.6114), ('hatya', 0.3941), ('haran', 0.3162), ('religious', 0.2766), ('circuit', 0.2525)]
#
# Speech 75:
# Keywords with Scores (KeyBERT): [('crore', 0.3931), ('constituency', 0.3753), ('minister', 0.3749), ('narendrabhai', 0.3594), ('budget', 0.3526)]
#
# Speech 76:
# Keywords with Scores (KeyBERT): [('minister', 0.4472), ('panchayat', 0.4248), ('bharat', 0.3832), ('ujjwala', 0.3694), ('crore', 0.3611)]
#
# Speech 77:
# Keywords with Scores (KeyBERT): [('madhya', 0.4448), ('compensation', 0.4415), ('coalfield', 0.4169), ('coal', 0.3814), ('employment', 0.3427)]
#
# Speech 78:
# Keywords with Scores (KeyBERT): [('jammu', 0.4948), ('constituency', 0.4525), ('land', 0.4021), ('ownership', 0.354), ('farmer', 0.3057)]
#
# Speech 79:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4927), ('municipal', 0.3753), ('constituency', 0.3709), ('nagar', 0.368), ('kotwali', 0.3512)]
#
# Speech 80:
# Keywords with Scores (KeyBERT): [('poverty', 0.3681), ('bharat', 0.3652), ('agriculture', 0.3497), ('crore', 0.3392), ('government', 0.321)]
#
# Speech 81:
# Keywords with Scores (KeyBERT): [('andhra', 0.4011), ('agriculture', 0.382), ('agricultural', 0.3377), ('pradesh', 0.3357), ('irrigation', 0.3301)]
#
# Speech 82:
# Keywords with Scores (KeyBERT): [('bihar', 0.4793), ('bharat', 0.437), ('patna', 0.4167), ('bakhtiyarpurpurnia', 0.4113), ('railway', 0.37)]
#
# Speech 83:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4982), ('rajya', 0.4211), ('nagar', 0.3903), ('sabha', 0.3822), ('bharat', 0.3594)]
#
# Speech 84:
# Keywords with Scores (KeyBERT): [('poverty', 0.3236), ('minister', 0.3208), ('maharashtra', 0.3126), ('government', 0.3083), ('income', 0.2942)]
#
# Speech 85:
# Keywords with Scores (KeyBERT): [('taxrelated', 0.3678), ('tax', 0.3462), ('taxpayer', 0.3277), ('minister', 0.3012), ('tribunal', 0.2815)]
#
# Speech 86:
# Keywords with Scores (KeyBERT): [('bharat', 0.3877), ('india', 0.3186), ('poverty', 0.3065), ('crore', 0.3063), ('yojana', 0.2928)]
#
# Speech 87:
# Keywords with Scores (KeyBERT): [('minister', 0.3847), ('crore', 0.3287), ('government', 0.3151), ('constituency', 0.2948), ('maharashtra', 0.2935)]
#
# Speech 88:
# Keywords with Scores (KeyBERT): [('minister', 0.4153), ('crore', 0.3998), ('aadhaar', 0.3923), ('yojana', 0.3852), ('dhan', 0.3603)]
#
# Speech 89:
# Keywords with Scores (KeyBERT): [('kashmir', 0.4257), ('jammu', 0.3984), ('sustainable', 0.3641), ('agriculture', 0.3618), ('budget', 0.3439)]
#
# Speech 90:
# Keywords with Scores (KeyBERT): [('yojana', 0.4359), ('ujjawala', 0.4346), ('government', 0.4154), ('lakhpati', 0.4119), ('bharat', 0.4032)]
#
# Speech 91:
# Keywords with Scores (KeyBERT): [('crore', 0.4427), ('bharat', 0.3673), ('india', 0.3618), ('aadhaar', 0.3573), ('minister', 0.3457)]
#
# Speech 92:
# Keywords with Scores (KeyBERT): [('bihar', 0.4815), ('bhutan', 0.4291), ('bangladesh', 0.4112), ('kishanganj', 0.371), ('livelihood', 0.3473)]
#
# Speech 93:
# Keywords with Scores (KeyBERT): [('crore', 0.3832), ('bengal', 0.3766), ('constituency', 0.3632), ('budget', 0.3533), ('government', 0.3471)]
#
# Speech 94:
# Keywords with Scores (KeyBERT): [('andhra', 0.4702), ('pradesh', 0.445), ('amravati', 0.3346), ('parliament', 0.3193), ('capital', 0.3153)]
#
# Speech 95:
# Keywords with Scores (KeyBERT): [('punjab', 0.5318), ('sahib', 0.4687), ('haryana', 0.444), ('chandigarh', 0.4236), ('mandir', 0.4125)]
#
# Speech 96:
# Keywords with Scores (KeyBERT): [('poverty', 0.3721), ('anganwadi', 0.334), ('crore', 0.3331), ('maharashtra', 0.3273), ('parliament', 0.3205)]
#
# Speech 97:
# Keywords with Scores (KeyBERT): [('bihar', 0.4486), ('jahanabad', 0.3922), ('bharat', 0.3838), ('development', 0.356), ('crore', 0.3497)]
#
# Speech 98:
# Keywords with Scores (KeyBERT): [('talukas', 0.4559), ('taluka', 0.4405), ('maharashtra', 0.4043), ('bharat', 0.3966), ('mumbai', 0.3603)]
#
# Speech 99:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4493), ('reform', 0.3701), ('taxpayer', 0.3417), ('dariyapur', 0.3241), ('government', 0.3228)]
#
# Speech 100:
# Keywords with Scores (KeyBERT): [('demand', 0.4285), ('government', 0.3823), ('inflation', 0.3554), ('kerala', 0.3335), ('asean', 0.321)]
#
# Speech 101:
# Keywords with Scores (KeyBERT): [('andhra', 0.4334), ('pradesh', 0.3911), ('capital', 0.375), ('allocating', 0.3404), ('government', 0.3257)]
#
# Speech 102:
# Keywords with Scores (KeyBERT): [('agriculture', 0.4795), ('pmvishwakarma', 0.3608), ('caste', 0.3514), ('yojana', 0.3429), ('government', 0.3424)]
#
# Speech 103:
# Keywords with Scores (KeyBERT): [('shahganj', 0.496), ('azamgarh', 0.4877), ('gorakhpur', 0.4712), ('lalganj', 0.4599), ('nizamabad', 0.4011)]
#
# Speech 104:
# Keywords with Scores (KeyBERT): [('minister', 0.4331), ('india', 0.3678), ('crore', 0.3639), ('constituency', 0.3627), ('sikkim', 0.3464)]
#
# Speech 105:
# Keywords with Scores (KeyBERT): [('government', 0.4365), ('indore', 0.4243), ('economic', 0.3847), ('policy', 0.3475), ('innovation', 0.3367)]
#
# Speech 106:
# Keywords with Scores (KeyBERT): [('income', 0.438), ('labour', 0.3884), ('earnings', 0.3681), ('india', 0.3376), ('wealth', 0.329)]
#
# Speech 107:
# Keywords with Scores (KeyBERT): [('sector', 0.4121), ('financial', 0.3933), ('government', 0.3922), ('finance', 0.3729), ('recruitment', 0.3554)]
#
# Speech 108:
# Keywords with Scores (KeyBERT): [('karnataka', 0.3897), ('bharat', 0.3758), ('lakshmi', 0.3585), ('reservoir', 0.3206), ('bangalore', 0.3089)]
#
# Speech 109:
# Keywords with Scores (KeyBERT): [('nicobar', 0.2988), ('island', 0.2963), ('andaman', 0.2844), ('madurai', 0.2669), ('demand', 0.262)]
#
# Speech 110:
# Keywords with Scores (KeyBERT): [('bharat', 0.3473), ('anganwadi', 0.3299), ('reform', 0.3287), ('government', 0.3261), ('pmsvanidhi', 0.3243)]
#
# Speech 111:
# Keywords with Scores (KeyBERT): [('expenditure', 0.3779), ('budget', 0.3425), ('bharat', 0.3167), ('aanganwadi', 0.3113), ('crore', 0.3112)]
#
# Speech 112:
# Keywords with Scores (KeyBERT): [('budget', 0.3997), ('expenditure', 0.3926), ('bihar', 0.3802), ('development', 0.3673), ('crore', 0.3669)]
#
# Speech 113:
# Keywords with Scores (KeyBERT): [('minister', 0.3854), ('crore', 0.3612), ('government', 0.3531), ('bharat', 0.3503), ('yojana', 0.3168)]
#
# Speech 114:
# Keywords with Scores (KeyBERT): [('crore', 0.374), ('caste', 0.3657), ('madrasa', 0.3533), ('yojana', 0.3403), ('expenditure', 0.3318)]
#
# Speech 115:
# Keywords with Scores (KeyBERT): [('bihar', 0.4706), ('ahmedabad', 0.4262), ('azamnagar', 0.4061), ('railway', 0.4033), ('bhagalpur', 0.3903)]
#
# Speech 116:
# Keywords with Scores (KeyBERT): [('bharat', 0.351), ('constituency', 0.3282), ('parliament', 0.328), ('shakti', 0.3271), ('ujjwala', 0.3184)]
#
# Speech 117:
# Keywords with Scores (KeyBERT): [('demand', 0.4244), ('anganwadi', 0.4208), ('budget', 0.3595), ('unemployment', 0.3593), ('balrampur', 0.3524)]
#
# Speech 118:
# Keywords with Scores (KeyBERT): [('crore', 0.3366), ('bharat', 0.3289), ('sabha', 0.315), ('parliament', 0.3107), ('minister', 0.3094)]
#
# Speech 119:
# Keywords with Scores (KeyBERT): [('government', 0.4131), ('india', 0.3885), ('gorakhpur', 0.3671), ('msme', 0.3335), ('subsidy', 0.322)]
#
# Speech 120:
# Keywords with Scores (KeyBERT): [('taxation', 0.4455), ('government', 0.3647), ('debt', 0.3532), ('lakh', 0.3265), ('rupee', 0.3164)]
#
# Speech 121:
# Keywords with Scores (KeyBERT): [('minister', 0.404), ('bharat', 0.3913), ('ramgarh', 0.3889), ('government', 0.3623), ('india', 0.359)]
#
# Speech 122:
# Keywords with Scores (KeyBERT): [('karnataka', 0.4931), ('jharkhand', 0.4377), ('bihar', 0.4371), ('government', 0.3612), ('india', 0.3548)]
#
# Speech 123:
# Keywords with Scores (KeyBERT): [('minister', 0.4657), ('government', 0.331), ('country', 0.329), ('nationbuilding', 0.3236), ('railway', 0.2609)]
#
# Speech 124:
# Keywords with Scores (KeyBERT): [('crore', 0.4008), ('ujjwala', 0.381), ('infrastructure', 0.3456), ('india', 0.3353), ('shakti', 0.3317)]
#
# Speech 125:
# Keywords with Scores (KeyBERT): [('yojana', 0.3588), ('bharat', 0.351), ('provision', 0.3183), ('ujjwala', 0.3129), ('infrastructure', 0.3046)]
#
# Speech 126:
# Keywords with Scores (KeyBERT): [('yojana', 0.3963), ('agriculture', 0.3886), ('saksham', 0.3709), ('anganwadi', 0.3515), ('poverty', 0.3416)]
#
# Speech 127:
# Keywords with Scores (KeyBERT): [('yojana', 0.3596), ('sector', 0.3476), ('crore', 0.3471), ('rise', 0.3285), ('visionary', 0.3264)]
#
# Speech 128:
# Keywords with Scores (KeyBERT): [('bharat', 0.3342), ('nidhi', 0.32), ('anganwadi', 0.3039), ('minister', 0.3024), ('yojana', 0.2982)]
#
# Speech 129:
# Keywords with Scores (KeyBERT): [('protesting', 0.4516), ('capitalist', 0.3811), ('economic', 0.3667), ('worker', 0.3499), ('minister', 0.3468)]
#
# Speech 130:
# Keywords with Scores (KeyBERT): [('gujarat', 0.4013), ('maharashtra', 0.3788), ('mumbai', 0.3718), ('mahanagar', 0.3612), ('delhi', 0.342)]
#
# Speech 131:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4266), ('crore', 0.3518), ('bharat', 0.3492), ('anganwadi', 0.2989), ('minister', 0.2936)]
#
# Speech 132:
# Keywords with Scores (KeyBERT): [('pmsvanidhi', 0.3619), ('minister', 0.3099), ('yojana', 0.3028), ('yojanas', 0.3023), ('bharat', 0.3014)]
#
# Speech 133:
# Keywords with Scores (KeyBERT): [('agriculture', 0.4184), ('poverty', 0.4006), ('pmsvanidhi', 0.3676), ('jharkhand', 0.3417), ('empowerment', 0.3283)]
#
# Speech 134:
# Keywords with Scores (KeyBERT): [('minister', 0.3483), ('pmsvanidhi', 0.3154), ('crore', 0.2946), ('ministry', 0.2764), ('bharat', 0.2671)]
#
# Speech 135:
# Keywords with Scores (KeyBERT): [('budget', 0.3625), ('government', 0.3592), ('bharat', 0.3458), ('anganwadis', 0.3413), ('infrastructure', 0.3357)]
#
# Speech 136:
# Keywords with Scores (KeyBERT): [('fiscal', 0.3661), ('crore', 0.3456), ('expenditure', 0.3366), ('nidhi', 0.3281), ('yojana', 0.3143)]
#
# Speech 137:
# Keywords with Scores (KeyBERT): [('agriculture', 0.3472), ('poverty', 0.3428), ('yojana', 0.3179), ('crore', 0.3023), ('sector', 0.2974)]
#
# Speech 138:
# Keywords with Scores (KeyBERT): [('punjab', 0.4296), ('minister', 0.3645), ('demand', 0.3545), ('crore', 0.3535), ('farmer', 0.3371)]
#
# Speech 139:
# Keywords with Scores (KeyBERT): [('tamil', 0.3846), ('caste', 0.3696), ('jammu', 0.3658), ('amended', 0.3598), ('kashmir', 0.3502)]
#
# Speech 140:
# Keywords with Scores (KeyBERT): [('examination', 0.3849), ('merit', 0.3679), ('minister', 0.3416), ('recruitment', 0.336), ('ensuring', 0.2934)]
#
# Speech 141:
# Keywords with Scores (KeyBERT): [('kashmir', 0.4951), ('jammu', 0.49), ('reservation', 0.4578), ('caste', 0.4416), ('lakh', 0.3719)]
#
# Speech 142:
# Keywords with Scores (KeyBERT): [('reservation', 0.543), ('jammu', 0.4542), ('caste', 0.4503), ('janata', 0.4463), ('kashmir', 0.4204)]
#
# Speech 143:
# Keywords with Scores (KeyBERT): [('bjp', 0.5051), ('jammu', 0.4986), ('kashmir', 0.4617), ('singh', 0.3943), ('reservation', 0.3755)]
#
# Speech 144:
# Keywords with Scores (KeyBERT): [('reservation', 0.3972), ('support', 0.3596), ('benefit', 0.3449), ('government', 0.3094), ('obc', 0.3017)]
#
# Speech 145:
# Keywords with Scores (KeyBERT): [('kashmir', 0.4998), ('jammu', 0.4399), ('gurjarbakarwals', 0.379), ('caste', 0.3346), ('reservation', 0.3267)]
#
# Speech 146:
# Keywords with Scores (KeyBERT): [('discriminated', 0.5217), ('reservation', 0.4719), ('india', 0.4185), ('kashmir', 0.4141), ('jammu', 0.3772)]
#
# Speech 147:
# Keywords with Scores (KeyBERT): [('kashmir', 0.5105), ('unemployment', 0.4614), ('jammu', 0.4493), ('progress', 0.3417), ('education', 0.3278)]
#
# Speech 148:
# Keywords with Scores (KeyBERT): [('reservation', 0.4737), ('jammu', 0.4494), ('kashmir', 0.3986), ('provision', 0.3587), ('commission', 0.2694)]
#
# Speech 149:
# Keywords with Scores (KeyBERT): [('kashmir', 0.4904), ('jammu', 0.4637), ('ladakh', 0.4296), ('caste', 0.4267), ('union', 0.3476)]
#
# Speech 150:
# Keywords with Scores (KeyBERT): [('minister', 0.3651), ('rise', 0.2985), ('education', 0.2795), ('promote', 0.2589), ('mp', 0.2461)]
#
# Speech 151:
# Keywords with Scores (KeyBERT): [('examination', 0.5091), ('malpractice', 0.3091), ('highlevel', 0.3084), ('incident', 0.3067), ('government', 0.3016)]
#
# Speech 152:
# Keywords with Scores (KeyBERT): [('reservation', 0.4354), ('judiciary', 0.3627), ('crore', 0.3621), ('delhi', 0.3576), ('provision', 0.3449)]
#
# Speech 153:
# Keywords with Scores (KeyBERT): [('examination', 0.4554), ('corruption', 0.4496), ('exam', 0.4274), ('lakh', 0.3161), ('crime', 0.3091)]
#
# Speech 154:
# Keywords with Scores (KeyBERT): [('examination', 0.4731), ('corruption', 0.4327), ('exam', 0.4149), ('merit', 0.3537), ('prevention', 0.35)]
#
# Speech 155:
# Keywords with Scores (KeyBERT): [('examination', 0.4622), ('law', 0.354), ('categorised', 0.3097), ('categorising', 0.306), ('trial', 0.2933)]
#
# Speech 156:
# Keywords with Scores (KeyBERT): [('rajasthan', 0.4484), ('tehsil', 0.3168), ('examination', 0.3108), ('corruption', 0.2926), ('india', 0.2637)]
#
# Speech 157:
# Keywords with Scores (KeyBERT): [('examination', 0.3612), ('bihar', 0.3504), ('corruption', 0.3276), ('government', 0.3208), ('merit', 0.32)]
#
# Speech 158:
# Keywords with Scores (KeyBERT): [('caste', 0.4835), ('reservation', 0.4799), ('tamil', 0.3908), ('demand', 0.3447), ('union', 0.3394)]
#
# Speech 159:
# Keywords with Scores (KeyBERT): [('examination', 0.4795), ('exam', 0.4374), ('education', 0.2922), ('consequence', 0.2919), ('bihar', 0.2917)]
#
# Speech 160:
# Keywords with Scores (KeyBERT): [('jharkhand', 0.3998), ('examination', 0.3972), ('minister', 0.3725), ('cbi', 0.368), ('inquiry', 0.3286)]
#
# Speech 161:
# Keywords with Scores (KeyBERT): [('caste', 0.4095), ('reservation', 0.3793), ('kashmir', 0.3653), ('jammu', 0.2998), ('tribals', 0.2991)]
#
# Speech 162:
# Keywords with Scores (KeyBERT): [('kashmir', 0.4111), ('demand', 0.4085), ('jammu', 0.3632), ('raise', 0.3225), ('government', 0.309)]
#
# Speech 163:
# Keywords with Scores (KeyBERT): [('caste', 0.4944), ('reservation', 0.4711), ('bihar', 0.4567), ('jammu', 0.4403), ('kashmir', 0.4057)]
#
# Speech 164:
# Keywords with Scores (KeyBERT): [('jammu', 0.5239), ('odisha', 0.5161), ('kashmir', 0.4912), ('tribal', 0.4096), ('tribe', 0.385)]
#
# Speech 165:
# Keywords with Scores (KeyBERT): [('caste', 0.5248), ('kashmir', 0.4561), ('poverty', 0.4211), ('tribe', 0.4182), ('jammu', 0.4083)]
#
# Speech 166:
# Keywords with Scores (KeyBERT): [('bharat', 0.3897), ('kashmir', 0.371), ('caste', 0.3509), ('minister', 0.3474), ('government', 0.3344)]
#
# Speech 167:
# Keywords with Scores (KeyBERT): [('panchayati', 0.4649), ('jammu', 0.4522), ('kashmir', 0.4506), ('caste', 0.4274), ('rise', 0.4216)]
#
# Speech 168:
# Keywords with Scores (KeyBERT): [('jammu', 0.551), ('kashmir', 0.5329), ('caste', 0.4038), ('union', 0.3632), ('territory', 0.3547)]
#
# Speech 169:
# Keywords with Scores (KeyBERT): [('caste', 0.3868), ('kashmir', 0.3837), ('jammu', 0.3559), ('minister', 0.3023), ('amendment', 0.2973)]
#
# Speech 170:
# Keywords with Scores (KeyBERT): [('india', 0.3053), ('sector', 0.2838), ('infrastructure', 0.2546), ('agriculture', 0.2504), ('empowerment', 0.24)]
#
# Speech 171:
# Keywords with Scores (KeyBERT): [('yojana', 0.3767), ('development', 0.37), ('empowerment', 0.362), ('poverty', 0.3577), ('crore', 0.3519)]
#
# Speech 172:
# Keywords with Scores (KeyBERT): [('rajasthan', 0.5585), ('highway', 0.4235), ('upgrade', 0.3769), ('statement', 0.2484), ('state', 0.2118)]
#
# Speech 173:
# Keywords with Scores (KeyBERT): [('tajewala', 0.4533), ('canal', 0.4273), ('yamuna', 0.3458), ('jhunjhunu', 0.3308), ('water', 0.2779)]
#
# Speech 174:
# Keywords with Scores (KeyBERT): [('sambalpuri', 0.5031), ('constitution', 0.3941), ('schedule', 0.3412), ('language', 0.3331), ('statement', 0.2385)]
#
# Speech 175:
# Keywords with Scores (KeyBERT): [('incamera', 0.6171), ('proceeding', 0.4754), ('statement', 0.3086), ('laid', 0.2378), ('regarding', 0.2252)]
#
# Speech 176:
# Keywords with Scores (KeyBERT): [('railway', 0.5625), ('daltonganj', 0.5109), ('connectivity', 0.3981), ('gaya', 0.3416), ('laid', 0.2543)]
#
# Speech 177:
# Keywords with Scores (KeyBERT): [('railway', 0.4346), ('deoria', 0.4152), ('station', 0.3392), ('shifting', 0.2865), ('district', 0.2771)]
#
# Speech 178:
# Keywords with Scores (KeyBERT): [('withdrawal', 0.5011), ('onion', 0.4385), ('ban', 0.3809), ('export', 0.3642), ('statement', 0.1971)]
#
# Speech 179:
# Keywords with Scores (KeyBERT): [('examination', 0.4752), ('distance', 0.4031), ('minimize', 0.3413), ('student', 0.3277), ('convenience', 0.3193)]
#
# Speech 180:
# Keywords with Scores (KeyBERT): [('secularism', 0.4637), ('secular', 0.4488), ('republic', 0.4384), ('nehru', 0.4189), ('hindu', 0.3887)]
#
# Speech 181:
# Keywords with Scores (KeyBERT): [('manipur', 0.4309), ('india', 0.3537), ('government', 0.3425), ('indian', 0.3208), ('caste', 0.3084)]
#
# Speech 182:
# Keywords with Scores (KeyBERT): [('vidyalayas', 0.3745), ('education', 0.371), ('promote', 0.3476), ('participation', 0.3301), ('rise', 0.3283)]
#
# Speech 183:
# Keywords with Scores (KeyBERT): [('bihar', 0.5431), ('road', 0.38), ('construct', 0.3634), ('samastipur', 0.2905), ('ring', 0.2766)]
#
# Speech 184:
# Keywords with Scores (KeyBERT): [('plight', 0.5302), ('farmer', 0.5234), ('maharashtra', 0.5084), ('statement', 0.3351), ('laid', 0.2636)]
#
# Speech 185:
# Keywords with Scores (KeyBERT): [('yojana', 0.4952), ('pradhan', 0.4725), ('pmjay', 0.4092), ('arogya', 0.3401), ('statement', 0.323)]
#
# Speech 186:
# Keywords with Scores (KeyBERT): [('minister', 0.3796), ('president', 0.3547), ('government', 0.3393), ('parliament', 0.32), ('kashmir', 0.3034)]
#
# Speech 187:
# Keywords with Scores (KeyBERT): [('odisha', 0.5257), ('mediation', 0.4544), ('court', 0.4363), ('kalahandi', 0.3357), ('bench', 0.3066)]
#
# Speech 188:
# Keywords with Scores (KeyBERT): [('welfare', 0.4752), ('policy', 0.3651), ('child', 0.318), ('comprehensive', 0.271), ('country', 0.2588)]
#
# Speech 189:
# Keywords with Scores (KeyBERT): [('constitution', 0.4502), ('magahi', 0.379), ('schedule', 0.3529), ('language', 0.3351), ('eighth', 0.2546)]
#
# Speech 190:
# Keywords with Scores (KeyBERT): [('bharat', 0.3432), ('government', 0.3336), ('sabha', 0.3231), ('nidhi', 0.3126), ('parliament', 0.3078)]
#
# Speech 191:
# Keywords with Scores (KeyBERT): [('bharat', 0.4739), ('gandhi', 0.3998), ('rajya', 0.3754), ('india', 0.3537), ('mahatma', 0.3381)]
#
# Speech 192:
# Keywords with Scores (KeyBERT): [('bihar', 0.5807), ('bharat', 0.4462), ('india', 0.3834), ('labour', 0.3462), ('reservation', 0.3327)]
#
# Speech 193:
# Keywords with Scores (KeyBERT): [('bharat', 0.3929), ('ujjwala', 0.3773), ('government', 0.3717), ('yojana', 0.364), ('india', 0.3414)]
#
# Speech 194:
# Keywords with Scores (KeyBERT): [('achievement', 0.3859), ('chandrayaan', 0.3671), ('government', 0.3555), ('wealth', 0.3238), ('country', 0.3138)]
#
# Speech 195:
# Keywords with Scores (KeyBERT): [('odisha', 0.3975), ('kidney', 0.3814), ('treatment', 0.3331), ('hospital', 0.3154), ('health', 0.3085)]
#
# Speech 196:
# Keywords with Scores (KeyBERT): [('advertisement', 0.505), ('ban', 0.3847), ('mockery', 0.3659), ('officer', 0.3339), ('army', 0.3265)]
#
# Speech 197:
# Keywords with Scores (KeyBERT): [('maharashtra', 0.4131), ('savitribai', 0.4098), ('woman', 0.3811), ('phule', 0.3435), ('teacher', 0.2985)]
#
# Speech 198:
# Keywords with Scores (KeyBERT): [('irrigation', 0.4464), ('flood', 0.4027), ('kosimechi', 0.3833), ('river', 0.363), ('araria', 0.3612)]
#
# Speech 199:
# Keywords with Scores (KeyBERT): [('facility', 0.4033), ('clinic', 0.4008), ('medical', 0.3199), ('centre', 0.314), ('pandemic', 0.3044)]
#
# Speech 200:
# Keywords with Scores (KeyBERT): [('airport', 0.5244), ('patna', 0.4135), ('raxaul', 0.4099), ('delhi', 0.378), ('bihar', 0.3393)]
#
# Speech 201:
# Keywords with Scores (KeyBERT): [('constituency', 0.4878), ('salempur', 0.4717), ('parliamentary', 0.3734), ('provision', 0.2999), ('government', 0.2801)]
#
# Speech 202:
# Keywords with Scores (KeyBERT): [('doping', 0.5382), ('olympics', 0.4785), ('medal', 0.4236), ('sport', 0.4185), ('drug', 0.3726)]
#
# Speech 203:
# Keywords with Scores (KeyBERT): [('embankment', 0.408), ('agricultural', 0.3864), ('flood', 0.3756), ('district', 0.3642), ('farmland', 0.3592)]
#
# Speech 204:
# Keywords with Scores (KeyBERT): [('railway', 0.4687), ('baran', 0.4279), ('rail', 0.4272), ('delhisogaria', 0.4201), ('delhi', 0.4025)]
#
# Speech 205:
# Keywords with Scores (KeyBERT): [('metro', 0.4331), ('mumbai', 0.4115), ('corridor', 0.3634), ('construction', 0.3621), ('anvil', 0.3551)]
#
# Speech 206:
# Keywords with Scores (KeyBERT): [('doping', 0.5652), ('sportspersons', 0.4183), ('sportsperson', 0.4033), ('athlete', 0.3936), ('sporting', 0.3926)]
#
# Speech 207:
# Keywords with Scores (KeyBERT): [('odisha', 0.4034), ('crore', 0.3738), ('mnregs', 0.3682), ('fund', 0.3639), ('development', 0.3105)]
#
# Speech 208:
# Keywords with Scores (KeyBERT): [('vidyalayas', 0.5239), ('balrampur', 0.4191), ('admission', 0.3982), ('hostel', 0.3777), ('shrawasti', 0.3734)]
#
# Speech 209:
# Keywords with Scores (KeyBERT): [('flood', 0.3658), ('andhra', 0.3643), ('krmb', 0.3615), ('barrage', 0.3575), ('quota', 0.356)]
#
# Speech 210:
# Keywords with Scores (KeyBERT): [('doping', 0.4272), ('sport', 0.3147), ('committee', 0.3027), ('government', 0.297), ('india', 0.2951)]
#
# Speech 211:
# Keywords with Scores (KeyBERT): [('doping', 0.3878), ('athlete', 0.3438), ('disciplinary', 0.3055), ('committee', 0.2938), ('sportspersons', 0.2928)]
#
# Speech 212:
# Keywords with Scores (KeyBERT): [('government', 0.3574), ('appointed', 0.3405), ('committee', 0.3316), ('minister', 0.3259), ('discrimination', 0.2998)]
#
# Speech 213:
# Keywords with Scores (KeyBERT): [('doping', 0.579), ('olympic', 0.3807), ('athlete', 0.3574), ('sport', 0.3415), ('medal', 0.3131)]
#
# Speech 214:
# Keywords with Scores (KeyBERT): [('doping', 0.3802), ('disciplinary', 0.3224), ('qualification', 0.2847), ('support', 0.2586), ('minister', 0.2518)]
#
# Speech 215:
# Keywords with Scores (KeyBERT): [('minister', 0.3692), ('law', 0.3261), ('doping', 0.3058), ('behalf', 0.2945), ('organisation', 0.2844)]
#
# Speech 216:
# Keywords with Scores (KeyBERT): [('sportspersons', 0.3531), ('abroad', 0.2797), ('minister', 0.271), ('player', 0.2673), ('national', 0.256)]
#
# Speech 217:
# Keywords with Scores (KeyBERT): [('legislation', 0.4881), ('doping', 0.4357), ('violation', 0.3495), ('constitute', 0.3131), ('objected', 0.313)]
#
# Speech 218:
# Keywords with Scores (KeyBERT): [('doping', 0.5039), ('nada', 0.3909), ('athlete', 0.3474), ('sponsored', 0.3379), ('supplement', 0.3034)]
#
# Speech 219:
# Keywords with Scores (KeyBERT): [('bulandshahr', 0.3953), ('district', 0.3929), ('road', 0.3307), ('development', 0.3164), ('traffic', 0.2892)]
#
# Speech 220:
# Keywords with Scores (KeyBERT): [('contractor', 0.4705), ('contractorfirm', 0.4538), ('construction', 0.3917), ('shahjahanpur', 0.3529), ('highlevel', 0.3473)]
#
# Speech 221:
# Keywords with Scores (KeyBERT): [('agneepath', 0.4554), ('madhya', 0.3917), ('pradesh', 0.3876), ('government', 0.3631), ('recruitment', 0.3549)]
#
# Speech 222:
# Keywords with Scores (KeyBERT): [('bihar', 0.4163), ('constituency', 0.3739), ('district', 0.3432), ('agriculture', 0.316), ('sheohar', 0.3002)]
#
# Speech 223:
# Keywords with Scores (KeyBERT): [('ayurveda', 0.584), ('ayurvedic', 0.482), ('yoga', 0.4408), ('herbal', 0.4178), ('bihar', 0.4076)]
#
# Speech 224:
# Keywords with Scores (KeyBERT): [('ahmednagar', 0.5683), ('constituency', 0.3816), ('improvement', 0.3413), ('district', 0.3382), ('road', 0.3297)]
#
# Speech 225:
# Keywords with Scores (KeyBERT): [('groundwater', 0.5693), ('rajasthan', 0.3625), ('bhujal', 0.3408), ('village', 0.3384), ('yojana', 0.3266)]
#
# Speech 226:
# Keywords with Scores (KeyBERT): [('cruelty', 0.4941), ('slaughterhouse', 0.3784), ('meat', 0.3775), ('slaughtered', 0.364), ('animal', 0.3535)]
#
# Speech 227:
# Keywords with Scores (KeyBERT): [('jaipur', 0.5643), ('rajasthan', 0.4723), ('jodhpur', 0.4597), ('airport', 0.428), ('aviation', 0.3423)]
#
# Speech 228:
# Keywords with Scores (KeyBERT): [('dfc', 0.419), ('andhra', 0.3749), ('corridor', 0.3733), ('dfcs', 0.3609), ('freight', 0.3599)]
#
# Speech 229:
# Keywords with Scores (KeyBERT): [('bihar', 0.5045), ('parbat', 0.4995), ('pradesh', 0.4578), ('uttar', 0.4332), ('temple', 0.3856)]
#
# Speech 230:
# Keywords with Scores (KeyBERT): [('dhenkanal', 0.6077), ('kolkata', 0.4146), ('chennai', 0.3467), ('railway', 0.3308), ('odisha', 0.3045)]
#
# Speech 231:
# Keywords with Scores (KeyBERT): [('rajasthan', 0.3659), ('court', 0.3578), ('counselling', 0.3182), ('counsellor', 0.3021), ('justice', 0.2971)]
#
# Speech 232:
# Keywords with Scores (KeyBERT): [('pomegranate', 0.5085), ('pest', 0.4165), ('crop', 0.3282), ('horticulture', 0.3207), ('hectare', 0.3105)]
#
# Speech 233:
# Keywords with Scores (KeyBERT): [('amend', 0.3953), ('court', 0.3949), ('amendment', 0.3883), ('proposed', 0.3873), ('bihar', 0.3294)]
#
# Speech 234:
# Keywords with Scores (KeyBERT): [('judiciary', 0.4635), ('court', 0.4116), ('judge', 0.3608), ('appeal', 0.3584), ('law', 0.3155)]
#
# Speech 235:
# Keywords with Scores (KeyBERT): [('judicial', 0.4595), ('himachal', 0.3601), ('court', 0.3597), ('petition', 0.355), ('legislation', 0.3522)]
#
# Speech 236:
# Keywords with Scores (KeyBERT): [('judiciary', 0.5129), ('judicial', 0.4383), ('parliament', 0.3695), ('himachal', 0.3599), ('pradesh', 0.3544)]
#
# Speech 237:
# Keywords with Scores (KeyBERT): [('judicial', 0.4316), ('court', 0.4007), ('enacting', 0.3563), ('justice', 0.3381), ('law', 0.3212)]
#
# Speech 238:
# Keywords with Scores (KeyBERT): [('enacted', 0.3994), ('court', 0.3918), ('act', 0.386), ('justice', 0.3469), ('judge', 0.3372)]
#
# Speech 239:
# Keywords with Scores (KeyBERT): [('court', 0.4037), ('dowry', 0.3623), ('dispute', 0.3509), ('parent', 0.3314), ('family', 0.331)]
#
# Speech 240:
# Keywords with Scores (KeyBERT): [('parliament', 0.477), ('bihar', 0.4469), ('himachal', 0.4126), ('pradesh', 0.4052), ('jharkhand', 0.3887)]
#
# Speech 241:
# Keywords with Scores (KeyBERT): [('court', 0.4407), ('madhya', 0.326), ('family', 0.2776), ('pradesh', 0.2728), ('act', 0.2537)]
#
# Speech 242:
# Keywords with Scores (KeyBERT): [('counselling', 0.4162), ('court', 0.4127), ('advocate', 0.3608), ('minister', 0.3249), ('providing', 0.268)]
#
# Speech 243:
# Keywords with Scores (KeyBERT): [('minister', 0.3498), ('pradesh', 0.3356), ('court', 0.3156), ('odisha', 0.3138), ('bargarh', 0.3125)]
#
# Speech 244:
# Keywords with Scores (KeyBERT): [('court', 0.4045), ('appeal', 0.3642), ('petition', 0.359), ('filed', 0.3494), ('himachal', 0.314)]
#
# Speech 245:
# Keywords with Scores (KeyBERT): [('court', 0.359), ('support', 0.2698), ('trial', 0.2474), ('amendment', 0.2342), ('minister', 0.225)]
#
# Speech 246:
# Keywords with Scores (KeyBERT): [('gandhinagar', 0.5448), ('fci', 0.4217), ('district', 0.3689), ('constituency', 0.368), ('road', 0.3416)]
#
# Speech 247:
# Keywords with Scores (KeyBERT): [('government', 0.405), ('employee', 0.3798), ('vidyalaya', 0.3352), ('education', 0.3346), ('india', 0.2976)]
#
# Speech 248:
# Keywords with Scores (KeyBERT): [('constituency', 0.3588), ('resumed', 0.3257), ('covid', 0.3223), ('stoppage', 0.3215), ('madhya', 0.3193)]
#
# Speech 249:
# Keywords with Scores (KeyBERT): [('donation', 0.3514), ('donating', 0.3305), ('donate', 0.2972), ('blood', 0.296), ('hospital', 0.2959)]
#
# Speech 250:
# Keywords with Scores (KeyBERT): [('darjeeling', 0.4276), ('tea', 0.3793), ('feudal', 0.3784), ('government', 0.3717), ('land', 0.3672)]
#
# Speech 251:
# Keywords with Scores (KeyBERT): [('jharkhand', 0.575), ('drought', 0.4527), ('rainfall', 0.37), ('district', 0.3505), ('loksabha', 0.3155)]
#
# Speech 252:
# Keywords with Scores (KeyBERT): [('vidyalaya', 0.5014), ('navodaya', 0.4366), ('constituency', 0.4076), ('district', 0.3514), ('banaskantha', 0.3475)]
#
# Speech 253:
# Keywords with Scores (KeyBERT): [('chhattisgarh', 0.3386), ('shakti', 0.3145), ('water', 0.3088), ('implementation', 0.2953), ('scheme', 0.2908)]
#
# Speech 254:
# Keywords with Scores (KeyBERT): [('panchayat', 0.5562), ('displaced', 0.4099), ('compensation', 0.3565), ('displacement', 0.355), ('resettlement', 0.3202)]
#
# Speech 255:
# Keywords with Scores (KeyBERT): [('rainfall', 0.5749), ('drought', 0.5323), ('meteorological', 0.4346), ('rain', 0.4206), ('monsoon', 0.4042)]
#
# Speech 256:
# Keywords with Scores (KeyBERT): [('canal', 0.5074), ('odisha', 0.4542), ('irrigation', 0.3812), ('baleswar', 0.2719), ('agriculture', 0.271)]
#
# Speech 257:
# Keywords with Scores (KeyBERT): [('telangana', 0.3403), ('colliery', 0.3355), ('notice', 0.3044), ('mdo', 0.2794), ('mdos', 0.2715)]
#
# Speech 258:
# Keywords with Scores (KeyBERT): [('recruitment', 0.4402), ('sabha', 0.3928), ('youth', 0.3446), ('constituency', 0.3233), ('eligible', 0.3174)]
#
# Speech 259:
# Keywords with Scores (KeyBERT): [('bihar', 0.4708), ('haryana', 0.4032), ('demand', 0.3957), ('labourer', 0.3785), ('minister', 0.35)]
#
# Speech 260:
# Keywords with Scores (KeyBERT): [('constituency', 0.402), ('bharatmala', 0.398), ('coastline', 0.3977), ('project', 0.3503), ('india', 0.3405)]
#
# Speech 261:
# Keywords with Scores (KeyBERT): [('bihtaaurangabad', 0.5165), ('bihta', 0.4976), ('rail', 0.4757), ('railway', 0.4729), ('jharkhand', 0.4559)]
#
# Speech 262:
# Keywords with Scores (KeyBERT): [('biswanath', 0.6088), ('delhidibrugarh', 0.4686), ('assam', 0.4569), ('delhinaharlagun', 0.447), ('delhi', 0.4415)]
#
# Speech 263:
# Keywords with Scores (KeyBERT): [('antarctica', 0.4977), ('continent', 0.3751), ('treaty', 0.3572), ('agreement', 0.3023), ('bharati', 0.288)]
#
# Speech 264:
# Keywords with Scores (KeyBERT): [('bharat', 0.3829), ('funding', 0.3228), ('management', 0.3184), ('implementing', 0.3153), ('waste', 0.307)]
#
# Speech 265:
# Keywords with Scores (KeyBERT): [('fertilizer', 0.554), ('subsidy', 0.4771), ('chhattisgarh', 0.3457), ('farmer', 0.3228), ('dap', 0.2934)]
#
# Speech 266:
# Keywords with Scores (KeyBERT): [('agriculture', 0.6003), ('agricultural', 0.5348), ('sector', 0.3808), ('produce', 0.3771), ('technology', 0.3656)]
#
# Speech 267:
# Keywords with Scores (KeyBERT): [('rajasthan', 0.4598), ('kanhaiya', 0.4283), ('murder', 0.4137), ('daawateislami', 0.3866), ('udaipur', 0.3634)]
#
# Speech 268:
# Keywords with Scores (KeyBERT): [('railway', 0.4777), ('karnataka', 0.4133), ('constituency', 0.3643), ('maharashtra', 0.3643), ('proposal', 0.3526)]
#
# Speech 269:
# Keywords with Scores (KeyBERT): [('krishna', 0.5479), ('mahabharata', 0.4542), ('arjuna', 0.4464), ('gita', 0.4345), ('jayanti', 0.3608)]
#
# Speech 270:
# Keywords with Scores (KeyBERT): [('railway', 0.4886), ('jodhpur', 0.4551), ('yeshwantpur', 0.4417), ('gandhidham', 0.431), ('jaipur', 0.427)]
#
# Speech 271:
# Keywords with Scores (KeyBERT): [('instrument', 0.4804), ('manufacturing', 0.4501), ('industry', 0.4172), ('china', 0.4046), ('ambala', 0.3771)]
#
# Speech 272:
# Keywords with Scores (KeyBERT): [('agriculture', 0.51), ('irrigation', 0.4005), ('sector', 0.3759), ('constituency', 0.3612), ('india', 0.3448)]
#
# Speech 273:
# Keywords with Scores (KeyBERT): [('patna', 0.6313), ('constituency', 0.4952), ('district', 0.4465), ('krishi', 0.3497), ('parliamentary', 0.337)]
#
# Speech 274:
# Keywords with Scores (KeyBERT): [('pradesh', 0.4609), ('banjara', 0.4514), ('tribe', 0.425), ('category', 0.3999), ('uttar', 0.3934)]
#
# Speech 275:
# Keywords with Scores (KeyBERT): [('csr', 0.483), ('panipat', 0.3808), ('constituency', 0.3725), ('karnal', 0.3444), ('expenditure', 0.3173)]
#
# Speech 276:
# Keywords with Scores (KeyBERT): [('expressway', 0.5384), ('constituency', 0.4725), ('highway', 0.4157), ('road', 0.3917), ('raipur', 0.3841)]
#
# Speech 277:
# Keywords with Scores (KeyBERT): [('textile', 0.4689), ('incentive', 0.3916), ('sector', 0.3557), ('pli', 0.3529), ('fiber', 0.3281)]
#
# Speech 278:
# Keywords with Scores (KeyBERT): [('vasai', 0.395), ('virar', 0.3645), ('population', 0.336), ('lakh', 0.3208), ('city', 0.3026)]
#
# Speech 279:
# Keywords with Scores (KeyBERT): [('vidyalayas', 0.5512), ('navodaya', 0.4111), ('teacher', 0.341), ('pension', 0.3105), ('village', 0.3021)]
#
# Speech 280:
# Keywords with Scores (KeyBERT): [('railway', 0.5319), ('trainslocal', 0.4586), ('train', 0.4473), ('demand', 0.3593), ('station', 0.3495)]
#
# Speech 281:
# Keywords with Scores (KeyBERT): [('electricity', 0.468), ('delhi', 0.427), ('transformer', 0.3547), ('power', 0.3169), ('sector', 0.3053)]
#
# Speech 282:
# Keywords with Scores (KeyBERT): [('irrigation', 0.5809), ('gujarat', 0.4612), ('cultivation', 0.4334), ('farm', 0.3913), ('canal', 0.3905)]
#
# Speech 283:
# Keywords with Scores (KeyBERT): [('chhattisgarh', 0.4459), ('development', 0.3867), ('develop', 0.3725), ('school', 0.3345), ('infrastructure', 0.3227)]
#
# Speech 284:
# Keywords with Scores (KeyBERT): [('railway', 0.4568), ('ramganjmandi', 0.4498), ('departmental', 0.3471), ('minister', 0.3258), ('project', 0.3021)]
#
# Speech 285:
# Keywords with Scores (KeyBERT): [('minister', 0.4323), ('road', 0.4255), ('highway', 0.4122), ('traffic', 0.3577), ('savarkundlaamrelivadiajetpur', 0.3266)]
#
# Speech 286:
# Keywords with Scores (KeyBERT): [('kishangarhajmer', 0.528), ('kishangarh', 0.5071), ('airport', 0.4874), ('ahmedabadhyderabadindoresurat', 0.4665), ('delhi', 0.403)]
#
# Speech 287:
# Keywords with Scores (KeyBERT): [('bihar', 0.4843), ('constituency', 0.4334), ('parliamentary', 0.3579), ('highway', 0.3432), ('road', 0.3378)]
#
# Speech 288:
# Keywords with Scores (KeyBERT): [('caste', 0.428), ('lohara', 0.3633), ('tribe', 0.3527), ('lohar', 0.3522), ('hindi', 0.3479)]
#
# Speech 289:
# Keywords with Scores (KeyBERT): [('imc', 0.4272), ('integrated', 0.4213), ('proposal', 0.4044), ('nicdc', 0.3865), ('jharkhand', 0.3826)]
#
# Speech 290:
# Keywords with Scores (KeyBERT): [('constituency', 0.5442), ('parliamentary', 0.4944), ('maharajganj', 0.4265), ('sabha', 0.41), ('janatabazar', 0.4075)]
#
# Speech 291:
# Keywords with Scores (KeyBERT): [('agricultural', 0.5033), ('farmer', 0.4365), ('rainfall', 0.3822), ('crop', 0.3733), ('pradhan', 0.3565)]
#
# Speech 292:
# Keywords with Scores (KeyBERT): [('constituency', 0.5746), ('parliamentary', 0.4863), ('lohardaga', 0.3902), ('sportspersons', 0.2549), ('rural', 0.2537)]
#
# Speech 293:
# Keywords with Scores (KeyBERT): [('welfare', 0.4298), ('crore', 0.4103), ('bharat', 0.3721), ('poor', 0.3697), ('health', 0.3553)]
#
# Speech 294:
# Keywords with Scores (KeyBERT): [('provision', 0.4488), ('demand', 0.3967), ('farming', 0.3811), ('pradesh', 0.3553), ('madhya', 0.3253)]
#
# Speech 295:
# Keywords with Scores (KeyBERT): [('deoghar', 0.5271), ('jharkahand', 0.3183), ('recruitment', 0.3126), ('india', 0.3115), ('tourist', 0.286)]
#
# Speech 296:
# Keywords with Scores (KeyBERT): [('rajasthan', 0.4872), ('indira', 0.4797), ('ganganagar', 0.4434), ('irrigation', 0.4428), ('haryana', 0.4425)]
#
# Speech 297:
# Keywords with Scores (KeyBERT): [('jute', 0.4056), ('worker', 0.3878), ('textile', 0.3725), ('industry', 0.3704), ('bureaucracy', 0.365)]
#
# Speech 298:
# Keywords with Scores (KeyBERT): [('paddy', 0.4371), ('farmer', 0.3615), ('negligence', 0.3297), ('chhattisgarh', 0.3163), ('cooperative', 0.3049)]
#
# Speech 299:
# Keywords with Scores (KeyBERT): [('lalitpursingrauli', 0.5689), ('rail', 0.4961), ('constituency', 0.4647), ('railless', 0.4137), ('parliamentary', 0.3808)]
#
# Speech 300:
# Keywords with Scores (KeyBERT): [('jharkhand', 0.5917), ('poshan', 0.5076), ('sakhi', 0.4327), ('dhanbad', 0.4177), ('district', 0.4156)]
#
# Speech 301:
# Keywords with Scores (KeyBERT): [('constituency', 0.493), ('irrigation', 0.4494), ('parliamentary', 0.4299), ('rajasthan', 0.4245), ('minister', 0.3772)]
#
# Speech 302:
# Keywords with Scores (KeyBERT): [('fencing', 0.4326), ('jammu', 0.3942), ('kashmir', 0.3894), ('farmer', 0.3681), ('compensation', 0.3232)]
#
# Speech 303:
# Keywords with Scores (KeyBERT): [('disarmament', 0.4574), ('nuclear', 0.4438), ('treaty', 0.378), ('proliferation', 0.3523), ('country', 0.3069)]
#
# Speech 304:
# Keywords with Scores (KeyBERT): [('andhra', 0.44), ('pradesh', 0.3808), ('renamed', 0.3541), ('minister', 0.3071), ('government', 0.2925)]
#
# Speech 305:
# Keywords with Scores (KeyBERT): [('potatogrowing', 0.3952), ('potato', 0.3434), ('bengal', 0.3352), ('produce', 0.3227), ('sector', 0.313)]
#
# Speech 306:
# Keywords with Scores (KeyBERT): [('constituency', 0.4491), ('vups', 0.4376), ('parliamentary', 0.4108), ('widening', 0.3761), ('lane', 0.3624)]
#
# Speech 307:
# Keywords with Scores (KeyBERT): [('disarmament', 0.3645), ('obligation', 0.3441), ('nuclear', 0.3367), ('financing', 0.2938), ('deterrence', 0.2878)]
#
# Speech 308:
# Keywords with Scores (KeyBERT): [('nuclear', 0.3975), ('licence', 0.3818), ('ganganagar', 0.2835), ('crore', 0.2809), ('license', 0.28)]
#
# Speech 309:
# Keywords with Scores (KeyBERT): [('airport', 0.4949), ('belagavigorakhpur', 0.4752), ('belgaum', 0.4166), ('karnataka', 0.4039), ('belagavibangalore', 0.3448)]
#
# Speech 310:
# Keywords with Scores (KeyBERT): [('government', 0.3904), ('amended', 0.39), ('amendment', 0.3605), ('terrorist', 0.3398), ('support', 0.3287)]
#
# Speech 311:
# Keywords with Scores (KeyBERT): [('government', 0.3583), ('nuclear', 0.3464), ('proliferationrelevant', 0.3387), ('technology', 0.3367), ('designation', 0.3298)]
#
# Speech 312:
# ...
#
# Speech 1086:
# Keywords with Scores (KeyBERT): [('mumbai', 0.4107), ('bhavan', 0.4023), ('maharashtra', 0.3765), ('application', 0.3724), ('requirement', 0.3333)]
#
# Speech 1087:
# Keywords with Scores (KeyBERT): [('unemployment', 0.5318), ('unemployed', 0.432), ('assam', 0.4019), ('government', 0.2975), ('claiming', 0.2848)]
#
# Speech 1088:
# Keywords with Scores (KeyBERT): [('andhra', 0.3778), ('pradesh', 0.3684), ('government', 0.3533), ('crore', 0.3193), ('minister', 0.3085)]
#
# Speech 1089:
# Keywords with Scores (KeyBERT): [('agriculture', 0.4068), ('pandit', 0.3833), ('agricultural', 0.3727), ('bharat', 0.3614), ('ujjwala', 0.3525)]
#
# Speech 1090:
# Keywords with Scores (KeyBERT): [('diversity', 0.4208), ('india', 0.4107), ('gst', 0.3285), ('swaminathan', 0.3187), ('sector', 0.3107)]
#
# Speech 1091:
# Keywords with Scores (KeyBERT): [('bharat', 0.3989), ('development', 0.3859), ('government', 0.3665), ('pradhan', 0.3598), ('ujjawala', 0.3582)]
#
# Speech 1092:
# Keywords with Scores (KeyBERT): [('gujarat', 0.409), ('taluk', 0.3909), ('bharat', 0.3626), ('gangapur', 0.3451), ('yojana', 0.328)]
#
# Speech 1093:
# Keywords with Scores (KeyBERT): [('government', 0.3768), ('welfare', 0.3744), ('gdp', 0.3562), ('healthcare', 0.338), ('odisha', 0.3334)]
#
# Speech 1094:
# Keywords with Scores (KeyBERT): [('corruption', 0.4417), ('crore', 0.3466), ('government', 0.3431), ('scam', 0.3376), ('sardha', 0.3286)]
#
# Speech 1095:
# Keywords with Scores (KeyBERT): [('government', 0.44), ('welfare', 0.3206), ('safeguarded', 0.3056), ('caste', 0.2917), ('session', 0.2803)]
#
# Speech 1096:
# Keywords with Scores (KeyBERT): [('bharat', 0.4143), ('prakash', 0.377), ('crore', 0.3626), ('conferred', 0.3455), ('gurunanak', 0.3418)]
#
# Speech 1097:
# Keywords with Scores (KeyBERT): [('scheme', 0.3522), ('crore', 0.3462), ('lakh', 0.3398), ('bharat', 0.3383), ('government', 0.3341)]
#
# Speech 1098:
# Keywords with Scores (KeyBERT): [('agricultural', 0.3407), ('bharat', 0.3289), ('ujjwala', 0.3228), ('yojana', 0.3136), ('crore', 0.3109)]
#
# Speech 1099:
# Keywords with Scores (KeyBERT): [('lakh', 0.3639), ('crore', 0.3585), ('ujjwala', 0.3456), ('yojana', 0.34), ('income', 0.3181)]
#
# Speech 1100:
# Keywords with Scores (KeyBERT): [('government', 0.4532), ('pandit', 0.4316), ('india', 0.4027), ('uppaddhayajis', 0.3888), ('sabka', 0.378)]
#
# Speech 1101:
# Keywords with Scores (KeyBERT): [('demonetisation', 0.4105), ('government', 0.3625), ('president', 0.3416), ('operational', 0.3286), ('airport', 0.3093)]
#
# Speech 1102:
# Keywords with Scores (KeyBERT): [('government', 0.4404), ('ujjawala', 0.3732), ('yojana', 0.37), ('crore', 0.3557), ('farmer', 0.3556)]
#
# Speech 1103:
# Keywords with Scores (KeyBERT): [('government', 0.3792), ('ujjwala', 0.3636), ('crore', 0.353), ('gst', 0.3186), ('pradhan', 0.3149)]
#
# Speech 1104:
# Keywords with Scores (KeyBERT): [('caste', 0.4358), ('farmer', 0.3908), ('reservation', 0.3571), ('provision', 0.3416), ('agro', 0.3252)]
#
# Speech 1105:
# Keywords with Scores (KeyBERT): [('kashmir', 0.4277), ('pakistan', 0.3998), ('government', 0.38), ('india', 0.3627), ('taliban', 0.3575)]
#
# Speech 1106:
# Keywords with Scores (KeyBERT): [('government', 0.403), ('minister', 0.363), ('ujjwala', 0.3588), ('president', 0.3461), ('crore', 0.3301)]
#
# Speech 1107:
# Keywords with Scores (KeyBERT): [('government', 0.3326), ('welfare', 0.3071), ('crore', 0.3023), ('yojana', 0.2962), ('gdp', 0.289)]
#
# Speech 1108:
# Keywords with Scores (KeyBERT): [('bjp', 0.4533), ('government', 0.3851), ('development', 0.3512), ('agriculture', 0.3412), ('modi', 0.3252)]
#
# Speech 1109:
# Keywords with Scores (KeyBERT): [('prosperity', 0.4208), ('government', 0.3776), ('economy', 0.3379), ('success', 0.3336), ('infrastructure', 0.3333)]
#
# Speech 1110:
# Keywords with Scores (KeyBERT): [('bsnl', 0.5369), ('telecom', 0.4999), ('provider', 0.4242), ('airtel', 0.4088), ('govt', 0.3365)]
#
# Speech 1111:
# Keywords with Scores (KeyBERT): [('government', 0.4689), ('challenge', 0.4329), ('empowerment', 0.3937), ('progress', 0.387), ('welfare', 0.35)]
#
# Speech 1112:
# Keywords with Scores (KeyBERT): [('minister', 0.4131), ('kheradkanpur', 0.3685), ('constituency', 0.3646), ('government', 0.3645), ('parliamentary', 0.353)]
#
# Speech 1113:
# Keywords with Scores (KeyBERT): [('jammu', 0.396), ('ujjwala', 0.3943), ('government', 0.379), ('bharat', 0.3769), ('constituency', 0.3699)]
#
# Speech 1114:
# Keywords with Scores (KeyBERT): [('india', 0.3339), ('president', 0.3078), ('development', 0.3025), ('government', 0.2949), ('visionary', 0.2901)]
#
# Speech 1115:
# Keywords with Scores (KeyBERT): [('gandhi', 0.4092), ('bharati', 0.4091), ('telangana', 0.3957), ('bharat', 0.3945), ('odisha', 0.3837)]
#
# Speech 1116:
# Keywords with Scores (KeyBERT): [('gandhi', 0.5268), ('mahatma', 0.4756), ('bjp', 0.3879), ('mandir', 0.3801), ('mahasabha', 0.3682)]
#
# Speech 1117:
# Keywords with Scores (KeyBERT): [('ujjwala', 0.4432), ('yojana', 0.4233), ('pension', 0.3594), ('bharat', 0.3311), ('pardhis', 0.3274)]
#
# Speech 1118:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4115), ('ujjwala', 0.3647), ('bharat', 0.3636), ('yojana', 0.3351), ('crore', 0.3281)]
#
# Speech 1119:
# Keywords with Scores (KeyBERT): [('bharat', 0.3572), ('welfare', 0.354), ('demonetisation', 0.3417), ('government', 0.3368), ('ujjwala', 0.3319)]
#
# Speech 1120:
# Keywords with Scores (KeyBERT): [('monorail', 0.4952), ('bhubaneswar', 0.3556), ('odisha', 0.3478), ('paika', 0.3194), ('capital', 0.3163)]
#
# Speech 1121:
# Keywords with Scores (KeyBERT): [('odisha', 0.4975), ('bhubaneswar', 0.4237), ('paika', 0.3688), ('airport', 0.3353), ('paradip', 0.3321)]
#
# Speech 1122:
# Keywords with Scores (KeyBERT): [('bharat', 0.3847), ('crore', 0.3601), ('ujjwala', 0.3511), ('india', 0.3296), ('yojana', 0.3253)]
#
# Speech 1123:
# Keywords with Scores (KeyBERT): [('welfare', 0.4561), ('empowerment', 0.4206), ('government', 0.3766), ('castesscheduled', 0.355), ('deprived', 0.327)]
#
# Speech 1124:
# Keywords with Scores (KeyBERT): [('government', 0.3951), ('minister', 0.3744), ('development', 0.3597), ('corruption', 0.3172), ('education', 0.3081)]
#
# Speech 1125:
# Keywords with Scores (KeyBERT): [('agriculture', 0.3989), ('unemployment', 0.3402), ('gdp', 0.3304), ('pradesh', 0.3271), ('government', 0.3093)]
#
# Speech 1126:
# Keywords with Scores (KeyBERT): [('demonetisation', 0.3947), ('aadhaar', 0.3616), ('minister', 0.3597), ('government', 0.3502), ('crore', 0.326)]
#
# Speech 1127:
# Keywords with Scores (KeyBERT): [('pradesh', 0.391), ('reservation', 0.3796), ('caste', 0.3794), ('government', 0.3719), ('uttar', 0.3361)]
#
# Speech 1128:
# Keywords with Scores (KeyBERT): [('aadhaar', 0.3321), ('yojana', 0.3045), ('government', 0.2933), ('ujjwala', 0.2857), ('india', 0.2742)]
#
# Speech 1129:
# Keywords with Scores (KeyBERT): [('bharat', 0.4407), ('yojana', 0.3972), ('ujjwala', 0.3911), ('government', 0.383), ('crore', 0.3772)]
#
# Speech 1130:
# Keywords with Scores (KeyBERT): [('constituency', 0.3766), ('minister', 0.3708), ('bharat', 0.3703), ('government', 0.361), ('parliamentary', 0.3441)]
#
# Speech 1131:
# Keywords with Scores (KeyBERT): [('government', 0.4151), ('parliamentary', 0.3583), ('demonetisation', 0.3345), ('legislation', 0.3334), ('pradesh', 0.3283)]
#
# Speech 1132:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4783), ('mahatma', 0.4146), ('gandhi', 0.4057), ('bharat', 0.4031), ('ujjawala', 0.3973)]
#
# Speech 1133:
# Keywords with Scores (KeyBERT): [('pension', 0.3877), ('taxpayer', 0.3783), ('income', 0.3717), ('lakh', 0.3587), ('crore', 0.354)]
#
# Speech 1134:
# Keywords with Scores (KeyBERT): [('government', 0.4317), ('governance', 0.4083), ('mandate', 0.3786), ('bharat', 0.3483), ('caste', 0.3217)]
#
# Speech 1135:
# Keywords with Scores (KeyBERT): [('panchayat', 0.4348), ('rajasthan', 0.3722), ('bharat', 0.3393), ('crore', 0.3048), ('ganganagar', 0.2944)]
#
# Speech 1136:
# Keywords with Scores (KeyBERT): [('minister', 0.4309), ('government', 0.4276), ('assam', 0.4025), ('initiativesprogrammes', 0.369), ('development', 0.336)]
#
# Speech 1137:
# Keywords with Scores (KeyBERT): [('panchayat', 0.464), ('bjp', 0.3813), ('development', 0.3775), ('india', 0.3338), ('developed', 0.3146)]
#
# Speech 1138:
# Keywords with Scores (KeyBERT): [('minister', 0.4265), ('nagar', 0.415), ('crore', 0.4133), ('constituency', 0.4015), ('ujjawala', 0.386)]
#
# Speech 1139:
# Keywords with Scores (KeyBERT): [('bharat', 0.4045), ('government', 0.3346), ('reservation', 0.3268), ('president', 0.3252), ('india', 0.3246)]
#
# Speech 1140:
# Keywords with Scores (KeyBERT): [('bharat', 0.4451), ('bihar', 0.3984), ('compulsory', 0.3743), ('ujjawala', 0.349), ('government', 0.3489)]
#
# Speech 1141:
# Keywords with Scores (KeyBERT): [('technology', 0.4135), ('dna', 0.3597), ('future', 0.3113), ('minister', 0.2824), ('chairman', 0.2769)]
#
# Speech 1142:
# Keywords with Scores (KeyBERT): [('justice', 0.3872), ('law', 0.375), ('criminal', 0.3392), ('civil', 0.326), ('authority', 0.325)]
#
# Speech 1143:
# Keywords with Scores (KeyBERT): [('minister', 0.4267), ('magistrate', 0.3579), ('databank', 0.3128), ('politician', 0.3111), ('dna', 0.3026)]
#
# Speech 1144:
# Keywords with Scores (KeyBERT): [('reservation', 0.4748), ('bihar', 0.4151), ('constitution', 0.3711), ('proposal', 0.3663), ('unconstitutional', 0.3461)]
#
# Speech 1145:
# Keywords with Scores (KeyBERT): [('sikkim', 0.5433), ('tamang', 0.4065), ('approval', 0.3545), ('status', 0.341), ('support', 0.3262)]
#
# Speech 1146:
# Keywords with Scores (KeyBERT): [('unanimously', 0.5131), ('consensus', 0.4832), ('parliamentary', 0.4385), ('committee', 0.4376), ('amendment', 0.3269)]
#
# Speech 1147:
# Keywords with Scores (KeyBERT): [('constitution', 0.3838), ('amendment', 0.3821), ('reservation', 0.3414), ('castesscheduled', 0.331), ('clause', 0.2815)]
#
# Speech 1148:
# Keywords with Scores (KeyBERT): [('assam', 0.4725), ('assamese', 0.4062), ('migrant', 0.3848), ('bangladeshi', 0.3789), ('bangladesh', 0.3443)]
#
# Speech 1149:
# Keywords with Scores (KeyBERT): [('citizenship', 0.4172), ('caste', 0.3851), ('hindu', 0.3802), ('migrant', 0.3725), ('assam', 0.3574)]
#
# Speech 1150:
# Keywords with Scores (KeyBERT): [('development', 0.3513), ('facility', 0.3392), ('farmer', 0.3145), ('ensure', 0.2966), ('india', 0.2875)]
#
# Speech 1151:
# Keywords with Scores (KeyBERT): [('assam', 0.4442), ('oppose', 0.4023), ('constitution', 0.3754), ('discriminate', 0.2835), ('violation', 0.2209)]
#
# Speech 1152:
# Keywords with Scores (KeyBERT): [('assam', 0.4724), ('assamese', 0.3809), ('safeguard', 0.3328), ('indigenous', 0.2892), ('bangladeshi', 0.2684)]
#
# Speech 1153:
# Keywords with Scores (KeyBERT): [('reservation', 0.4704), ('caste', 0.4305), ('oppose', 0.4159), ('amendment', 0.4005), ('dalits', 0.3535)]
#
# Speech 1154:
# Keywords with Scores (KeyBERT): [('discrimination', 0.4079), ('reservation', 0.376), ('constitution', 0.3639), ('telangana', 0.3608), ('oppression', 0.3512)]
#
# Speech 1155:
# Keywords with Scores (KeyBERT): [('reservation', 0.4772), ('compulsory', 0.4452), ('education', 0.4059), ('caste', 0.3804), ('committee', 0.3445)]
#
# Speech 1156:
# Keywords with Scores (KeyBERT): [('assam', 0.4694), ('bangladesh', 0.4351), ('india', 0.4216), ('hindu', 0.3608), ('western', 0.3405)]
#
# Speech 1157:
# Keywords with Scores (KeyBERT): [('hindu', 0.4061), ('citizenship', 0.4045), ('rise', 0.3892), ('nehruliyakat', 0.3537), ('pakistan', 0.3471)]
#
# Speech 1158:
# Keywords with Scores (KeyBERT): [('unemployment', 0.4208), ('government', 0.3989), ('amendment', 0.3578), ('constitution', 0.3489), ('unemployed', 0.3335)]
#
# Speech 1159:
# Keywords with Scores (KeyBERT): [('reservation', 0.4646), ('caste', 0.3905), ('amendment', 0.3815), ('constitutional', 0.363), ('provision', 0.3111)]
#
# Speech 1160:
# Keywords with Scores (KeyBERT): [('constitution', 0.4206), ('parliamentary', 0.3997), ('amendment', 0.3876), ('reservation', 0.3609), ('government', 0.3472)]
#
# Speech 1161:
# Keywords with Scores (KeyBERT): [('reservation', 0.3589), ('passed', 0.3439), ('government', 0.3422), ('urgency', 0.3268), ('party', 0.3052)]
#
# Speech 1162:
# Keywords with Scores (KeyBERT): [('amendment', 0.4294), ('constitution', 0.4104), ('reservation', 0.3697), ('government', 0.3673), ('behalf', 0.3636)]
#
# Speech 1163:
# Keywords with Scores (KeyBERT): [('caste', 0.4126), ('bihari', 0.3925), ('government', 0.3594), ('reservation', 0.358), ('amendment', 0.3359)]
#
# Speech 1164:
# Keywords with Scores (KeyBERT): [('reservation', 0.4289), ('caste', 0.423), ('protest', 0.4129), ('modi', 0.378), ('ji', 0.3558)]
#
# Speech 1165:
# Keywords with Scores (KeyBERT): [('amended', 0.4342), ('bjp', 0.4257), ('reservation', 0.3732), ('constitution', 0.3501), ('introduced', 0.2794)]
#
# Speech 1166:
# Keywords with Scores (KeyBERT): [('reservation', 0.5527), ('caste', 0.3525), ('economic', 0.2764), ('prosperity', 0.2746), ('provision', 0.272)]
#
# Speech 1167:
# Keywords with Scores (KeyBERT): [('policy', 0.3754), ('manifesto', 0.3535), ('government', 0.315), ('constitution', 0.3059), ('theory', 0.3054)]
#
# Speech 1168:
# Keywords with Scores (KeyBERT): [('reservation', 0.5453), ('amendment', 0.4786), ('constitution', 0.477), ('government', 0.4035), ('admission', 0.3264)]
#
# Speech 1169:
# Keywords with Scores (KeyBERT): [('government', 0.4424), ('reservation', 0.4153), ('caste', 0.4016), ('committee', 0.3704), ('constitution', 0.3575)]
#
# Speech 1170:
# Keywords with Scores (KeyBERT): [('reservation', 0.5739), ('demand', 0.3871), ('opposition', 0.3788), ('decision', 0.3607), ('saheb', 0.3461)]
#
# Speech 1171:
# Keywords with Scores (KeyBERT): [('dream', 0.4208), ('reservation', 0.3368), ('development', 0.3229), ('translated', 0.3145), ('wake', 0.3136)]
#
# Speech 1172:
# Keywords with Scores (KeyBERT): [('judiciary', 0.4676), ('government', 0.4155), ('constitution', 0.404), ('caste', 0.4019), ('amendment', 0.3724)]
#
# Speech 1173:
# Keywords with Scores (KeyBERT): [('leprosy', 0.5572), ('cured', 0.3638), ('medicine', 0.3212), ('divorce', 0.3047), ('curable', 0.2922)]
#
# Speech 1174:
# Keywords with Scores (KeyBERT): [('oppose', 0.4529), ('government', 0.3899), ('islamic', 0.3781), ('islam', 0.3666), ('marriage', 0.3658)]
#
# Speech 1175:
# Keywords with Scores (KeyBERT): [('rafale', 0.4521), ('government', 0.3216), ('jet', 0.3177), ('constitution', 0.2986), ('fighter', 0.2867)]
#
# Speech 1176:
# Keywords with Scores (KeyBERT): [('auditor', 0.3522), ('court', 0.3399), ('pricing', 0.3301), ('reliance', 0.3147), ('arun', 0.3122)]
#
# Speech 1177:
# Keywords with Scores (KeyBERT): [('rafale', 0.4551), ('crore', 0.3546), ('jpc', 0.3435), ('aircraft', 0.323), ('secretary', 0.2768)]
#
# Speech 1178:
# Keywords with Scores (KeyBERT): [('opposition', 0.4013), ('congress', 0.359), ('government', 0.3462), ('agreement', 0.3239), ('political', 0.2798)]
#
# Speech 1179:
# Keywords with Scores (KeyBERT): [('government', 0.4406), ('constitution', 0.4294), ('regulation', 0.416), ('opposition', 0.3914), ('court', 0.3642)]
#
# Speech 1180:
# Keywords with Scores (KeyBERT): [('aircraft', 0.466), ('aviation', 0.438), ('rafale', 0.4297), ('government', 0.3759), ('contract', 0.3379)]
#
# Speech 1181:
# Keywords with Scores (KeyBERT): [('congress', 0.5072), ('rafale', 0.3765), ('government', 0.3635), ('aircraft', 0.343), ('squadron', 0.3351)]
#
# Speech 1182:
# Keywords with Scores (KeyBERT): [('aadhaar', 0.607), ('provision', 0.3097), ('welfare', 0.3029), ('proposed', 0.289), ('amendment', 0.2819)]
#
# Speech 1183:
# Keywords with Scores (KeyBERT): [('aadhaar', 0.5766), ('welfare', 0.3132), ('enrolled', 0.3086), ('provision', 0.3027), ('enroll', 0.2709)]
#
# Speech 1184:
# Keywords with Scores (KeyBERT): [('aadhaar', 0.495), ('aadhaarbased', 0.4758), ('court', 0.3806), ('judgment', 0.3429), ('supreme', 0.3155)]
#
# Speech 1185:
# Keywords with Scores (KeyBERT): [('rafale', 0.3786), ('congress', 0.3575), ('discussed', 0.3316), ('aircraft', 0.33), ('government', 0.3238)]
#
# Speech 1186:
# Keywords with Scores (KeyBERT): [('government', 0.4091), ('parliament', 0.36), ('minister', 0.3132), ('reliance', 0.2962), ('cag', 0.2866)]
#
# Speech 1187:
# Keywords with Scores (KeyBERT): [('aircraft', 0.3833), ('demand', 0.3584), ('negotiation', 0.3103), ('government', 0.2908), ('minister', 0.2716)]
