# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("modified_dataset.csv")

# %%
df.head(5)
# Out:
#                           Speaker  \
# 0  0            SHRI GAURAV GOGOI
# 1  1     SHRI MADDILA GURUMOORTHY
# 2  2          SHRI RAMPRIT MANDAL
# 3  3  SHRI PRATAP CHANDRA SARANGI
# 4  5            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category
# ...

# %%
df.columns
# Out:
# Index([' ', 'Speaker', 'Speech', 'Date', 'Type', 'Gender', 'Party',
#        'Category'],
#       dtype='object')

# %%
df = df.drop(' ', axis=1)

# %%
df.head(5)
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category
# 0            Issue
# ...

# %%
len(df)
# Out:
# 1495

# %%
df["Speech"] = df["Speech"].str.replace('\n',' ')

# %%
df.head(5)
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category
# 0            Issue
# ...

# %%
df.shape
# Out:
# (1495, 7)

# %%
df = df.dropna(subset=['Speech'])

# %%
df.shape
# Out:
# (1495, 7)

# %%
df.loc[0, "Speech"]
# Out:
# "This is a country characterised by devotion. This  country is a country of faith. In this country, we bind our diversity with goodwill  and cherish the society with a sense of service. Lord Rama belongs to everyone and  he is with us all the time. When we meet each other, we exchange greetings by saying  'Ram-Ram' in North India or Western India. What is Mahatma Gandhi's definition  of Ram Rajya? Where everyone is happy and no one is sad, this is his definition.  Gandhi ji has also said that his Hindu dharma teaches him to respect all religions,  the secret of Ram Rajya is inherent in this definition. We should ponder whether all  the backward, deprived and minorities are happy, this was the definition of Ram  Rajya by Mahatma Gandhi. But today we are seeing that crimes against Scheduled  Castes and Scheduled Tribes are on the rise. If we compare it with the year gone by,  crime has gone up by around 50 percent in the year 2023. Is this Ram Rajya? Today  the backward classes are dem
# ...

# %%
df.nunique()
# Out:
# Speaker      408
# Speech      1495
# Date          68
# Type           2
# Gender         2
# Party         34
# Category       5
# dtype: int64

# %%
df['Party'].unique()
# Out:
# array(['Congress', 'YSR Congress', 'JDU', 'BJP', 'BSP', 'Shiv Sena',
#        'TDP', 'AIMIM', 'Independent', 'BJD', 'NCP', 'Lok Janshakti Party',
#        'DMK', 'Jharkhand Mukti Morcha', 'TMC', 'JKNC',
#        'Shiromani Akali Dal', 'Kerala Congress', 'SP', 'VCK',
#        'All India Trinamool Congress', 'RLP', 'KECM', 'TRS', 'AAP',
#        'Apna Dal', 'JDS', 'Communist Party of India',
#        'All India United Democratic Front', 'Sikkim Krantikari Morcha',
#        'RJD', 'NDP', 'SDF', 'Republican Party of India'], dtype=object)

# %%
df['Party'].nunique()
# Out:
# 34

# %%
df.dropna(inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                           Speaker  \
# 0               SHRI GAURAV GOGOI
# 1        SHRI MADDILA GURUMOORTHY
# 2             SHRI RAMPRIT MANDAL
# 3     SHRI PRATAP CHANDRA SARANGI
# 4               SHRI MALOOK NAGAR
# ...                           ...
# 1490   SHRI BHAIRON PRASAD MISHRA
# 1491           DR. SHASHI THAROOR
# 1492           SHRI ARVIND SAWANT
# 1493           SHRI JAYADEV GALLA
# 1494          SHRI MOHAMMAD SALIM
#
#                                                  Speech  \
# 0     This is a country characterised by devotion. T...
# 1     I would like to speak about Lord  Rama and the...
# 2     I would like to express my gratitude to you  f...
# 3     Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4     Unprecedented work has been done during the  1...
# ...                                                 ...
# 1490  The present Bill seeks to remove  discrepancie...
# 1491  The Supreme Court of India in its landmark  ju...
# ...

# %%
df.columns
# Out:
# Index(['Speaker', 'Speech', 'Date', 'Type', 'Gender', 'Party', 'Category'], dtype='object')

# %%
for i in range(len(df)):
  speaker = df.loc[i, "Party"]
  if(speaker in ["YSRCP", "YSR Congress Party", "Yuvajana Sramika Rythu Congress Party"]):
    df.loc[i, 'Party'] = "YSR Congress"

  elif(speaker in ["Lok Jan Shakti Party"]):
    df.loc[i, 'Party'] = "Lok Janshakti Party"

  elif(speaker in ["All India Majlis-e-Ittehadul Muslimeen", "All india Majlis-e-Ittehadul Muslimeen"]):
    df.loc[i, 'Party'] = "AIMIM"

  elif(speaker in ["JMM"]):
    df.loc[i, 'Party'] = "Jharkhand Mukti Morcha"

  elif(speaker in ["JNKC", "Jammu and Kashmir National Conference"]):
    df.loc[i, 'Party'] = "JKNC"

  elif(speaker in ["Nationalist Congress Party"]):
    df.loc[i, 'Party'] = "NCP"

  elif(speaker in ["Akali Dal", "SAD"]):
    df.loc[i, 'Party'] = "Shiromani Akali Dal"

  elif(speaker in ["Bharat Rashtra Samithi"]):
    df.loc[i, 'Party'] = "BRS"

  elif(speaker in ["Samajwadi Party"]):
    df.loc[i, 'Party'] = "SP"

  elif(speaker in ["Biju Janata Dal"]):
    df.loc[i, 'Party'] = "BJD"

  elif(speaker in ["Bahujan Samaj Party"]):
    df.loc[i, 'Party'] = "BSP"

  elif(speaker in ["All India Trinamool Congress", "Apna Dal"]):
    df.loc[i, 'Party'] = "TMC"

  elif(speaker in ["Telangana Rashtra Samithi"]):
    df.loc[i, 'Party'] = "TRS"

  elif(speaker in ["Dravida Munnetra Kazhagam"]):
    df.loc[i, 'Party'] = "DMK"

  elif(speaker in ["Janata Da", "Janata Dal"]):
    df.loc[i, 'Party'] = "JDU"

  elif(speaker in ["Kerala Congress (M)", "KECM"]):
    df.loc[i, 'Party'] = "Kerala Congress"

  elif(speaker in ["Rashtriya Loktantrik Party"]):
    df.loc[i, 'Party'] = "RLP"

  elif(speaker in ["Nationalist Democratic Progressive Party"]):
    df.loc[i, 'Party'] = "NDP"

  elif(speaker in ["Sikkim Democratic Front"]):
    df.loc[i, 'Party'] = "SDF"

  elif(speaker in ["Telugu Desam Party"]):
    df.loc[i, 'Party'] = "TDP"

  elif(speaker in ["Viduthalai Chiruthaigal Katchi"]):
    df.loc[i, 'Party'] = "VCK"

  elif(speaker in ["AITC"]):
    df.loc[i, 'Party'] = "All India Trinamool Congress"

  elif(speaker in ["Congress"]):
    df.loc[i, 'Party'] = "INC"

# %%
df['Party'].unique()
# Out:
# array(['INC', 'YSR Congress', 'JDU', 'BJP', 'BSP', 'Shiv Sena', 'TDP',
#        'AIMIM', 'Independent', 'BJD', 'NCP', 'Lok Janshakti Party', 'DMK',
#        'Jharkhand Mukti Morcha', 'TMC', 'JKNC', 'Shiromani Akali Dal',
#        'Kerala Congress', 'SP', 'VCK', 'RLP', 'TRS', 'AAP', 'JDS',
#        'Communist Party of India', 'All India United Democratic Front',
#        'Sikkim Krantikari Morcha', 'RJD', 'NDP', 'SDF',
#        'Republican Party of India'], dtype=object)

# %%
df['Party'].nunique()
# Out:
# 31

# %%
df.Party.value_counts().nlargest(10)
# Out:
# Party
# BJP             618
# INC             117
# Shiv Sena        97
# YSR Congress     81
# BJD              75
# JDU              70
# BSP              67
# TMC              59
# NCP              51
# TDP              44
# Name: count, dtype: int64

# %%
df.to_csv("Lok_Sabha_Dataset_Annotated.csv")

# %%
party = list(dict(df.Party.value_counts().nlargest(10)).keys())
vals = list(dict(df.Party.value_counts().nlargest(10)).values())
ax = sns.barplot(x = party, y = vals, palette="deep")
plt.xticks(rotation=45)
plt.title("Top 10 Parties in Lok Sabha Based on Number of Speeches")
# Out:
# <ipython-input-261-458d3fe7f36d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = party, y = vals, palette="deep")
# Text(0.5, 1.0, 'Top 10 Parties in Lok Sabha Based on Number of Speeches')

# %%
party = list(dict(df.Party.value_counts()).keys())
vals = list(dict(df.Party.value_counts()).values())
df_sub = df.Party.value_counts().to_frame()
plt.figure(figsize = (15, 6))
# ax = sns.barplot(x = party, y = vals, palette="deep")
# ax.bar_label(ax.containers[0], fontsize=10);
ax = sns.barplot(df_sub, x = party, y = vals, palette="deep")
# ax.bar_label(ax.containers[0], fontsize=10);
plt.xticks(rotation=90)
plt.title("Parties Participation in Lok Sabha Based on Number of Speeches")
# Out:
# <ipython-input-263-0805140e0ebe>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(df_sub, x = party, y = vals, palette="deep")
# Text(0.5, 1.0, 'Parties Participation in Lok Sabha Based on Number of Speeches')

# %%
for i in range(len(df)):
  cat = df.loc[i, "Category"]
  if(cat in ["Call for Action", "Call for action", "Call For Action/Appreciate", "Appreciate/Call For Action"]):
    df.loc[i, 'Category'] = "Call For Action"

  elif(cat in ["Blame/Call For Action", "Blame/Issue", "Blame (on Delhi govt.)"]):
    df.loc[i, 'Category'] = "Blame"

  elif(cat == "Appreciation"):
    df.loc[i, 'Category'] = "Appreciate"

# %%
df.Category.value_counts()
# Out:
# Category
# Appreciate         441
# Call For Action    411
# Issue              298
# Blame              206
# Neutral            139
# Name: count, dtype: int64

# %%
party = list(dict(df.Category.value_counts()).keys())
vals = list(dict(df.Category.value_counts()).values())
sns.barplot(x = party, y = vals, palette="deep")
plt.xticks(rotation=45)
plt.title("Total Category Distribution")
# Out:
# <ipython-input-238-bacfa4ef0ce2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = party, y = vals, palette="deep")
# Text(0.5, 1.0, 'Total Category Distribution')

# %%
df.groupby('Party')['Category'].value_counts().nlargest(10)
# Out:
# Party         Category
# BJP           Appreciate         246
#               Call For Action    125
#               Issue               69
#               Neutral             46
# Congress      Blame               35
#               Issue               28
# YSR Congress  Call For Action     26
# BJD           Call For Action     24
# Shiv Sena     Call For Action     23
# BSP           Call For Action     22
# Name: Category, dtype: int64

# %%
top_parties = list(dict(df.Party.value_counts().nlargest(10)).keys())
top_parties
# Out:
# ['BJP',
#  'Congress',
#  'Shiv Sena',
#  'BJD',
#  'YSR Congress',
#  'JDU',
#  'BSP',
#  'NCP',
#  'TMC',
#  'TDP']

# %%
fig, axs = plt.subplots(10,1, figsize=(30, 30))
i = 0
for party in top_parties:
  df_sub = df[df.Party == party]
  # print(df_sub.groupby('Party')['Category'].value_counts())
  d = dict(df_sub.groupby('Party')['Category'].value_counts())
  # print(tuple(d.keys())[1][1])
  labels = list(d.keys())
  # print(labels)
  vals = list(d.values())
  axs[i].pie(vals, labels = labels, autopct = "%.1f")
  i += 1
  # df_sub.groupby('Party')['Category'].value_counts().plot(kind="pie")

# %%
unique_speakers = df.drop_duplicates(subset="Speaker")

# %%
unique_speakers.shape
# Out:
# (373, 7)

# %%
df_unique_speakers = unique_speakers.groupby('Party')['Gender'].value_counts().to_frame().unstack()
plt.figure(figsize = (25, 16))
df_unique_speakers.plot(kind='bar')
# Out:
# <Axes: xlabel='Party'>

# %%
unique_speakers[["Party", "Gender"]].value_counts()[2:].to_frame().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Party'>

# %%
# Most Frequent speakers
df[["Speaker", "Party"]].value_counts().nlargest(10)
# Out:
# Speaker                         Party
# SHRIMATI SUPRIYA SADANAND SULE  NCP            32
# SHRI BHARTRUHARI MAHTAB         BJD            21
# SHRI ASADUDDIN OWAISI           AIMIM          15
# SHRI JAYADEV GALLA              TDP            15
# SHRI ARVIND SAWANT              Shiv Sena      14
# SHRI VINAYAK BHAURAO RAUT       Shiv Sena      14
# SHRIMATI NAVNEET RAVI RANA      Independent    14
# SHRI ADHIR RANJAN CHOWDHURY     Congress       13
# SHRI HANUMAN BENIWAL            RLP            13
# SHRI ANUBHAV MOHANTY            BJD            12
# dtype: int64

# %%
df.Type.unique()
# Out:
# array(['Union Budget', 'Oath'], dtype=object)

# %%
df.Type.value_counts()
# Out:
# Union Budget    1166
# Oath              22
# Name: Type, dtype: int64

# %% [markdown]
# ## Pre-Processing the text

# %%
# !pip install stanza

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
import stanza

# %%
# Download necessary resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv("database.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0                      Speaker  \
# 0           0            SHRI GAURAV GOGOI
# 1           1     SHRI MADDILA GURUMOORTHY
# 2           2          SHRI RAMPRIT MANDAL
# 3           3  SHRI PRATAP CHANDRA SARANGI
# 4           4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head(5)
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
#           Category
# 0            Issue
# ...

# %%
df.shape
# Out:
# (1188, 7)

# %%
def removeNumbers(data):
	return ''.join([i for i in data if not i.isdigit()])

def toLowerCase(data):
	return data.lower()

def removeWhiteSpace(data):
	return data.replace(" ","")

def removeNewLine(data):
	return data.replace("\n","")

def getUpperCharacters(data):
	return ''.join(c for c in data if c.isupper())

def removeSpecialCharacters(data):
	data = re.sub('[^a-zA-Z0-9 \n\.]', '', data)
	return data

# %%
df['Preprocessed_Speech'] = df['Speech'].apply(toLowerCase)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removeSpecialCharacters)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removeNewLine)
df['Preprocessed_Speech'] = df['Preprocessed_Speech'].apply(removeNumbers)

# %%
df.head(5)
# Out:
#                        Speaker  \
# 0            SHRI GAURAV GOGOI
# 1     SHRI MADDILA GURUMOORTHY
# 2          SHRI RAMPRIT MANDAL
# 3  SHRI PRATAP CHANDRA SARANGI
# 4            SHRI MALOOK NAGAR
#
#                                               Speech  \
# 0  This is a country characterised by devotion. T...
# 1  I would like to speak about Lord  Rama and the...
# 2  I would like to express my gratitude to you  f...
# 3  Lord Ram is a symbol of dignity.  Lord Shri Ra...
# 4  Unprecedented work has been done during the  1...
#
#                           Date          Type Gender         Party  \
# 0  Saturday, February 10, 2024  Union Budget      M      Congress
# 1  Saturday, February 10, 2024  Union Budget      M  YSR Congress
# 2  Saturday, February 10, 2024  Union Budget      M           JDU
# 3  Saturday, February 10, 2024  Union Budget      M           BJP
# 4  Saturday, February 10, 2024  Union Budget      M           BSP
#
# ...

# %%
df['Preprocessed_Speech'][1]
# Out:
# 'i would like to speak about lord  rama and the importance of the eternal teachings of lord rama. as depicted in the  ramayana his reign termed as ram rajya symbolized good governance and  epitomised justice welfare and happiness for all. the leadership of lord rama was  dedicated to fairness compassion and the welfare of his people above all else. the  lord venkateshwara temple in my parliamentary constituency at tirupati is one of  the most famous temples in our country. anjanadri hill one of the seven hills is  supposed to be the birthplace of hanuman. another location lepakshi is referenced  in the ramaana which stands as a testament to the widespread reverence of lord  ramas legacy.  by developing these sites we will enhance indias cultural heritage  tourism as well as reinforce the bonds of unity and spirituality inspired by lord  rama. we request the government for comprehensive development and better  connectivity to all religious sites nationwide to further enrich our cultur
# ...

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,ner,sentiment')
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# ...
# INFO:stanza:Loading these models for language: en (English):
# ...
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | pos       | combined_charlm           |
# | lemma     | combined_nocharlm         |
# | sentiment | sstplus_charlm            |
# | ner       | ontonotes-ww-multi_charlm |
# ...
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: sentiment
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
# Tokenization function using Stanza
df['Tokenized_Speech'] = [nlp(entry) for entry in df['Preprocessed_Speech']]

# %%
df['Tokenized_Speech'][0].sentences[1].print_tokens()

# %%
def extract_lemma(doc):
    parsed_text = {'word':[], 'lemma':[]}
    # Iterate over each sentence in the processed text
    for sent in doc.sentences:
        for wrd in sent.words:
            #extract text and lemma
            parsed_text['word'].append(wrd.text)
            parsed_text['lemma'].append(wrd.lemma)
    #return a dataframe
    return parsed_text['lemma']

# %%
# Creating a field containing the lemmatised words
df['lemmatised_speech'] = [extract_lemma(entry) for entry in df['Tokenized_Speech']]

# %%
stop_words = set(stopwords.words('english'))

# %%
# Pre-processed field contains the tokens upon which tokenisation, lemmatisation and removal of punctuation and stop-words is applied
df['Preprocessed_Speech'] = df['lemmatised_speech']

# %%
for i in range(len(df)):
    df['Preprocessed_Speech'][i] = [ele for ele in df['Preprocessed_Speech'][i] if ele not in (stop_words)]
